# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import pingouin as pg
import nibabel as nii
import numpy as np

# %%
df = pd.read_csv("sym_results_invsymloss_volume_v2.csv")
df=df[df.columns[1:]]
#display(df["struct"].unique())
display(df["method"].unique())
#df=df[~df["method"].isin(['Pair-zero-mean'])]
#df=df[df["method"].isin(["Affine","Pair","OP"])]
#df=df[~df["method"].isin(['Pair-zero-mean',"Pair-aug",'SyN'])]
#df=df[~df["struct"].isin(["bs","bg","th","cb","str","hpf","hy"])]
#df=df[~df["struct"].isin(["bs","bg"])]
#df=df[~df["mouse"].isin(["M877"])]
#df=df[~df["target"].isin(["M877"])]
#df=df[df['mouse'] == df['target']]

#display(df["struct"].unique())
display(df["method"].unique())


df["loss"]=df["loss"].apply(lambda x : float(x))
df.sort_values("loss")
# Out:
# array(['SyN', 'SyN-Mask', 'SyN-Mean', 'DL-IRIS-sym', 'OP-sym', 'Pair-sym'],
#       dtype=object)
# array(['SyN', 'SyN-Mask', 'SyN-Mean', 'DL-IRIS-sym', 'OP-sym', 'Pair-sym'],
#       dtype=object)
#        method mouse      loss
# 23        SyN  M875  0.000017
# 72   SyN-Mean  M857  0.000017
# 16        SyN  M672  0.000017
# 18        SyN  M857  0.000019
# 74   SyN-Mean  M867  0.000019
# ..        ...   ...       ...
# 143  Pair-sym   665  0.128631
# 149  Pair-sym   680  0.134896
# 138  Pair-sym   660  0.140778
# 147  Pair-sym   675  0.147472
# 153  Pair-sym  M857  0.281247
#
# [162 rows x 3 columns]

# %%
dfVolumeAvg=df.groupby(["struct"]).agg({"volume" : ['mean','std']})
dfVolumeAvg.columns = dfVolumeAvg.columns.map('_'.join).str.strip('_')

#dfVolumeAvg.columns = dfVolumeAvg.columns.droplevel(0)
dfVolumeAvg=dfVolumeAvg.reset_index()
dfVolumeAvg
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 dfVolumeAvg=df.groupby(["struct"]).agg({"volume" : ['mean','std']})
#       2 dfVolumeAvg.columns = dfVolumeAvg.columns.map('_'.join).str.strip('_')
#       4 #dfVolumeAvg.columns = dfVolumeAvg.columns.droplevel(0)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'struct'

# %%
dfMouseAvg=df.groupby(["method"]).agg({"loss" : ['mean','std']})
dfMouseAvg.columns = dfMouseAvg.columns.map('_'.join).str.strip('_')

#dfMouseAvg.columns = dfMouseAvg.columns.droplevel(0)
dfMouseAvg=dfMouseAvg.reset_index()
dfMouseAvg.round(4)
# Out:
#         method  loss_mean  loss_std
# 0  DL-IRIS-sym     0.0031    0.0004
# 1       OP-sym     0.0463    0.0042
# 2     Pair-sym     0.0988    0.0449
# 3          SyN     0.0000    0.0000
# 4     SyN-Mask     0.0000    0.0000
# 5     SyN-Mean     0.0000    0.0000

# %%
plt.figure(figsize=(20,5))
sns.boxplot(data=df,x="struct",y="dice", hue="method")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 plt.figure(figsize=(20,5))
# ----> 2 sns.boxplot(data=df,x="struct",y="dice", hue="method")
#
# File ~/.local/lib/python3.8/site-packages/seaborn/categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
#    1602         color=color,
#    1603         legend=legend,
#    1604     )
#    1606     if ax is None:
#    1607         ax = plt.gca()
#
# File ~/.local/lib/python3.8/site-packages/seaborn/categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File ~/.local/lib/python3.8/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/.local/lib/python3.8/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/.local/lib/python3.8/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/.local/lib/python3.8/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `struct` for `x`. An entry with this name does not appear in `data`.

# %%
dfpivotMean=dfMouseAvg.pivot(index='method', columns='struct',values="dice_mean")
dfpivotMean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'struct'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 dfpivotMean=dfMouseAvg.pivot(index='method', columns='struct',values="dice_mean")
#       2 dfpivotMean
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:8414, in DataFrame.pivot(self, columns, index, values)
#    8409 @Substitution("")
#    8410 @Appender(_shared_docs["pivot"])
#    8411 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8412     from pandas.core.reshape.pivot import pivot
# -> 8414     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:542, in pivot(data, columns, index, values)
#     539 else:
#     540     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
# --> 542 data_columns = [data[col] for col in columns_listlike]
#     543 index_list.extend(data_columns)
#     544 multiindex = MultiIndex.from_arrays(index_list)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:542, in <listcomp>(.0)
#     539 else:
#     540     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
# --> 542 data_columns = [data[col] for col in columns_listlike]
#     543 index_list.extend(data_columns)
#     544 multiindex = MultiIndex.from_arrays(index_list)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'struct'

# %%
methodRanking=100*dfpivotMean.mean(axis=1)
methodRanking
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 methodRanking=100*dfpivotMean.mean(axis=1)
#       2 methodRanking
#
# NameError: name 'dfpivotMean' is not defined

# %%
dfpivotStd=100*dfMouseAvg.pivot(index='method', columns='struct',values="dice_std")
dfpivotStd
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'struct'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 dfpivotStd=100*dfMouseAvg.pivot(index='method', columns='struct',values="dice_std")
#       2 dfpivotStd
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:8414, in DataFrame.pivot(self, columns, index, values)
#    8409 @Substitution("")
#    8410 @Appender(_shared_docs["pivot"])
#    8411 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8412     from pandas.core.reshape.pivot import pivot
# -> 8414     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:542, in pivot(data, columns, index, values)
#     539 else:
#     540     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
# --> 542 data_columns = [data[col] for col in columns_listlike]
#     543 index_list.extend(data_columns)
#     544 multiindex = MultiIndex.from_arrays(index_list)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:542, in <listcomp>(.0)
#     539 else:
#     540     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
# --> 542 data_columns = [data[col] for col in columns_listlike]
#     543 index_list.extend(data_columns)
#     544 multiindex = MultiIndex.from_arrays(index_list)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'struct'

# %%
methodRanking=dfpivotStd.mean(axis=1)
methodRanking
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 methodRanking=dfpivotStd.mean(axis=1)
#       2 methodRanking
#
# NameError: name 'dfpivotStd' is not defined

# %%
structRanking=dfpivotMean.mean(axis=0).sort_values()
structRanking
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 structRanking=dfpivotMean.mean(axis=0).sort_values()
#       2 structRanking
#
# NameError: name 'dfpivotMean' is not defined

# %%
structRankingByVariance=dfpivotMean.std(axis=0).sort_values()
structRankingByVariance
# Out:
# struct
# th     0.009143
# hpf    0.012286
# str    0.014954
# cb     0.014977
# hy     0.018108
# mb     0.020844
# gp     0.022194
# ctx    0.031988
# olf    0.037460
# dtype: float64

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data=df, x="struct",y="dice", hue="method")
plt.savefig("ranking.png")

# %%
plt.figure(figsize=(20,5))
sns.boxplot(data=dfMouseAvg, x="method",y="dice_mean", order=methodRanking.index )
plt.savefig("ranking2.png")

# %%
plt.figure(figsize=(20,5))
sns.boxplot(data=dfMouseAvg, x="struct",y="dice_mean", order=structRanking.index)
plt.savefig("ranking3.png")

# %%
plt.figure(figsize=(20,5))
sns.boxplot(data=dfMouseAvg, x="struct",y="dice_mean", order=structRankingByVariance.index)
plt.savefig("ranking3bis.png")

# %% [markdown]
# gp : petite structure / peu contrasté => difficile à segmenter
#
# olf : sensible au fied of view => grand variabilité morpho / pb de crop
#
# mb : structure peu contrasté / mal définiee ?
#
# hy : inferior : pb RSN / biais / variabilté FOV / decoupe
#
#
# ctx / str / hpf / cb / th

# %%
for item in structRanking.index :
    plt.figure(figsize=(20,5))
    sns.boxplot(data=df[df["struct"]==item], x="method",y="dice", order=methodRanking.index )
    plt.title(item)
    plt.show()

# %%
from statannotations.Annotator import Annotator
for item in structRanking.index :
    plt.figure(figsize=(20,5))
    ax=sns.boxplot(data=df[df["struct"]==item], x="method",y="dice", order=methodRanking.index )
    plt.title(item)
    pairs=[("Pair","OP"),("Pair","Pair-zero"),('DL-GIN-3fold','DL-IRIS'),('DL-GIN-3fold','OP'),("Pair-null","Pair-zero"),("Pair-null","SyN-Mean"),("OP","SyN-Mean")]
    annotator = Annotator(ax, pairs, data=df[df["struct"]==item], x="method",y="dice", order=methodRanking.index.tolist() )
    annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
    annotator.apply_and_annotate()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 from statannotations.Annotator import Annotator
#       2 for item in structRanking.index :
#       3     plt.figure(figsize=(20,5))
#
# ModuleNotFoundError: No module named 'statannotations'

# %%
.tolist()
# Out:
#   Input In [15]
#     .tolist()
#     ^
# SyntaxError: invalid syntax

# %%
methodRanking.index.tolist()
# Out:
# ['SyN',
#  'Affine',
#  'SyN-Mask',
#  'Pair-null',
#  'DL-IRIS',
#  'SyN-Mean',
#  'DL-GIN-3fold',
#  'Pair-zero',
#  'Pair',
#  'OP']

# %%
df.pivot(index='method', columns=['mouse',"struct"],values="dice").T.ptests(paired=True)
# Out:
# method         Affine DL-GIN-3fold DL-IRIS      OP    Pair Pair-null  \
# method
# Affine              -          ***     ***     ***     ***       ***
# DL-GIN-3fold  -10.808            -             ***       *       ***
# DL-IRIS       -11.225         0.65       -     ***     ***       ***
# OP             -12.03       -5.155  -4.262       -               ***
# Pair            -11.0       -2.409   -4.45   1.722       -       ***
# Pair-null     -10.654        4.819   8.842    8.46   8.369         -
# Pair-zero     -10.127       -0.565  -2.236   3.749   4.304    -6.816
# SyN             5.077       15.586  14.574  18.165  16.851    12.362
# SyN-Mask       -3.356       11.298   9.459  17.779  15.215     4.778
# SyN-Mean       -13.12        0.361  -0.794   4.061   3.278    -9.373
#
# method       Pair-zero      SyN SyN-Mask SyN-Mean
# method
# Affine             ***      ***      ***      ***
# DL-GIN-3fold                ***      ***
# DL-IRIS              *      ***      ***
# OP                 ***      ***      ***      ***
# Pair               ***      ***      ***       **
# Pair-null          ***      ***      ***      ***
# Pair-zero            -      ***      ***
# SyN             15.854        -      ***      ***
# SyN-Mask        12.348  -12.042        -      ***
# SyN-Mean         1.267  -15.677  -10.573        -

# %%
for item in df["struct"].unique() :
    print(item)
    display(df[df["struct"]==item].pivot(index='method', columns=['mouse',"struct"],values="dice").T.ptests(paired=True))
# Out:
# hy
# method        Affine DL-GIN-3fold DL-IRIS      OP   Pair Pair-null Pair-zero  \
# method
# Affine             -          ***     ***     ***    ***       ***
# DL-GIN-3fold  -4.375            -              **                          *
# DL-IRIS       -7.184       -1.582       -      **                        ***
# OP            -7.355       -3.614    -3.1       -     **        **       ***
# Pair          -6.004       -1.965  -0.909   3.624      -                 ***
# Pair-null     -7.172       -0.809   1.317    3.44  1.565         -        **
# Pair-zero     -1.937        2.329   4.872  10.026  7.461     3.525         -
# SyN            9.455        9.697  10.143  11.244  10.46    10.562     9.732
# SyN-Mask       4.969        5.779   6.423   7.406  6.829     6.543     5.744
# SyN-Mean      -3.736        0.563   2.547   7.555  4.522     1.354    -3.271
#
# method            SyN SyN-Mask SyN-Mean
# method
# Affine            ***      ***      ***
# DL-GIN-3fold      ***      ***
# DL-IRIS           ***      ***        *
# OP                ***      ***      ***
# Pair              ***      ***      ***
# Pair-null         ***      ***
# Pair-zero         ***      ***       **
# SyN                 -      ***      ***
# SyN-Mask       -7.762        -      ***
# SyN-Mean      -10.503   -6.348        -
# mb
# method        Affine DL-GIN-3fold DL-IRIS      OP    Pair Pair-null Pair-zero  \
# method
# Affine             -                   **
# DL-GIN-3fold  -1.131            -     ***                         *
# DL-IRIS       -3.507       -4.812       -     ***      **       ***        **
# OP            -1.652       -1.985   3.924       -                **
# Pair          -1.615       -1.257   2.878   0.114       -        **
# Pair-null      0.344        2.435   5.944   3.144   3.035         -        **
# Pair-zero     -1.867       -1.566   3.229   -0.47  -0.611    -3.093         -
# SyN           11.514       10.309   12.32  11.089  10.989    10.563    11.564
# SyN-Mask       4.632        8.849  15.138  12.581  13.012     6.111    14.147
# SyN-Mean       -3.39       -8.053   -1.32  -6.774  -4.857    -6.187    -4.267
#
# method            SyN SyN-Mask SyN-Mean
# method
# Affine            ***      ***       **
# DL-GIN-3fold      ***      ***      ***
# DL-IRIS           ***      ***
# OP                ***      ***      ***
# Pair              ***      ***      ***
# Pair-null         ***      ***      ***
# Pair-zero         ***      ***      ***
# SyN                 -      ***      ***
# SyN-Mask       -8.745        -      ***
# SyN-Mean      -11.736  -13.739        -
# hpf
# method         Affine DL-GIN-3fold DL-IRIS      OP    Pair Pair-null  \
# method
# Affine              -          ***     ***     ***     ***       ***
# DL-GIN-3fold   -8.305            -             ***
# DL-IRIS       -10.111        0.185       -     ***               ***
# OP            -15.061       -4.128  -7.732       -     ***       ***
# Pair          -11.783       -0.024  -0.593   7.422       -       ***
# Pair-null     -15.178       -1.138  -4.572   4.833  -3.798         -
# Pair-zero      -8.713        1.419   3.403  10.608   4.979      8.84
# SyN            12.258         15.1  24.349  23.432  24.916      26.4
# SyN-Mask        6.386       10.261  13.702  14.622  14.262    14.661
# SyN-Mean      -10.332       -0.463  -1.995   7.368  -1.036     1.777
#
# method       Pair-zero     SyN SyN-Mask SyN-Mean
# method
# Affine             ***     ***      ***      ***
# DL-GIN-3fold               ***      ***
# DL-IRIS             **     ***      ***
# OP                 ***     ***      ***      ***
# Pair               ***     ***      ***
# Pair-null          ***     ***      ***
# Pair-zero            -     ***      ***      ***
# SyN             23.281       -      ***      ***
# SyN-Mask        12.037  -8.121        -      ***
# SyN-Mean        -4.484  -25.44  -14.291        -
# str
# method         Affine DL-GIN-3fold DL-IRIS      OP   Pair Pair-null Pair-zero  \
# method
# Affine              -          ***     ***     ***    ***       ***       ***
# DL-GIN-3fold  -10.878            -
# DL-IRIS        -11.99       -0.929       -                      ***
# OP            -13.315       -1.843  -0.855       -              ***         *
# Pair          -11.478       -1.482  -1.584  -0.531      -       ***        **
# Pair-null     -12.466        0.846   4.998   5.232   5.71         -         *
# Pair-zero     -10.536       -0.182   1.682   2.095  3.581    -2.308         -
# SyN            -3.433        4.844   8.149   8.037  8.425     6.731     7.001
# SyN-Mask       -3.928        4.132   7.124   6.958  7.572       5.6     6.148
# SyN-Mean      -10.196        0.062   3.419   3.435  6.185    -1.851     0.696
#
# method           SyN SyN-Mask SyN-Mean
# method
# Affine            **      ***      ***
# DL-GIN-3fold     ***      ***
# DL-IRIS          ***      ***       **
# OP               ***      ***       **
# Pair             ***      ***      ***
# Pair-null        ***      ***
# Pair-zero        ***      ***
# SyN                -       **      ***
# SyN-Mask      -2.878        -      ***
# SyN-Mean      -7.508   -6.387        -
# ctx
# method         Affine DL-GIN-3fold  DL-IRIS       OP     Pair Pair-null  \
# method
# Affine              -                   ***                **       ***
# DL-GIN-3fold    0.032            -      ***               ***       ***
# DL-IRIS        -5.322      -14.029        -      ***       **
# OP             -0.804       -1.989    9.595        -       **       ***
# Pair           -3.427       -3.769    3.539   -3.193        -        **
# Pair-null      -7.746       -8.234    1.213   -7.009   -3.563         -
# Pair-zero        1.07        1.158    6.673    2.073    4.761     6.394
# SyN             1.621        1.738    7.852    2.881    4.965     8.344
# SyN-Mask       -4.118       -4.175      2.4   -3.906   -0.726     2.156
# SyN-Mean      -12.476       -32.16  -18.806  -30.526  -12.108   -13.873
#
# method       Pair-zero      SyN SyN-Mask SyN-Mean
# method
# Affine                               ***      ***
# DL-GIN-3fold                         ***      ***
# DL-IRIS            ***      ***        *      ***
# OP                   *       **      ***      ***
# Pair               ***      ***               ***
# Pair-null          ***      ***        *      ***
# Pair-zero            -               ***      ***
# SyN              0.483        -      ***      ***
# SyN-Mask        -4.553  -11.408        -      ***
# SyN-Mean        -12.76  -17.682   -13.05        -
# gp
# method        Affine DL-GIN-3fold DL-IRIS      OP    Pair Pair-null Pair-zero  \
# method
# Affine             -          ***     ***     ***     ***       ***       ***
# DL-GIN-3fold  -5.018            -      **       *       *                  **
# DL-IRIS       -6.672       -2.781       -      **               ***         *
# OP            -6.265       -2.386   3.089       -       *         *       ***
# Pair          -5.642       -2.739  -0.094  -2.493       -        **         *
# Pair-null     -6.921       -0.448   4.745    2.71   3.096         -       ***
# Pair-zero     -6.629       -3.439  -2.264    -4.4  -2.284    -4.719         -
# SyN           -2.528         3.89    8.25   8.031   6.453     7.072     7.904
# SyN-Mask      -3.557        1.555   9.647   7.405   7.099     3.756     9.421
# SyN-Mean      -7.378       -1.943   2.654   0.044    1.62    -3.781     3.082
#
# method            SyN SyN-Mask SyN-Mean
# method
# Affine              *       **      ***
# DL-GIN-3fold      ***
# DL-IRIS           ***      ***        *
# OP                ***      ***
# Pair              ***      ***
# Pair-null         ***      ***      ***
# Pair-zero         ***      ***       **
# SyN                 -      ***      ***
# SyN-Mask       -4.117        -      ***
# SyN-Mean      -11.706   -9.027        -
# th
# method        Affine DL-GIN-3fold DL-IRIS      OP    Pair Pair-null Pair-zero  \
# method
# Affine             -          ***     ***     ***     ***       ***       ***
# DL-GIN-3fold  -6.569            -                                 *
# DL-IRIS       -8.839        0.051       -     ***     ***       ***
# OP            -9.307       -1.732  -4.988       -               ***       ***
# Pair          -9.056       -1.291  -3.771    1.43       -       ***       ***
# Pair-null      -7.37        2.754   4.413   8.671   7.127         -         *
# Pair-zero     -6.533        0.963   1.726   4.613    4.96    -2.187         -
# SyN            8.595        9.751  11.352  11.321  11.174     9.817    10.322
# SyN-Mask       3.476        7.192  10.813  11.295  10.304     7.222     8.022
# SyN-Mean      -6.596       -0.393  -1.138   3.856   2.327    -4.123    -2.438
#
# method            SyN SyN-Mask SyN-Mean
# method
# Affine            ***       **      ***
# DL-GIN-3fold      ***      ***
# DL-IRIS           ***      ***
# OP                ***      ***      ***
# Pair              ***      ***        *
# Pair-null         ***      ***      ***
# Pair-zero         ***      ***        *
# SyN                 -      ***      ***
# SyN-Mask       -8.985        -      ***
# SyN-Mean      -10.977   -9.515        -
# cb
# method         Affine DL-GIN-3fold DL-IRIS      OP    Pair Pair-null  \
# method
# Affine              -          ***     ***     ***     ***       ***
# DL-GIN-3fold   -8.635            -              **     ***       ***
# DL-IRIS        -9.419        0.445       -      **     ***       ***
# OP             -9.256       -3.696  -3.526       -       *       ***
# Pair          -10.865       -4.877  -7.877  -2.609       -       ***
# Pair-null     -10.327        5.794   6.284   6.493   8.326         -
# Pair-zero     -10.288        -3.86  -6.059  -1.696    1.59    -7.581
# SyN             0.187        7.649   8.156    8.63   9.189     3.835
# SyN-Mask       -2.745       10.323  14.294  12.072  15.316     2.198
# SyN-Mean      -10.905       -5.297  -8.351  -3.124  -0.136    -7.889
#
# method       Pair-zero      SyN SyN-Mask SyN-Mean
# method
# Affine             ***                 *      ***
# DL-GIN-3fold       ***      ***      ***      ***
# DL-IRIS            ***      ***      ***      ***
# OP                          ***      ***       **
# Pair                        ***      ***
# Pair-null          ***      ***        *      ***
# Pair-zero            -      ***      ***
# SyN              8.875        -        *      ***
# SyN-Mask        14.049   -2.776        -      ***
# SyN-Mean         -1.08  -10.073  -17.199        -
# olf
# method         Affine DL-GIN-3fold  DL-IRIS      OP    Pair Pair-null  \
# method
# Affine              -          ***      ***     ***     ***       ***
# DL-GIN-3fold  -30.892            -      ***      **     ***       ***
# DL-IRIS        -40.89        17.85        -     ***     ***       ***
# OP             -28.57       -3.175  -17.605       -     ***       ***
# Pair          -31.331        6.637  -16.897   6.678       -       ***
# Pair-null     -18.882       21.265    8.266  19.322  23.917         -
# Pair-zero      -16.41         6.32   -7.474   6.303   3.114   -10.187
# SyN            -4.105        6.959    0.029   7.334   4.676    -1.367
# SyN-Mask      -13.055        3.905   -6.444   4.376   0.999    -8.726
# SyN-Mean      -10.039       24.247   -0.923  38.465  11.264    -3.732
#
# method       Pair-zero     SyN SyN-Mask SyN-Mean
# method
# Affine             ***     ***      ***      ***
# DL-GIN-3fold       ***     ***      ***      ***
# DL-IRIS            ***              ***
# OP                 ***     ***      ***      ***
# Pair                **     ***               ***
# Pair-null          ***              ***      ***
# Pair-zero            -      **               ***
# SyN              3.654       -      ***
# SyN-Mask        -0.822  -6.433        -      ***
# SyN-Mean         5.391  -0.485    5.194        -

# %%
post_hocs = pg.pairwise_tests(dv='dice_mean', within='method',subject="struct", data=dfMouseAvg,padjust="fdr_bh")
post_hocs[post_hocs["p-corr"]>0.05].sort_values("p-unc")
# Out:
#    Contrast             A             B  Paired  Parametric         T  dof  \
# 42   method           SyN      SyN-Mask    True        True -3.053234  8.0
# 36   method     Pair-null           SyN    True        True  2.978994  8.0
# 10   method  DL-GIN-3fold            OP    True        True -2.926103  8.0
# 1    method        Affine       DL-IRIS    True        True -2.887837  8.0
# 3    method        Affine          Pair    True        True -2.778803  8.0
# 2    method        Affine            OP    True        True -2.743447  8.0
# 19   method       DL-IRIS     Pair-null    True        True  2.664782  8.0
# 4    method        Affine     Pair-null    True        True -2.646965  8.0
# 0    method        Affine  DL-GIN-3fold    True        True -2.510299  8.0
# 44   method      SyN-Mask      SyN-Mean    True        True -2.460752  8.0
# 5    method        Affine     Pair-zero    True        True -2.454227  8.0
# 22   method       DL-IRIS      SyN-Mask    True        True  2.111434  8.0
# 30   method          Pair     Pair-null    True        True  2.065619  8.0
# 25   method            OP     Pair-null    True        True  1.772934  8.0
# 35   method     Pair-null     Pair-zero    True        True -1.680057  8.0
# 31   method          Pair     Pair-zero    True        True  1.677221  8.0
# 6    method        Affine           SyN    True        True  1.156756  8.0
# 12   method  DL-GIN-3fold     Pair-null    True        True  1.140478  8.0
# 37   method     Pair-null      SyN-Mask    True        True  1.081293  8.0
# 18   method       DL-IRIS          Pair    True        True -0.999237  8.0
# 26   method            OP     Pair-zero    True        True  0.953349  8.0
# 11   method  DL-GIN-3fold          Pair    True        True -0.920366  8.0
# 34   method          Pair      SyN-Mean    True        True  0.862582  8.0
# 17   method       DL-IRIS            OP    True        True -0.854422  8.0
# 7    method        Affine      SyN-Mask    True        True -0.820359  8.0
# 29   method            OP      SyN-Mean    True        True  0.804331  8.0
# 20   method       DL-IRIS     Pair-zero    True        True -0.543040  8.0
# 24   method            OP          Pair    True        True  0.505409  8.0
# 41   method     Pair-zero      SyN-Mean    True        True  0.346928  8.0
# 23   method       DL-IRIS      SyN-Mean    True        True -0.332017  8.0
# 13   method  DL-GIN-3fold     Pair-zero    True        True -0.174077  8.0
# 9    method  DL-GIN-3fold       DL-IRIS    True        True  0.159638  8.0
# 16   method  DL-GIN-3fold      SyN-Mean    True        True  0.087025  8.0
#
#    alternative     p-unc    p-corr p-adjust   BF10    hedges
# 42   two-sided  0.015744  0.054497   fdr_bh  4.444 -0.391294
# 36   two-sided  0.017627  0.056660   fdr_bh  4.067  0.504324
# 10   two-sided  0.019112  0.056999   fdr_bh  3.818 -0.096377
# 1    two-sided  0.020266  0.056999   fdr_bh  3.647 -0.381213
# 3    two-sided  0.023969  0.063285   fdr_bh  3.201 -0.470279
# 2    two-sided  0.025314  0.063285   fdr_bh  3.069 -0.489484
# 19   two-sided  0.028593  0.066136   fdr_bh  2.794  0.134380
# 4    two-sided  0.029394  0.066136   fdr_bh  2.735 -0.251101
# 0    two-sided  0.036354  0.077624   fdr_bh  2.324 -0.401965
# 44   two-sided  0.039273  0.077624   fdr_bh  2.191 -0.301557
# 5    two-sided  0.039674  0.077624   fdr_bh  2.174 -0.432775
# 22   two-sided  0.067722  0.126979   fdr_bh  1.456  0.298410
# 30   two-sided  0.072722  0.130900   fdr_bh  1.382  0.227023
# 25   two-sided  0.114174  0.197609   fdr_bh  0.997  0.250618
# 35   two-sided  0.131457  0.212177   fdr_bh  0.903 -0.181813
# 31   two-sided  0.132022  0.212177   fdr_bh    0.9  0.054869
# 6    two-sided  0.280743  0.430616   fdr_bh  0.546  0.224728
# 12   two-sided  0.287077  0.430616   fdr_bh  0.539  0.156631
# 37   two-sided  0.311081  0.451569   fdr_bh  0.513  0.146846
# 18   two-sided  0.346941  0.487886   fdr_bh  0.481 -0.092693
# 26   two-sided  0.368327  0.502264   fdr_bh  0.465  0.083856
# 11   two-sided  0.384295  0.508625   fdr_bh  0.454 -0.069360
# 34   two-sided  0.413477  0.522151   fdr_bh  0.436  0.078259
# 17   two-sided  0.417721  0.522151   fdr_bh  0.434 -0.119252
# 7    two-sided  0.435771  0.526321   fdr_bh  0.424 -0.130884
# 29   two-sided  0.444448  0.526321   fdr_bh   0.42  0.104201
# 20   two-sided  0.601900  0.694500   fdr_bh  0.364 -0.042404
# 24   two-sided  0.626899  0.705262   fdr_bh  0.358  0.029209
# 41   two-sided  0.737595  0.801866   fdr_bh  0.339  0.029302
# 23   two-sided  0.748408  0.801866   fdr_bh  0.337 -0.011072
# 13   two-sided  0.866129  0.897058   fdr_bh  0.326 -0.018324
# 9    two-sided  0.877123  0.897058   fdr_bh  0.325  0.022830
# 16   two-sided  0.932791  0.932791   fdr_bh  0.323  0.011053

# %%
post_hocs = pg.pairwise_tests(dv='dice', between='method', data=df,padjust="fdr_bh")
post_hocs[post_hocs["p-corr"]>0.05].sort_values("p-unc")
# Out:
#    Contrast             A          B  Paired  Parametric         T    dof  \
# 35   method     Pair-null  Pair-zero   False        True -2.070284  484.0
# 12   method  DL-GIN-3fold  Pair-null   False        True  1.763509  484.0
# 37   method     Pair-null   SyN-Mask   False        True  1.665330  484.0
# 38   method     Pair-null   SyN-Mean   False        True -1.623651  484.0
# 19   method       DL-IRIS  Pair-null   False        True  1.539646  484.0
# 7    method        Affine   SyN-Mask   False        True -1.455729  484.0
# 17   method       DL-IRIS         OP   False        True -1.378741  484.0
# 29   method            OP   SyN-Mean   False        True  1.205285  484.0
# 10   method  DL-GIN-3fold         OP   False        True -1.089878  484.0
# 18   method       DL-IRIS       Pair   False        True -1.069564  484.0
# 26   method            OP  Pair-zero   False        True  0.963068  484.0
# 34   method          Pair   SyN-Mean   False        True  0.903547  484.0
# 11   method  DL-GIN-3fold       Pair   False        True -0.782511  484.0
# 31   method          Pair  Pair-zero   False        True  0.628628  484.0
# 20   method       DL-IRIS  Pair-zero   False        True -0.485879  484.0
# 24   method            OP       Pair   False        True  0.338065  484.0
# 41   method     Pair-zero   SyN-Mean   False        True  0.336096  484.0
# 9    method  DL-GIN-3fold    DL-IRIS   False        True  0.258013  484.0
# 13   method  DL-GIN-3fold  Pair-zero   False        True -0.205212  484.0
# 23   method       DL-IRIS   SyN-Mean   False        True -0.127743  484.0
# 16   method  DL-GIN-3fold   SyN-Mean   False        True  0.125122  484.0
#
#    alternative     p-unc    p-corr p-adjust   BF10    hedges
# 35   two-sided  0.038955  0.070120   fdr_bh  0.802 -0.187529
# 12   two-sided  0.078446  0.135771   fdr_bh  0.455  0.159741
# 37   two-sided  0.096494  0.160823   fdr_bh  0.386  0.150848
# 38   two-sided  0.105101  0.168913   fdr_bh  0.362 -0.147072
# 19   two-sided  0.124300  0.192880   fdr_bh  0.318  0.139463
# 7    two-sided  0.146116  0.219174   fdr_bh  0.282 -0.131862
# 17   two-sided  0.168611  0.244759   fdr_bh  0.253 -0.124888
# 29   two-sided  0.228682  0.321584   fdr_bh  0.204  0.109176
# 10   two-sided  0.276309  0.376785   fdr_bh  0.179 -0.098722
# 18   two-sided  0.285349  0.377667   fdr_bh  0.176 -0.096882
# 26   two-sided  0.335994  0.431992   fdr_bh  0.158  0.087236
# 34   two-sided  0.366685  0.458357   fdr_bh   0.15  0.081844
# 11   two-sided  0.434297  0.528199   fdr_bh  0.136 -0.070881
# 31   two-sided  0.529889  0.627500   fdr_bh  0.122  0.056942
# 20   two-sided  0.627273  0.723776   fdr_bh  0.113 -0.044012
# 24   two-sided  0.735461  0.808841   fdr_bh  0.107  0.030622
# 41   two-sided  0.736944  0.808841   fdr_bh  0.106  0.030444
# 9    two-sided  0.796506  0.853400   fdr_bh  0.104  0.023371
# 13   two-sided  0.837493  0.876446   fdr_bh  0.103 -0.018588
# 23   two-sided  0.898405  0.900479   fdr_bh  0.102 -0.011571
# 16   two-sided  0.900479  0.900479   fdr_bh  0.102  0.011334
