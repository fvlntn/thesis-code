# %%
import argparse
import logging
import sys

import monai
import torch
from torch.utils.tensorboard import SummaryWriter
from monai.utils import set_determinism
import numpy as np
from glob import glob
import os

from monai.transforms.transform import Transform
from monai.transforms import Activations, EnsureType, Compose
from transforms import CropMRId, BinaryMask, GetLargestComponent, GetLabelsAsOneHotd, Shaped, InverseOneHot
from torch import nn
from transforms_dict import getSegmentationEvalTransformsForMRI
from transforms_dict import getSegmentationInverseTransformForLabels

from seg_data import getDataset
from seg_model import getUNetForSegmentation
from utils import compute_mean_dice, getReducePlateauScheduler, getAdamOptimizer, loadExistingModel
from utils import print_model_output, check_model_name, getDevice

# %%
#Parameters
N4 = False
resample = False
save_tmp = False
get_largest_component = False

# %%
#Modelname and device

def getUNETRForSegmentation():
    device = getDevice()
    model = monai.networks.nets.UNETR(
        in_channels=1,
        out_channels=4,
        img_size=(128, 128, 128),
        feature_size=16,
        hidden_size=768,
        mlp_dim=3072,
        num_heads=12,
        pos_embed="perceptron",
        norm_name="instance",
        res_block=True,
        dropout_rate=0.0,
    ).to(device)
    return model

#model = getUNETRForSegmentation()
#modelname = "labels/seg_labels_unetr_1.pth"

model = getUNetForSegmentation()
modelname = "labels/seg_labels_2.pth"

modelname = check_model_name(modelname)
set_determinism(seed=0)
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
device = getDevice()

# %%
def max_channel_wise(labels):
    labels = labels.detach().cpu().numpy()
    labels[np.where(labels == np.amax(labels, axis=1))] = 1
    labels[labels != 1] = 0
    return labels


class GetMaxChannelWise(Transform):
    def __call__(self, labels):
        labels = max_channel_wise(labels)
        return labels

# %%
def getSegmentationPostProcessingForLabel():
    device = getDevice()
    postprocessing_transforms = Compose(
        [
            EnsureType(),
            GetMaxChannelWise(),
            EnsureType(data_type="tensor", device=device),
        ]
    )
    return postprocessing_transforms


def getSegmentationPostProcessingForLabelOutput():
    device = getDevice()
    postprocessing_transforms = Compose(
        [
            EnsureType(),
            Activations(other=nn.Softmax(dim=1)),
            GetMaxChannelWise(),
            EnsureType(data_type="tensor", device=device),
        ]
    )
    return postprocessing_transforms

def getSegmentationPostProcessingForAllLabelsOutput():
    device = getDevice()
    postprocessing_transforms = Compose(
        [
            EnsureType(),
            Activations(other=nn.Softmax(dim=1)),
            InverseOneHot(),
            EnsureType(data_type="tensor", device=device),
        ]
    )
    return postprocessing_transforms

# %%
#postprocessing
device = getDevice()
outputs_processing = getSegmentationPostProcessingForLabelOutput()
all_outputs_processing = getSegmentationPostProcessingForAllLabelsOutput()
labels_processing = getSegmentationPostProcessingForLabel()
test_proba = Compose([
    EnsureType(),
    Activations(other=nn.Softmax(dim=1)),
    EnsureType(data_type="tensor", device=device)
])

#activations
softmax = Activations(other=nn.Softmax(dim=1))

# %%
#Metric MUNet
def metric_munet(preds, labels):  
    #labels[np.where(labels == np.amax(labels, axis=0))] = 1
    #labels[labels != 1] = 0
    dice=2*np.sum(labels*preds,(0,1,2))/(np.sum((labels+preds),(0,1,2))+1)    
    return dice

def dice(a,b):
 intersection = np.logical_and(a, b)
 union = np.logical_or(a, b)
 dice = (2*np.sum(intersection))/(np.sum(union)+np.sum(intersection))
 return dice

# %%
#Model
import nibabel as nib
from transforms import GetLabelsAsOneHot, LoadNibabel, NibabelToNumpy

loadExistingModel(model, None, ft=modelname)
model.eval()

mris = sorted(glob(os.path.join("dataset", "Painfact-Segmentation", 'MRI', "*.nii.gz")))
labels = sorted(glob(os.path.join("dataset", "Painfact-Segmentation", 'Label', "*.nii.gz")))

metrics = [[], [], [], []]
for i, mri in enumerate(mris):
    print(str(i) + '/' + str(len(mris)), end='\r')
    if i>=0:
        mriname = mri
        outname = "labels_output_unet/" + mriname.split('/')[-1].split('.')[0]
        

        mri_preprocessing = getSegmentationEvalTransformsForMRI(N4=N4, outname=outname, save=save_tmp)

        with torch.no_grad():
            inputs = mri_preprocessing(mriname).to(device)
            outputs = model(inputs).cpu()  

            preds = outputs_processing(outputs)
            #all_preds = all_outputs_processing(outputs)
            #probs = test_proba(outputs)

            suffix = ["bg", "c1", "c2", "c3"]
            preds_resized = []
            for i in range(len(suffix)):
                transform = getSegmentationInverseTransformForLabels(mriname, out_name=outname, suffix=suffix[i], save=True)
                x = transform(preds[0, i, :, :, :]) 
                preds_resized.append(x)



            x = labels[i]
            x = LoadNibabel()(x)
            x = NibabelToNumpy()(x)
            x = GetLabelsAsOneHot(get=True, skip=False)(x)

            y = torch.stack([torch.from_numpy(z) for z in preds_resized]).numpy()

            for j in range(len(preds_resized)):
                metric = dice(y[j,:,:,:], x[j,:,:,:])  
                metrics[j].append(metric)     

            #for i in range(len(suffix)):
            #    transform = getSegmentationInverseTransformForLabels(mriname, out_name=outname, suffix=suffix[i]+'_prob', save=True)
            #    transform(probs[0, i, :, :, :])
            #transform = getSegmentationInverseTransformForLabels(mriname, out_name=outname, suffix=None, save=False)
            #transform(all_preds[0,:,:,:])

epoch_metrics = [np.mean(x) for x in metrics]
epoch_metric = np.mean(epoch_metrics)


print(
        "dice: {:.4f}".format(
            epoch_metric
        )
    )
print("dices: {:.4f}, {:.4f}, {:.4f}, {:.4f}".format(epoch_metrics[0], epoch_metrics[1], epoch_metrics[2], epoch_metrics[3]))
# Out:
# => Saved to labels_output_unet/000_M_I23_out_bg.nii.gz
# => Saved to labels_output_unet/000_M_I23_out_c1.nii.gz
# => Saved to labels_output_unet/000_M_I23_out_c2.nii.gz
# => Saved to labels_output_unet/000_M_I23_out_c3.nii.gz
# => Saved to labels_output_unet/101_M_A1_out_bg.nii.gz
# => Saved to labels_output_unet/101_M_A1_out_c1.nii.gz
# => Saved to labels_output_unet/101_M_A1_out_c2.nii.gz
# => Saved to labels_output_unet/101_M_A1_out_c3.nii.gz
# => Saved to labels_output_unet/102_M_A2_out_bg.nii.gz
# => Saved to labels_output_unet/102_M_A2_out_c1.nii.gz
# => Saved to labels_output_unet/102_M_A2_out_c2.nii.gz
# => Saved to labels_output_unet/102_M_A2_out_c3.nii.gz
# => Saved to labels_output_unet/103_M_I21_out_bg.nii.gz
# => Saved to labels_output_unet/103_M_I21_out_c1.nii.gz
# => Saved to labels_output_unet/103_M_I21_out_c2.nii.gz
# => Saved to labels_output_unet/103_M_I21_out_c3.nii.gz
# => Saved to labels_output_unet/109_F_K2_out_bg.nii.gz
# => Saved to labels_output_unet/109_F_K2_out_c1.nii.gz
# => Saved to labels_output_unet/109_F_K2_out_c2.nii.gz
# => Saved to labels_output_unet/109_F_K2_out_c3.nii.gz
# => Saved to labels_output_unet/110_F_K1_out_bg.nii.gz
# => Saved to labels_output_unet/110_F_K1_out_c1.nii.gz
# => Saved to labels_output_unet/110_F_K1_out_c2.nii.gz
# => Saved to labels_output_unet/110_F_K1_out_c3.nii.gz
# => Saved to labels_output_unet/113_M_A3_out_bg.nii.gz
# => Saved to labels_output_unet/113_M_A3_out_c1.nii.gz
# => Saved to labels_output_unet/113_M_A3_out_c2.nii.gz
# => Saved to labels_output_unet/113_M_A3_out_c3.nii.gz
# => Saved to labels_output_unet/114_M_A4_out_bg.nii.gz
# => Saved to labels_output_unet/114_M_A4_out_c1.nii.gz
# => Saved to labels_output_unet/114_M_A4_out_c2.nii.gz
# => Saved to labels_output_unet/114_M_A4_out_c3.nii.gz
# => Saved to labels_output_unet/115_M_E13_out_bg.nii.gz
# => Saved to labels_output_unet/115_M_E13_out_c1.nii.gz
# => Saved to labels_output_unet/115_M_E13_out_c2.nii.gz
# => Saved to labels_output_unet/115_M_E13_out_c3.nii.gz
# => Saved to labels_output_unet/116_F_K3_out_bg.nii.gz
# => Saved to labels_output_unet/116_F_K3_out_c1.nii.gz
# => Saved to labels_output_unet/116_F_K3_out_c2.nii.gz
# => Saved to labels_output_unet/116_F_K3_out_c3.nii.gz
# => Saved to labels_output_unet/117_F_K4_out_bg.nii.gz
# => Saved to labels_output_unet/117_F_K4_out_c1.nii.gz
# => Saved to labels_output_unet/117_F_K4_out_c2.nii.gz
# => Saved to labels_output_unet/117_F_K4_out_c3.nii.gz
# => Saved to labels_output_unet/120_M_B5_out_bg.nii.gz
# => Saved to labels_output_unet/120_M_B5_out_c1.nii.gz
# => Saved to labels_output_unet/120_M_B5_out_c2.nii.gz
# => Saved to labels_output_unet/120_M_B5_out_c3.nii.gz
# => Saved to labels_output_unet/123_F_K5_out_bg.nii.gz
# => Saved to labels_output_unet/123_F_K5_out_c1.nii.gz
# => Saved to labels_output_unet/123_F_K5_out_c2.nii.gz
# => Saved to labels_output_unet/123_F_K5_out_c3.nii.gz
# => Saved to labels_output_unet/124_F_L6_out_bg.nii.gz
# => Saved to labels_output_unet/124_F_L6_out_c1.nii.gz
# => Saved to labels_output_unet/124_F_L6_out_c2.nii.gz
# => Saved to labels_output_unet/124_F_L6_out_c3.nii.gz
# => Saved to labels_output_unet/130_M_C8_out_bg.nii.gz
# => Saved to labels_output_unet/130_M_C8_out_c1.nii.gz
# => Saved to labels_output_unet/130_M_C8_out_c2.nii.gz
# => Saved to labels_output_unet/130_M_C8_out_c3.nii.gz
# => Saved to labels_output_unet/131_M_D9_out_bg.nii.gz
# => Saved to labels_output_unet/131_M_D9_out_c1.nii.gz
# => Saved to labels_output_unet/131_M_D9_out_c2.nii.gz
# => Saved to labels_output_unet/131_M_D9_out_c3.nii.gz
# => Saved to labels_output_unet/132_M_I22_out_bg.nii.gz
# => Saved to labels_output_unet/132_M_I22_out_c1.nii.gz
# => Saved to labels_output_unet/132_M_I22_out_c2.nii.gz
# => Saved to labels_output_unet/132_M_I22_out_c3.nii.gz
# => Saved to labels_output_unet/135_F_L10_out_bg.nii.gz
# => Saved to labels_output_unet/135_F_L10_out_c1.nii.gz
# => Saved to labels_output_unet/135_F_L10_out_c2.nii.gz
# => Saved to labels_output_unet/135_F_L10_out_c3.nii.gz
# => Saved to labels_output_unet/136_F_L8_out_bg.nii.gz
# => Saved to labels_output_unet/136_F_L8_out_c1.nii.gz
# => Saved to labels_output_unet/136_F_L8_out_c2.nii.gz
# => Saved to labels_output_unet/136_F_L8_out_c3.nii.gz
# => Saved to labels_output_unet/141_M_D10_out_bg.nii.gz
# => Saved to labels_output_unet/141_M_D10_out_c1.nii.gz
# => Saved to labels_output_unet/141_M_D10_out_c2.nii.gz
# => Saved to labels_output_unet/141_M_D10_out_c3.nii.gz
# => Saved to labels_output_unet/142_M_C7_out_bg.nii.gz
# => Saved to labels_output_unet/142_M_C7_out_c1.nii.gz
# => Saved to labels_output_unet/142_M_C7_out_c2.nii.gz
# => Saved to labels_output_unet/142_M_C7_out_c3.nii.gz
# => Saved to labels_output_unet/145_F_L7_out_bg.nii.gz
# => Saved to labels_output_unet/145_F_L7_out_c1.nii.gz
# => Saved to labels_output_unet/145_F_L7_out_c2.nii.gz
# => Saved to labels_output_unet/145_F_L7_out_c3.nii.gz
# => Saved to labels_output_unet/146_F_L9_out_bg.nii.gz
# => Saved to labels_output_unet/146_F_L9_out_c1.nii.gz
# => Saved to labels_output_unet/146_F_L9_out_c2.nii.gz
# => Saved to labels_output_unet/146_F_L9_out_c3.nii.gz
# => Saved to labels_output_unet/150_M_F15_out_bg.nii.gz
# => Saved to labels_output_unet/150_M_F15_out_c1.nii.gz
# => Saved to labels_output_unet/150_M_F15_out_c2.nii.gz
# => Saved to labels_output_unet/150_M_F15_out_c3.nii.gz
# => Saved to labels_output_unet/151_F_M11_out_bg.nii.gz
# => Saved to labels_output_unet/151_F_M11_out_c1.nii.gz
# => Saved to labels_output_unet/151_F_M11_out_c2.nii.gz
# => Saved to labels_output_unet/151_F_M11_out_c3.nii.gz
# => Saved to labels_output_unet/152_F_M15_out_bg.nii.gz
# => Saved to labels_output_unet/152_F_M15_out_c1.nii.gz
# => Saved to labels_output_unet/152_F_M15_out_c2.nii.gz
# => Saved to labels_output_unet/152_F_M15_out_c3.nii.gz
# => Saved to labels_output_unet/159_M_G17_out_bg.nii.gz
# => Saved to labels_output_unet/159_M_G17_out_c1.nii.gz
# => Saved to labels_output_unet/159_M_G17_out_c2.nii.gz
# => Saved to labels_output_unet/159_M_G17_out_c3.nii.gz
# => Saved to labels_output_unet/160_F_M13_out_bg.nii.gz
# => Saved to labels_output_unet/160_F_M13_out_c1.nii.gz
# => Saved to labels_output_unet/160_F_M13_out_c2.nii.gz
# => Saved to labels_output_unet/160_F_M13_out_c3.nii.gz
# => Saved to labels_output_unet/161_F_M12_out_bg.nii.gz
# => Saved to labels_output_unet/161_F_M12_out_c1.nii.gz
# => Saved to labels_output_unet/161_F_M12_out_c2.nii.gz
# => Saved to labels_output_unet/161_F_M12_out_c3.nii.gz
# => Saved to labels_output_unet/162_M_G19_out_bg.nii.gz
# => Saved to labels_output_unet/162_M_G19_out_c1.nii.gz
# => Saved to labels_output_unet/162_M_G19_out_c2.nii.gz
# => Saved to labels_output_unet/162_M_G19_out_c3.nii.gz
# => Saved to labels_output_unet/163_M_G18_out_bg.nii.gz
# => Saved to labels_output_unet/163_M_G18_out_c1.nii.gz
# => Saved to labels_output_unet/163_M_G18_out_c2.nii.gz
# => Saved to labels_output_unet/163_M_G18_out_c3.nii.gz
# => Saved to labels_output_unet/164_M_J24_out_bg.nii.gz
# => Saved to labels_output_unet/164_M_J24_out_c1.nii.gz
# => Saved to labels_output_unet/164_M_J24_out_c2.nii.gz
# => Saved to labels_output_unet/164_M_J24_out_c3.nii.gz
# => Saved to labels_output_unet/170_F_N20_out_bg.nii.gz
# => Saved to labels_output_unet/170_F_N20_out_c1.nii.gz
# => Saved to labels_output_unet/170_F_N20_out_c2.nii.gz
# => Saved to labels_output_unet/170_F_N20_out_c3.nii.gz
# => Saved to labels_output_unet/177_F_N19_out_bg.nii.gz
# => Saved to labels_output_unet/177_F_N19_out_c1.nii.gz
# => Saved to labels_output_unet/177_F_N19_out_c2.nii.gz
# => Saved to labels_output_unet/177_F_N19_out_c3.nii.gz
# => Saved to labels_output_unet/178_F_N17_out_bg.nii.gz
# => Saved to labels_output_unet/178_F_N17_out_c1.nii.gz
# => Saved to labels_output_unet/178_F_N17_out_c2.nii.gz
# => Saved to labels_output_unet/178_F_N17_out_c3.nii.gz
# => Saved to labels_output_unet/185_F_N18_out_bg.nii.gz
# => Saved to labels_output_unet/185_F_N18_out_c1.nii.gz
# => Saved to labels_output_unet/185_F_N18_out_c2.nii.gz
# => Saved to labels_output_unet/185_F_N18_out_c3.nii.gz
# => Saved to labels_output_unet/186_F_N16_out_bg.nii.gz
# => Saved to labels_output_unet/186_F_N16_out_c1.nii.gz
# => Saved to labels_output_unet/186_F_N16_out_c2.nii.gz
# => Saved to labels_output_unet/186_F_N16_out_c3.nii.gz
# => Saved to labels_output_unet/187_M_H20_out_bg.nii.gz
# => Saved to labels_output_unet/187_M_H20_out_c1.nii.gz
# => Saved to labels_output_unet/187_M_H20_out_c2.nii.gz
# => Saved to labels_output_unet/187_M_H20_out_c3.nii.gz
# => Saved to labels_output_unet/189_M_J25_out_bg.nii.gz
# => Saved to labels_output_unet/189_M_J25_out_c1.nii.gz
# => Saved to labels_output_unet/189_M_J25_out_c2.nii.gz
# => Saved to labels_output_unet/189_M_J25_out_c3.nii.gz
# => Saved to labels_output_unet/195_F_O21_out_bg.nii.gz
# => Saved to labels_output_unet/195_F_O21_out_c1.nii.gz
# => Saved to labels_output_unet/195_F_O21_out_c2.nii.gz
# => Saved to labels_output_unet/195_F_O21_out_c3.nii.gz
# => Saved to labels_output_unet/196_F_O22_out_bg.nii.gz
# => Saved to labels_output_unet/196_F_O22_out_c1.nii.gz
# => Saved to labels_output_unet/196_F_O22_out_c2.nii.gz
# => Saved to labels_output_unet/196_F_O22_out_c3.nii.gz
# => Saved to labels_output_unet/197_M_E11_out_bg.nii.gz
# => Saved to labels_output_unet/197_M_E11_out_c1.nii.gz
# => Saved to labels_output_unet/197_M_E11_out_c2.nii.gz
# => Saved to labels_output_unet/197_M_E11_out_c3.nii.gz
# => Saved to labels_output_unet/198_M_E14_out_bg.nii.gz
# => Saved to labels_output_unet/198_M_E14_out_c1.nii.gz
# => Saved to labels_output_unet/198_M_E14_out_c2.nii.gz
# => Saved to labels_output_unet/198_M_E14_out_c3.nii.gz
# => Saved to labels_output_unet/199_M_E12_out_bg.nii.gz
# => Saved to labels_output_unet/199_M_E12_out_c1.nii.gz
# => Saved to labels_output_unet/199_M_E12_out_c2.nii.gz
# => Saved to labels_output_unet/199_M_E12_out_c3.nii.gz
# => Saved to labels_output_unet/201_F_O25_out_bg.nii.gz
# => Saved to labels_output_unet/201_F_O25_out_c1.nii.gz
# => Saved to labels_output_unet/201_F_O25_out_c2.nii.gz
# => Saved to labels_output_unet/201_F_O25_out_c3.nii.gz
# => Saved to labels_output_unet/202_F_O23_out_bg.nii.gz
# => Saved to labels_output_unet/202_F_O23_out_c1.nii.gz
# => Saved to labels_output_unet/202_F_O23_out_c2.nii.gz
# => Saved to labels_output_unet/202_F_O23_out_c3.nii.gz
# => Saved to labels_output_unet/203_F_O24_out_bg.nii.gz
# => Saved to labels_output_unet/203_F_O24_out_c1.nii.gz
# => Saved to labels_output_unet/203_F_O24_out_c2.nii.gz
# => Saved to labels_output_unet/203_F_O24_out_c3.nii.gz
# => Saved to labels_output_unet/207_M_P1_out_bg.nii.gz
# => Saved to labels_output_unet/207_M_P1_out_c1.nii.gz
# => Saved to labels_output_unet/207_M_P1_out_c2.nii.gz
# => Saved to labels_output_unet/207_M_P1_out_c3.nii.gz
# => Saved to labels_output_unet/208_M_Q4_out_bg.nii.gz
# => Saved to labels_output_unet/208_M_Q4_out_c1.nii.gz
# => Saved to labels_output_unet/208_M_Q4_out_c2.nii.gz
# => Saved to labels_output_unet/208_M_Q4_out_c3.nii.gz
# => Saved to labels_output_unet/209_M_P2_out_bg.nii.gz
# => Saved to labels_output_unet/209_M_P2_out_c1.nii.gz
# => Saved to labels_output_unet/209_M_P2_out_c2.nii.gz
# => Saved to labels_output_unet/209_M_P2_out_c3.nii.gz
# => Saved to labels_output_unet/213_F_AE16_out_bg.nii.gz
# => Saved to labels_output_unet/213_F_AE16_out_c1.nii.gz
# => Saved to labels_output_unet/213_F_AE16_out_c2.nii.gz
# => Saved to labels_output_unet/213_F_AE16_out_c3.nii.gz
# => Saved to labels_output_unet/214_F_AE17_out_bg.nii.gz
# => Saved to labels_output_unet/214_F_AE17_out_c1.nii.gz
# => Saved to labels_output_unet/214_F_AE17_out_c2.nii.gz
# => Saved to labels_output_unet/214_F_AE17_out_c3.nii.gz
# => Saved to labels_output_unet/215_F_AE18_out_bg.nii.gz
# => Saved to labels_output_unet/215_F_AE18_out_c1.nii.gz
# => Saved to labels_output_unet/215_F_AE18_out_c2.nii.gz
# => Saved to labels_output_unet/215_F_AE18_out_c3.nii.gz
# => Saved to labels_output_unet/216_F_AE19_out_bg.nii.gz
# => Saved to labels_output_unet/216_F_AE19_out_c1.nii.gz
# => Saved to labels_output_unet/216_F_AE19_out_c2.nii.gz
# => Saved to labels_output_unet/216_F_AE19_out_c3.nii.gz
# => Saved to labels_output_unet/220_M_P3_out_bg.nii.gz
# => Saved to labels_output_unet/220_M_P3_out_c1.nii.gz
# => Saved to labels_output_unet/220_M_P3_out_c2.nii.gz
# => Saved to labels_output_unet/220_M_P3_out_c3.nii.gz
# => Saved to labels_output_unet/221_M_Q5_out_bg.nii.gz
# => Saved to labels_output_unet/221_M_Q5_out_c1.nii.gz
# => Saved to labels_output_unet/221_M_Q5_out_c2.nii.gz
# => Saved to labels_output_unet/221_M_Q5_out_c3.nii.gz
# => Saved to labels_output_unet/223_M_AA23_out_bg.nii.gz
# => Saved to labels_output_unet/223_M_AA23_out_c1.nii.gz
# => Saved to labels_output_unet/223_M_AA23_out_c2.nii.gz
# => Saved to labels_output_unet/223_M_AA23_out_c3.nii.gz
# => Saved to labels_output_unet/226_F_AE20_out_bg.nii.gz
# => Saved to labels_output_unet/226_F_AE20_out_c1.nii.gz
# => Saved to labels_output_unet/226_F_AE20_out_c2.nii.gz
# => Saved to labels_output_unet/226_F_AE20_out_c3.nii.gz
# => Saved to labels_output_unet/227_F_AB1_out_bg.nii.gz
# => Saved to labels_output_unet/227_F_AB1_out_c1.nii.gz
# => Saved to labels_output_unet/227_F_AB1_out_c2.nii.gz
# => Saved to labels_output_unet/227_F_AB1_out_c3.nii.gz
# => Saved to labels_output_unet/231_M_AA24_out_bg.nii.gz
# => Saved to labels_output_unet/231_M_AA24_out_c1.nii.gz
# => Saved to labels_output_unet/231_M_AA24_out_c2.nii.gz
# => Saved to labels_output_unet/231_M_AA24_out_c3.nii.gz
# => Saved to labels_output_unet/234_F_AB2_out_bg.nii.gz
# => Saved to labels_output_unet/234_F_AB2_out_c1.nii.gz
# => Saved to labels_output_unet/234_F_AB2_out_c2.nii.gz
# => Saved to labels_output_unet/234_F_AB2_out_c3.nii.gz
# => Saved to labels_output_unet/235_F_AB3_out_bg.nii.gz
# => Saved to labels_output_unet/235_F_AB3_out_c1.nii.gz
# => Saved to labels_output_unet/235_F_AB3_out_c2.nii.gz
# => Saved to labels_output_unet/235_F_AB3_out_c3.nii.gz
# => Saved to labels_output_unet/236_F_AB4_out_bg.nii.gz
# => Saved to labels_output_unet/236_F_AB4_out_c1.nii.gz
# => Saved to labels_output_unet/236_F_AB4_out_c2.nii.gz
# => Saved to labels_output_unet/236_F_AB4_out_c3.nii.gz
# => Saved to labels_output_unet/237_F_AB5_out_bg.nii.gz
# => Saved to labels_output_unet/237_F_AB5_out_c1.nii.gz
# => Saved to labels_output_unet/237_F_AB5_out_c2.nii.gz
# => Saved to labels_output_unet/237_F_AB5_out_c3.nii.gz
# => Saved to labels_output_unet/239_M_R6_out_bg.nii.gz
# => Saved to labels_output_unet/239_M_R6_out_c1.nii.gz
# => Saved to labels_output_unet/239_M_R6_out_c2.nii.gz
# => Saved to labels_output_unet/239_M_R6_out_c3.nii.gz
# => Saved to labels_output_unet/240_M_R7_out_bg.nii.gz
# => Saved to labels_output_unet/240_M_R7_out_c1.nii.gz
# => Saved to labels_output_unet/240_M_R7_out_c2.nii.gz
# => Saved to labels_output_unet/240_M_R7_out_c3.nii.gz
# => Saved to labels_output_unet/241_F_AC6_out_bg.nii.gz
# => Saved to labels_output_unet/241_F_AC6_out_c1.nii.gz
# => Saved to labels_output_unet/241_F_AC6_out_c2.nii.gz
# => Saved to labels_output_unet/241_F_AC6_out_c3.nii.gz
# => Saved to labels_output_unet/242_F_AC7_out_bg.nii.gz
# => Saved to labels_output_unet/242_F_AC7_out_c1.nii.gz
# => Saved to labels_output_unet/242_F_AC7_out_c2.nii.gz
# => Saved to labels_output_unet/242_F_AC7_out_c3.nii.gz
# => Saved to labels_output_unet/243_F_AC8_out_bg.nii.gz
# => Saved to labels_output_unet/243_F_AC8_out_c1.nii.gz
# => Saved to labels_output_unet/243_F_AC8_out_c2.nii.gz
# => Saved to labels_output_unet/243_F_AC8_out_c3.nii.gz
# => Saved to labels_output_unet/244_M_R8_out_bg.nii.gz
# => Saved to labels_output_unet/244_M_R8_out_c1.nii.gz
# => Saved to labels_output_unet/244_M_R8_out_c2.nii.gz
# => Saved to labels_output_unet/244_M_R8_out_c3.nii.gz
# => Saved to labels_output_unet/246_M_S10_out_bg.nii.gz
# => Saved to labels_output_unet/246_M_S10_out_c1.nii.gz
# => Saved to labels_output_unet/246_M_S10_out_c2.nii.gz
# => Saved to labels_output_unet/246_M_S10_out_c3.nii.gz
# => Saved to labels_output_unet/247_M_Z22_out_bg.nii.gz
# => Saved to labels_output_unet/247_M_Z22_out_c1.nii.gz
# => Saved to labels_output_unet/247_M_Z22_out_c2.nii.gz
# => Saved to labels_output_unet/247_M_Z22_out_c3.nii.gz
# => Saved to labels_output_unet/250_F_AC9_out_bg.nii.gz
# => Saved to labels_output_unet/250_F_AC9_out_c1.nii.gz
# => Saved to labels_output_unet/250_F_AC9_out_c2.nii.gz
# => Saved to labels_output_unet/250_F_AC9_out_c3.nii.gz
# => Saved to labels_output_unet/251_F_AC10_out_bg.nii.gz
# => Saved to labels_output_unet/251_F_AC10_out_c1.nii.gz
# => Saved to labels_output_unet/251_F_AC10_out_c2.nii.gz
# => Saved to labels_output_unet/251_F_AC10_out_c3.nii.gz
# => Saved to labels_output_unet/252_M_T11_out_bg.nii.gz
# => Saved to labels_output_unet/252_M_T11_out_c1.nii.gz
# => Saved to labels_output_unet/252_M_T11_out_c2.nii.gz
# => Saved to labels_output_unet/252_M_T11_out_c3.nii.gz
# => Saved to labels_output_unet/253_M_T12_out_bg.nii.gz
# => Saved to labels_output_unet/253_M_T12_out_c1.nii.gz
# => Saved to labels_output_unet/253_M_T12_out_c2.nii.gz
# => Saved to labels_output_unet/253_M_T12_out_c3.nii.gz
# => Saved to labels_output_unet/254_M_U13_out_bg.nii.gz
# => Saved to labels_output_unet/254_M_U13_out_c1.nii.gz
# => Saved to labels_output_unet/254_M_U13_out_c2.nii.gz
# => Saved to labels_output_unet/254_M_U13_out_c3.nii.gz
# => Saved to labels_output_unet/257_F_AD11_out_bg.nii.gz
# => Saved to labels_output_unet/257_F_AD11_out_c1.nii.gz
# => Saved to labels_output_unet/257_F_AD11_out_c2.nii.gz
# => Saved to labels_output_unet/257_F_AD11_out_c3.nii.gz
# => Saved to labels_output_unet/258_F_AD12_out_bg.nii.gz
# => Saved to labels_output_unet/258_F_AD12_out_c1.nii.gz
# => Saved to labels_output_unet/258_F_AD12_out_c2.nii.gz
# => Saved to labels_output_unet/258_F_AD12_out_c3.nii.gz
# => Saved to labels_output_unet/259_F_AD1_out_bg.nii.gz
# => Saved to labels_output_unet/259_F_AD1_out_c1.nii.gz
# => Saved to labels_output_unet/259_F_AD1_out_c2.nii.gz
# => Saved to labels_output_unet/259_F_AD1_out_c3.nii.gz
# => Saved to labels_output_unet/263_F_AD14_out_bg.nii.gz
# => Saved to labels_output_unet/263_F_AD14_out_c1.nii.gz
# => Saved to labels_output_unet/263_F_AD14_out_c2.nii.gz
# => Saved to labels_output_unet/263_F_AD14_out_c3.nii.gz
# => Saved to labels_output_unet/265_M_U15_out_bg.nii.gz
# => Saved to labels_output_unet/265_M_U15_out_c1.nii.gz
# => Saved to labels_output_unet/265_M_U15_out_c2.nii.gz
# => Saved to labels_output_unet/265_M_U15_out_c3.nii.gz
# => Saved to labels_output_unet/266_M_W16_out_bg.nii.gz
# => Saved to labels_output_unet/266_M_W16_out_c1.nii.gz
# => Saved to labels_output_unet/266_M_W16_out_c2.nii.gz
# => Saved to labels_output_unet/266_M_W16_out_c3.nii.gz
# => Saved to labels_output_unet/269_F_AD15_out_bg.nii.gz
# => Saved to labels_output_unet/269_F_AD15_out_c1.nii.gz
# => Saved to labels_output_unet/269_F_AD15_out_c2.nii.gz
# => Saved to labels_output_unet/269_F_AD15_out_c3.nii.gz
# => Saved to labels_output_unet/270_F_AF21_out_bg.nii.gz
# => Saved to labels_output_unet/270_F_AF21_out_c1.nii.gz
# => Saved to labels_output_unet/270_F_AF21_out_c2.nii.gz
# => Saved to labels_output_unet/270_F_AF21_out_c3.nii.gz
# => Saved to labels_output_unet/271_F_AF22_out_bg.nii.gz
# => Saved to labels_output_unet/271_F_AF22_out_c1.nii.gz
# => Saved to labels_output_unet/271_F_AF22_out_c2.nii.gz
# => Saved to labels_output_unet/271_F_AF22_out_c3.nii.gz
# => Saved to labels_output_unet/274_M_X17_out_bg.nii.gz
# => Saved to labels_output_unet/274_M_X17_out_c1.nii.gz
# => Saved to labels_output_unet/274_M_X17_out_c2.nii.gz
# => Saved to labels_output_unet/274_M_X17_out_c3.nii.gz
# => Saved to labels_output_unet/275_M_Y20_out_bg.nii.gz
# => Saved to labels_output_unet/275_M_Y20_out_c1.nii.gz
# => Saved to labels_output_unet/275_M_Y20_out_c2.nii.gz
# => Saved to labels_output_unet/275_M_Y20_out_c3.nii.gz
# => Saved to labels_output_unet/276_M_Y19_out_bg.nii.gz
# => Saved to labels_output_unet/276_M_Y19_out_c1.nii.gz
# => Saved to labels_output_unet/276_M_Y19_out_c2.nii.gz
# => Saved to labels_output_unet/276_M_Y19_out_c3.nii.gz
# => Saved to labels_output_unet/277_M_X18_out_bg.nii.gz
# => Saved to labels_output_unet/277_M_X18_out_c1.nii.gz
# => Saved to labels_output_unet/277_M_X18_out_c2.nii.gz
# => Saved to labels_output_unet/277_M_X18_out_c3.nii.gz
# => Saved to labels_output_unet/280_F_AF23_out_bg.nii.gz
# => Saved to labels_output_unet/280_F_AF23_out_c1.nii.gz
# => Saved to labels_output_unet/280_F_AF23_out_c2.nii.gz
# => Saved to labels_output_unet/280_F_AF23_out_c3.nii.gz
# => Saved to labels_output_unet/281_F_AF24_out_bg.nii.gz
# => Saved to labels_output_unet/281_F_AF24_out_c1.nii.gz
# => Saved to labels_output_unet/281_F_AF24_out_c2.nii.gz
# => Saved to labels_output_unet/281_F_AF24_out_c3.nii.gz
# => Saved to labels_output_unet/282_F_AF25_out_bg.nii.gz
# => Saved to labels_output_unet/282_F_AF25_out_c1.nii.gz
# => Saved to labels_output_unet/282_F_AF25_out_c2.nii.gz
# => Saved to labels_output_unet/282_F_AF25_out_c3.nii.gz
# => Saved to labels_output_unet/284_M_AK11_out_bg.nii.gz
# => Saved to labels_output_unet/284_M_AK11_out_c1.nii.gz
# => Saved to labels_output_unet/284_M_AK11_out_c2.nii.gz
# => Saved to labels_output_unet/284_M_AK11_out_c3.nii.gz
# => Saved to labels_output_unet/285_M_AK12_out_bg.nii.gz
# => Saved to labels_output_unet/285_M_AK12_out_c1.nii.gz
# => Saved to labels_output_unet/285_M_AK12_out_c2.nii.gz
# => Saved to labels_output_unet/285_M_AK12_out_c3.nii.gz
# => Saved to labels_output_unet/287_F_AR6_out_bg.nii.gz
# => Saved to labels_output_unet/287_F_AR6_out_c1.nii.gz
# => Saved to labels_output_unet/287_F_AR6_out_c2.nii.gz
# => Saved to labels_output_unet/287_F_AR6_out_c3.nii.gz
# => Saved to labels_output_unet/289_F_AQ_out_bg.nii.gz
# => Saved to labels_output_unet/289_F_AQ_out_c1.nii.gz
# => Saved to labels_output_unet/289_F_AQ_out_c2.nii.gz
# => Saved to labels_output_unet/289_F_AQ_out_c3.nii.gz
# => Saved to labels_output_unet/295_M_AI17_out_bg.nii.gz
# => Saved to labels_output_unet/295_M_AI17_out_c1.nii.gz
# => Saved to labels_output_unet/295_M_AI17_out_c2.nii.gz
# => Saved to labels_output_unet/295_M_AI17_out_c3.nii.gz
# => Saved to labels_output_unet/296_M_AI18_out_bg.nii.gz
# => Saved to labels_output_unet/296_M_AI18_out_c1.nii.gz
# => Saved to labels_output_unet/296_M_AI18_out_c2.nii.gz
# => Saved to labels_output_unet/296_M_AI18_out_c3.nii.gz
# => Saved to labels_output_unet/297_M_AK13_out_bg.nii.gz
# => Saved to labels_output_unet/297_M_AK13_out_c1.nii.gz
# => Saved to labels_output_unet/297_M_AK13_out_c2.nii.gz
# => Saved to labels_output_unet/297_M_AK13_out_c3.nii.gz
# => Saved to labels_output_unet/301_F_AR7_out_bg.nii.gz
# => Saved to labels_output_unet/301_F_AR7_out_c1.nii.gz
# => Saved to labels_output_unet/301_F_AR7_out_c2.nii.gz
# => Saved to labels_output_unet/301_F_AR7_out_c3.nii.gz
# => Saved to labels_output_unet/304_F_AQ2_out_bg.nii.gz
# => Saved to labels_output_unet/304_F_AQ2_out_c1.nii.gz
# => Saved to labels_output_unet/304_F_AQ2_out_c2.nii.gz
# => Saved to labels_output_unet/304_F_AQ2_out_c3.nii.gz
# => Saved to labels_output_unet/306_M_AJ9_out_bg.nii.gz
# => Saved to labels_output_unet/306_M_AJ9_out_c1.nii.gz
# => Saved to labels_output_unet/306_M_AJ9_out_c2.nii.gz
# => Saved to labels_output_unet/306_M_AJ9_out_c3.nii.gz
# => Saved to labels_output_unet/307_M_AL14_out_bg.nii.gz
# => Saved to labels_output_unet/307_M_AL14_out_c1.nii.gz
# => Saved to labels_output_unet/307_M_AL14_out_c2.nii.gz
# => Saved to labels_output_unet/307_M_AL14_out_c3.nii.gz
# => Saved to labels_output_unet/310_F_AR8_out_bg.nii.gz
# => Saved to labels_output_unet/310_F_AR8_out_c1.nii.gz
# => Saved to labels_output_unet/310_F_AR8_out_c2.nii.gz
# => Saved to labels_output_unet/310_F_AR8_out_c3.nii.gz
# => Saved to labels_output_unet/312_F_AQ3_out_bg.nii.gz
# => Saved to labels_output_unet/312_F_AQ3_out_c1.nii.gz
# => Saved to labels_output_unet/312_F_AQ3_out_c2.nii.gz
# => Saved to labels_output_unet/312_F_AQ3_out_c3.nii.gz
# => Saved to labels_output_unet/316_M_AJ9_out_bg.nii.gz
# => Saved to labels_output_unet/316_M_AJ9_out_c1.nii.gz
# => Saved to labels_output_unet/316_M_AJ9_out_c2.nii.gz
# => Saved to labels_output_unet/316_M_AJ9_out_c3.nii.gz
# => Saved to labels_output_unet/317_M_AL15_out_bg.nii.gz
# => Saved to labels_output_unet/317_M_AL15_out_c1.nii.gz
# => Saved to labels_output_unet/317_M_AL15_out_c2.nii.gz
# => Saved to labels_output_unet/317_M_AL15_out_c3.nii.gz
# => Saved to labels_output_unet/318_F_AR9_out_bg.nii.gz
# => Saved to labels_output_unet/318_F_AR9_out_c1.nii.gz
# => Saved to labels_output_unet/318_F_AR9_out_c2.nii.gz
# => Saved to labels_output_unet/318_F_AR9_out_c3.nii.gz
# => Saved to labels_output_unet/322_F_AQ5_out_bg.nii.gz
# => Saved to labels_output_unet/322_F_AQ5_out_c1.nii.gz
# => Saved to labels_output_unet/322_F_AQ5_out_c2.nii.gz
# => Saved to labels_output_unet/322_F_AQ5_out_c3.nii.gz
# => Saved to labels_output_unet/324_M_AM16_out_bg.nii.gz
# => Saved to labels_output_unet/324_M_AM16_out_c1.nii.gz
# => Saved to labels_output_unet/324_M_AM16_out_c2.nii.gz
# => Saved to labels_output_unet/324_M_AM16_out_c3.nii.gz
# => Saved to labels_output_unet/326_M_AO21_out_bg.nii.gz
# => Saved to labels_output_unet/326_M_AO21_out_c1.nii.gz
# => Saved to labels_output_unet/326_M_AO21_out_c2.nii.gz
# => Saved to labels_output_unet/326_M_AO21_out_c3.nii.gz
# => Saved to labels_output_unet/328_F_AT16_out_bg.nii.gz
# => Saved to labels_output_unet/328_F_AT16_out_c1.nii.gz
# => Saved to labels_output_unet/328_F_AT16_out_c2.nii.gz
# => Saved to labels_output_unet/328_F_AT16_out_c3.nii.gz
# => Saved to labels_output_unet/329_F_AS11_out_bg.nii.gz
# => Saved to labels_output_unet/329_F_AS11_out_c1.nii.gz
# => Saved to labels_output_unet/329_F_AS11_out_c2.nii.gz
# => Saved to labels_output_unet/329_F_AS11_out_c3.nii.gz
# => Saved to labels_output_unet/333_M_AN18_out_bg.nii.gz
# => Saved to labels_output_unet/333_M_AN18_out_c1.nii.gz
# => Saved to labels_output_unet/333_M_AN18_out_c2.nii.gz
# => Saved to labels_output_unet/333_M_AN18_out_c3.nii.gz
# => Saved to labels_output_unet/335_F_AT17_out_bg.nii.gz
# => Saved to labels_output_unet/335_F_AT17_out_c1.nii.gz
# => Saved to labels_output_unet/335_F_AT17_out_c2.nii.gz
# => Saved to labels_output_unet/335_F_AT17_out_c3.nii.gz
# => Saved to labels_output_unet/336_F_AS12_out_bg.nii.gz
# => Saved to labels_output_unet/336_F_AS12_out_c1.nii.gz
# => Saved to labels_output_unet/336_F_AS12_out_c2.nii.gz
# => Saved to labels_output_unet/336_F_AS12_out_c3.nii.gz
# => Saved to labels_output_unet/340_M_AN19_out_bg.nii.gz
# => Saved to labels_output_unet/340_M_AN19_out_c1.nii.gz
# => Saved to labels_output_unet/340_M_AN19_out_c2.nii.gz
# => Saved to labels_output_unet/340_M_AN19_out_c3.nii.gz
# => Saved to labels_output_unet/342_M_AO22_out_bg.nii.gz
# => Saved to labels_output_unet/342_M_AO22_out_c1.nii.gz
# => Saved to labels_output_unet/342_M_AO22_out_c2.nii.gz
# => Saved to labels_output_unet/342_M_AO22_out_c3.nii.gz
# => Saved to labels_output_unet/344_M_AG2_out_bg.nii.gz
# => Saved to labels_output_unet/344_M_AG2_out_c1.nii.gz
# => Saved to labels_output_unet/344_M_AG2_out_c2.nii.gz
# => Saved to labels_output_unet/344_M_AG2_out_c3.nii.gz
# => Saved to labels_output_unet/350_F_AT18_out_bg.nii.gz
# => Saved to labels_output_unet/350_F_AT18_out_c1.nii.gz
# => Saved to labels_output_unet/350_F_AT18_out_c2.nii.gz
# => Saved to labels_output_unet/350_F_AT18_out_c3.nii.gz
# => Saved to labels_output_unet/351_F_AU21_out_bg.nii.gz
# => Saved to labels_output_unet/351_F_AU21_out_c1.nii.gz
# => Saved to labels_output_unet/351_F_AU21_out_c2.nii.gz
# => Saved to labels_output_unet/351_F_AU21_out_c3.nii.gz
# => Saved to labels_output_unet/353_M_AN20_out_bg.nii.gz
# => Saved to labels_output_unet/353_M_AN20_out_c1.nii.gz
# => Saved to labels_output_unet/353_M_AN20_out_c2.nii.gz
# => Saved to labels_output_unet/353_M_AN20_out_c3.nii.gz
# => Saved to labels_output_unet/355_M_AP24_out_bg.nii.gz
# => Saved to labels_output_unet/355_M_AP24_out_c1.nii.gz
# => Saved to labels_output_unet/355_M_AP24_out_c2.nii.gz
# => Saved to labels_output_unet/355_M_AP24_out_c3.nii.gz
# => Saved to labels_output_unet/359_F_AT19_out_bg.nii.gz
# => Saved to labels_output_unet/359_F_AT19_out_c1.nii.gz
# => Saved to labels_output_unet/359_F_AT19_out_c2.nii.gz
# => Saved to labels_output_unet/359_F_AT19_out_c3.nii.gz
# => Saved to labels_output_unet/360_F_AU22_out_bg.nii.gz
# => Saved to labels_output_unet/360_F_AU22_out_c1.nii.gz
# => Saved to labels_output_unet/360_F_AU22_out_c2.nii.gz
# => Saved to labels_output_unet/360_F_AU22_out_c3.nii.gz
# => Saved to labels_output_unet/368_M_AM17_out_bg.nii.gz
# => Saved to labels_output_unet/368_M_AM17_out_c1.nii.gz
# => Saved to labels_output_unet/368_M_AM17_out_c2.nii.gz
# => Saved to labels_output_unet/368_M_AM17_out_c3.nii.gz
# => Saved to labels_output_unet/370_F_AT20_out_bg.nii.gz
# => Saved to labels_output_unet/370_F_AT20_out_c1.nii.gz
# => Saved to labels_output_unet/370_F_AT20_out_c2.nii.gz
# => Saved to labels_output_unet/370_F_AT20_out_c3.nii.gz
# => Saved to labels_output_unet/371_F_AU23_out_bg.nii.gz
# => Saved to labels_output_unet/371_F_AU23_out_c1.nii.gz
# => Saved to labels_output_unet/371_F_AU23_out_c2.nii.gz
# => Saved to labels_output_unet/371_F_AU23_out_c3.nii.gz
# => Saved to labels_output_unet/373_F_AS14_out_bg.nii.gz
# => Saved to labels_output_unet/373_F_AS14_out_c1.nii.gz
# => Saved to labels_output_unet/373_F_AS14_out_c2.nii.gz
# => Saved to labels_output_unet/373_F_AS14_out_c3.nii.gz
# => Saved to labels_output_unet/378_M_AH5_out_bg.nii.gz
# => Saved to labels_output_unet/378_M_AH5_out_c1.nii.gz
# => Saved to labels_output_unet/378_M_AH5_out_c2.nii.gz
# => Saved to labels_output_unet/378_M_AH5_out_c3.nii.gz
# => Saved to labels_output_unet/379_M_AG2_out_bg.nii.gz
# => Saved to labels_output_unet/379_M_AG2_out_c1.nii.gz
# => Saved to labels_output_unet/379_M_AG2_out_c2.nii.gz
# => Saved to labels_output_unet/379_M_AG2_out_c3.nii.gz
# => Saved to labels_output_unet/380_F_AU24_out_bg.nii.gz
# => Saved to labels_output_unet/380_F_AU24_out_c1.nii.gz
# => Saved to labels_output_unet/380_F_AU24_out_c2.nii.gz
# => Saved to labels_output_unet/380_F_AU24_out_c3.nii.gz
# => Saved to labels_output_unet/387_M_AG3_out_bg.nii.gz
# => Saved to labels_output_unet/387_M_AG3_out_c1.nii.gz
# => Saved to labels_output_unet/387_M_AG3_out_c2.nii.gz
# => Saved to labels_output_unet/387_M_AG3_out_c3.nii.gz
# => Saved to labels_output_unet/392_F_AU25_out_bg.nii.gz
# => Saved to labels_output_unet/392_F_AU25_out_c1.nii.gz
# => Saved to labels_output_unet/392_F_AU25_out_c2.nii.gz
# => Saved to labels_output_unet/392_F_AU25_out_c3.nii.gz
# => Saved to labels_output_unet/400_M_AX6_out_bg.nii.gz
# => Saved to labels_output_unet/400_M_AX6_out_c1.nii.gz
# => Saved to labels_output_unet/400_M_AX6_out_c2.nii.gz
# => Saved to labels_output_unet/400_M_AX6_out_c3.nii.gz
# => Saved to labels_output_unet/402_F_BI16_out_bg.nii.gz
# => Saved to labels_output_unet/402_F_BI16_out_c1.nii.gz
# => Saved to labels_output_unet/402_F_BI16_out_c2.nii.gz
# => Saved to labels_output_unet/402_F_BI16_out_c3.nii.gz
# => Saved to labels_output_unet/403_F_BJ21_out_bg.nii.gz
# => Saved to labels_output_unet/403_F_BJ21_out_c1.nii.gz
# => Saved to labels_output_unet/403_F_BJ21_out_c2.nii.gz
# => Saved to labels_output_unet/403_F_BJ21_out_c3.nii.gz
# => Saved to labels_output_unet/405_F_BH11_out_bg.nii.gz
# => Saved to labels_output_unet/405_F_BH11_out_c1.nii.gz
# => Saved to labels_output_unet/405_F_BH11_out_c2.nii.gz
# => Saved to labels_output_unet/405_F_BH11_out_c3.nii.gz
# => Saved to labels_output_unet/407_M_AV2_out_bg.nii.gz
# => Saved to labels_output_unet/407_M_AV2_out_c1.nii.gz
# => Saved to labels_output_unet/407_M_AV2_out_c2.nii.gz
# => Saved to labels_output_unet/407_M_AV2_out_c3.nii.gz
# => Saved to labels_output_unet/409_M_AZ12_out_bg.nii.gz
# => Saved to labels_output_unet/409_M_AZ12_out_c1.nii.gz
# => Saved to labels_output_unet/409_M_AZ12_out_c2.nii.gz
# => Saved to labels_output_unet/409_M_AZ12_out_c3.nii.gz
# => Saved to labels_output_unet/410_M_AX7_out_bg.nii.gz
# => Saved to labels_output_unet/410_M_AX7_out_c1.nii.gz
# => Saved to labels_output_unet/410_M_AX7_out_c2.nii.gz
# => Saved to labels_output_unet/410_M_AX7_out_c3.nii.gz
# => Saved to labels_output_unet/412_F_BI17_out_bg.nii.gz
# => Saved to labels_output_unet/412_F_BI17_out_c1.nii.gz
# => Saved to labels_output_unet/412_F_BI17_out_c2.nii.gz
# => Saved to labels_output_unet/412_F_BI17_out_c3.nii.gz
# => Saved to labels_output_unet/413_F_BJ22_out_bg.nii.gz
# => Saved to labels_output_unet/413_F_BJ22_out_c1.nii.gz
# => Saved to labels_output_unet/413_F_BJ22_out_c2.nii.gz
# => Saved to labels_output_unet/413_F_BJ22_out_c3.nii.gz
# => Saved to labels_output_unet/416_F_BH12_out_bg.nii.gz
# => Saved to labels_output_unet/416_F_BH12_out_c1.nii.gz
# => Saved to labels_output_unet/416_F_BH12_out_c2.nii.gz
# => Saved to labels_output_unet/416_F_BH12_out_c3.nii.gz
# => Saved to labels_output_unet/418_M_AW4_out_bg.nii.gz
# => Saved to labels_output_unet/418_M_AW4_out_c1.nii.gz
# => Saved to labels_output_unet/418_M_AW4_out_c2.nii.gz
# => Saved to labels_output_unet/418_M_AW4_out_c3.nii.gz
# => Saved to labels_output_unet/419_M_AZ12_out_bg.nii.gz
# => Saved to labels_output_unet/419_M_AZ12_out_c1.nii.gz
# => Saved to labels_output_unet/419_M_AZ12_out_c2.nii.gz
# => Saved to labels_output_unet/419_M_AZ12_out_c3.nii.gz
# => Saved to labels_output_unet/420_M_AX8_out_bg.nii.gz
# => Saved to labels_output_unet/420_M_AX8_out_c1.nii.gz
# => Saved to labels_output_unet/420_M_AX8_out_c2.nii.gz
# => Saved to labels_output_unet/420_M_AX8_out_c3.nii.gz
# => Saved to labels_output_unet/421_F_BI18_out_bg.nii.gz
# => Saved to labels_output_unet/421_F_BI18_out_c1.nii.gz
# => Saved to labels_output_unet/421_F_BI18_out_c2.nii.gz
# => Saved to labels_output_unet/421_F_BI18_out_c3.nii.gz
# => Saved to labels_output_unet/424_F_BF1_out_bg.nii.gz
# => Saved to labels_output_unet/424_F_BF1_out_c1.nii.gz
# => Saved to labels_output_unet/424_F_BF1_out_c2.nii.gz
# => Saved to labels_output_unet/424_F_BF1_out_c3.nii.gz
# => Saved to labels_output_unet/425_M_AV3_out_bg.nii.gz
# => Saved to labels_output_unet/425_M_AV3_out_c1.nii.gz
# => Saved to labels_output_unet/425_M_AV3_out_c2.nii.gz
# => Saved to labels_output_unet/425_M_AV3_out_c3.nii.gz
# => Saved to labels_output_unet/426_M_BA13_out_bg.nii.gz
# => Saved to labels_output_unet/426_M_BA13_out_c1.nii.gz
# => Saved to labels_output_unet/426_M_BA13_out_c2.nii.gz
# => Saved to labels_output_unet/426_M_BA13_out_c3.nii.gz
# => Saved to labels_output_unet/429_M_BB16_out_bg.nii.gz
# => Saved to labels_output_unet/429_M_BB16_out_c1.nii.gz
# => Saved to labels_output_unet/429_M_BB16_out_c2.nii.gz
# => Saved to labels_output_unet/429_M_BB16_out_c3.nii.gz
# => Saved to labels_output_unet/430_F_BI19_out_bg.nii.gz
# => Saved to labels_output_unet/430_F_BI19_out_c1.nii.gz
# => Saved to labels_output_unet/430_F_BI19_out_c2.nii.gz
# => Saved to labels_output_unet/430_F_BI19_out_c3.nii.gz
# => Saved to labels_output_unet/433_F_BF2_out_bg.nii.gz
# => Saved to labels_output_unet/433_F_BF2_out_c1.nii.gz
# => Saved to labels_output_unet/433_F_BF2_out_c2.nii.gz
# => Saved to labels_output_unet/433_F_BF2_out_c3.nii.gz
# => Saved to labels_output_unet/435_M_BD21_out_bg.nii.gz
# => Saved to labels_output_unet/435_M_BD21_out_c1.nii.gz
# => Saved to labels_output_unet/435_M_BD21_out_c2.nii.gz
# => Saved to labels_output_unet/435_M_BD21_out_c3.nii.gz
# => Saved to labels_output_unet/436_M_BA14_out_bg.nii.gz
# => Saved to labels_output_unet/436_M_BA14_out_c1.nii.gz
# => Saved to labels_output_unet/436_M_BA14_out_c2.nii.gz
# => Saved to labels_output_unet/436_M_BA14_out_c3.nii.gz
# => Saved to labels_output_unet/438_M_BC19_out_bg.nii.gz
# => Saved to labels_output_unet/438_M_BC19_out_c1.nii.gz
# => Saved to labels_output_unet/438_M_BC19_out_c2.nii.gz
# => Saved to labels_output_unet/438_M_BC19_out_c3.nii.gz
# => Saved to labels_output_unet/442_F_BI20_out_bg.nii.gz
# => Saved to labels_output_unet/442_F_BI20_out_c1.nii.gz
# => Saved to labels_output_unet/442_F_BI20_out_c2.nii.gz
# => Saved to labels_output_unet/442_F_BI20_out_c3.nii.gz
# => Saved to labels_output_unet/443_F_BG6_out_bg.nii.gz
# => Saved to labels_output_unet/443_F_BG6_out_c1.nii.gz
# => Saved to labels_output_unet/443_F_BG6_out_c2.nii.gz
# => Saved to labels_output_unet/443_F_BG6_out_c3.nii.gz
# => Saved to labels_output_unet/445_M_BD22_out_bg.nii.gz
# => Saved to labels_output_unet/445_M_BD22_out_c1.nii.gz
# => Saved to labels_output_unet/445_M_BD22_out_c2.nii.gz
# => Saved to labels_output_unet/445_M_BD22_out_c3.nii.gz
# => Saved to labels_output_unet/446_M_BA15_out_bg.nii.gz
# => Saved to labels_output_unet/446_M_BA15_out_c1.nii.gz
# => Saved to labels_output_unet/446_M_BA15_out_c2.nii.gz
# => Saved to labels_output_unet/446_M_BA15_out_c3.nii.gz
# => Saved to labels_output_unet/452_F_BG7_out_bg.nii.gz
# => Saved to labels_output_unet/452_F_BG7_out_c1.nii.gz
# => Saved to labels_output_unet/452_F_BG7_out_c2.nii.gz
# => Saved to labels_output_unet/452_F_BG7_out_c3.nii.gz
# => Saved to labels_output_unet/456_F_BF3_out_bg.nii.gz
# => Saved to labels_output_unet/456_F_BF3_out_c1.nii.gz
# => Saved to labels_output_unet/456_F_BF3_out_c2.nii.gz
# => Saved to labels_output_unet/456_F_BF3_out_c3.nii.gz
# => Saved to labels_output_unet/458_M_BE24_out_bg.nii.gz
# => Saved to labels_output_unet/458_M_BE24_out_c1.nii.gz
# => Saved to labels_output_unet/458_M_BE24_out_c2.nii.gz
# => Saved to labels_output_unet/458_M_BE24_out_c3.nii.gz
# => Saved to labels_output_unet/461_M_BB18_out_bg.nii.gz
# => Saved to labels_output_unet/461_M_BB18_out_c1.nii.gz
# => Saved to labels_output_unet/461_M_BB18_out_c2.nii.gz
# => Saved to labels_output_unet/461_M_BB18_out_c3.nii.gz
# => Saved to labels_output_unet/463_f_BG8_out_bg.nii.gz
# => Saved to labels_output_unet/463_f_BG8_out_c1.nii.gz
# => Saved to labels_output_unet/463_f_BG8_out_c2.nii.gz
# => Saved to labels_output_unet/463_f_BG8_out_c3.nii.gz
# => Saved to labels_output_unet/466_F_BH16_out_bg.nii.gz
# => Saved to labels_output_unet/466_F_BH16_out_c1.nii.gz
# => Saved to labels_output_unet/466_F_BH16_out_c2.nii.gz
# => Saved to labels_output_unet/466_F_BH16_out_c3.nii.gz
# => Saved to labels_output_unet/468_M_BE25_out_bg.nii.gz
# => Saved to labels_output_unet/468_M_BE25_out_c1.nii.gz
# => Saved to labels_output_unet/468_M_BE25_out_c2.nii.gz
# => Saved to labels_output_unet/468_M_BE25_out_c3.nii.gz
# => Saved to labels_output_unet/470_F_BG9_out_bg.nii.gz
# => Saved to labels_output_unet/470_F_BG9_out_c1.nii.gz
# => Saved to labels_output_unet/470_F_BG9_out_c2.nii.gz
# => Saved to labels_output_unet/470_F_BG9_out_c3.nii.gz
# => Saved to labels_output_unet/473_M_BD23_out_bg.nii.gz
# => Saved to labels_output_unet/473_M_BD23_out_c1.nii.gz
# => Saved to labels_output_unet/473_M_BD23_out_c2.nii.gz
# => Saved to labels_output_unet/473_M_BD23_out_c3.nii.gz
# => Saved to labels_output_unet/478_F_BG10_out_bg.nii.gz
# => Saved to labels_output_unet/478_F_BG10_out_c1.nii.gz
# => Saved to labels_output_unet/478_F_BG10_out_c2.nii.gz
# => Saved to labels_output_unet/478_F_BG10_out_c3.nii.gz
# => Saved to labels_output_unet/479_F_BJ23_out_bg.nii.gz
# => Saved to labels_output_unet/479_F_BJ23_out_c1.nii.gz
# => Saved to labels_output_unet/479_F_BJ23_out_c2.nii.gz
# => Saved to labels_output_unet/479_F_BJ23_out_c3.nii.gz
# => Saved to labels_output_unet/483_M_AY9_out_bg.nii.gz
# => Saved to labels_output_unet/483_M_AY9_out_c1.nii.gz
# => Saved to labels_output_unet/483_M_AY9_out_c2.nii.gz
# => Saved to labels_output_unet/483_M_AY9_out_c3.nii.gz
# => Saved to labels_output_unet/485_F_BJ24_out_bg.nii.gz
# => Saved to labels_output_unet/485_F_BJ24_out_c1.nii.gz
# => Saved to labels_output_unet/485_F_BJ24_out_c2.nii.gz
# => Saved to labels_output_unet/485_F_BJ24_out_c3.nii.gz
# => Saved to labels_output_unet/488_F_BF4_out_bg.nii.gz
# => Saved to labels_output_unet/488_F_BF4_out_c1.nii.gz
# => Saved to labels_output_unet/488_F_BF4_out_c2.nii.gz
# => Saved to labels_output_unet/488_F_BF4_out_c3.nii.gz
# => Saved to labels_output_unet/489_F_BH14_out_bg.nii.gz
# => Saved to labels_output_unet/489_F_BH14_out_c1.nii.gz
# => Saved to labels_output_unet/489_F_BH14_out_c2.nii.gz
# => Saved to labels_output_unet/489_F_BH14_out_c3.nii.gz
# => Saved to labels_output_unet/494_M_AY10_out_bg.nii.gz
# => Saved to labels_output_unet/494_M_AY10_out_c1.nii.gz
# => Saved to labels_output_unet/494_M_AY10_out_c2.nii.gz
# => Saved to labels_output_unet/494_M_AY10_out_c3.nii.gz
# => Saved to labels_output_unet/496_M_BC20_out_bg.nii.gz
# => Saved to labels_output_unet/496_M_BC20_out_c1.nii.gz
# => Saved to labels_output_unet/496_M_BC20_out_c2.nii.gz
# => Saved to labels_output_unet/496_M_BC20_out_c3.nii.gz
# => Saved to labels_output_unet/498_F_BJ25_out_bg.nii.gz
# => Saved to labels_output_unet/498_F_BJ25_out_c1.nii.gz
# => Saved to labels_output_unet/498_F_BJ25_out_c2.nii.gz
# => Saved to labels_output_unet/498_F_BJ25_out_c3.nii.gz
# => Saved to labels_output_unet/501_F_BF5_out_bg.nii.gz
# => Saved to labels_output_unet/501_F_BF5_out_c1.nii.gz
# => Saved to labels_output_unet/501_F_BF5_out_c2.nii.gz
# => Saved to labels_output_unet/501_F_BF5_out_c3.nii.gz
# => Saved to labels_output_unet/505_M_BK1_out_bg.nii.gz
# => Saved to labels_output_unet/505_M_BK1_out_c1.nii.gz
# => Saved to labels_output_unet/505_M_BK1_out_c2.nii.gz
# => Saved to labels_output_unet/505_M_BK1_out_c3.nii.gz
# => Saved to labels_output_unet/507_M_BQ16_out_bg.nii.gz
# => Saved to labels_output_unet/507_M_BQ16_out_c1.nii.gz
# => Saved to labels_output_unet/507_M_BQ16_out_c2.nii.gz
# => Saved to labels_output_unet/507_M_BQ16_out_c3.nii.gz
# => Saved to labels_output_unet/508_M_BS21_out_bg.nii.gz
# => Saved to labels_output_unet/508_M_BS21_out_c1.nii.gz
# => Saved to labels_output_unet/508_M_BS21_out_c2.nii.gz
# => Saved to labels_output_unet/508_M_BS21_out_c3.nii.gz
# => Saved to labels_output_unet/511_F_BU1_out_bg.nii.gz
# => Saved to labels_output_unet/511_F_BU1_out_c1.nii.gz
# => Saved to labels_output_unet/511_F_BU1_out_c2.nii.gz
# => Saved to labels_output_unet/511_F_BU1_out_c3.nii.gz
# => Saved to labels_output_unet/513_M_BK2_out_bg.nii.gz
# => Saved to labels_output_unet/513_M_BK2_out_c1.nii.gz
# => Saved to labels_output_unet/513_M_BK2_out_c2.nii.gz
# => Saved to labels_output_unet/513_M_BK2_out_c3.nii.gz
# => Saved to labels_output_unet/514_F_BW11_out_bg.nii.gz
# => Saved to labels_output_unet/514_F_BW11_out_c1.nii.gz
# => Saved to labels_output_unet/514_F_BW11_out_c2.nii.gz
# => Saved to labels_output_unet/514_F_BW11_out_c3.nii.gz
# => Saved to labels_output_unet/516_M_BS22_out_bg.nii.gz
# => Saved to labels_output_unet/516_M_BS22_out_c1.nii.gz
# => Saved to labels_output_unet/516_M_BS22_out_c2.nii.gz
# => Saved to labels_output_unet/516_M_BS22_out_c3.nii.gz
# => Saved to labels_output_unet/518_F_BU2_out_bg.nii.gz
# => Saved to labels_output_unet/518_F_BU2_out_c1.nii.gz
# => Saved to labels_output_unet/518_F_BU2_out_c2.nii.gz
# => Saved to labels_output_unet/518_F_BU2_out_c3.nii.gz
# => Saved to labels_output_unet/521_M_BK3_out_bg.nii.gz
# => Saved to labels_output_unet/521_M_BK3_out_c1.nii.gz
# => Saved to labels_output_unet/521_M_BK3_out_c2.nii.gz
# => Saved to labels_output_unet/521_M_BK3_out_c3.nii.gz
# => Saved to labels_output_unet/523_M_BO11_out_bg.nii.gz
# => Saved to labels_output_unet/523_M_BO11_out_c1.nii.gz
# => Saved to labels_output_unet/523_M_BO11_out_c2.nii.gz
# => Saved to labels_output_unet/523_M_BO11_out_c3.nii.gz
# => Saved to labels_output_unet/525_F_BX16_out_bg.nii.gz
# => Saved to labels_output_unet/525_F_BX16_out_c1.nii.gz
# => Saved to labels_output_unet/525_F_BX16_out_c2.nii.gz
# => Saved to labels_output_unet/525_F_BX16_out_c3.nii.gz
# => Saved to labels_output_unet/528_F_BW12_out_bg.nii.gz
# => Saved to labels_output_unet/528_F_BW12_out_c1.nii.gz
# => Saved to labels_output_unet/528_F_BW12_out_c2.nii.gz
# => Saved to labels_output_unet/528_F_BW12_out_c3.nii.gz
# => Saved to labels_output_unet/529_F_BW13_out_bg.nii.gz
# => Saved to labels_output_unet/529_F_BW13_out_c1.nii.gz
# => Saved to labels_output_unet/529_F_BW13_out_c2.nii.gz
# => Saved to labels_output_unet/529_F_BW13_out_c3.nii.gz
# => Saved to labels_output_unet/534_M_BO12_out_bg.nii.gz
# => Saved to labels_output_unet/534_M_BO12_out_c1.nii.gz
# => Saved to labels_output_unet/534_M_BO12_out_c2.nii.gz
# => Saved to labels_output_unet/534_M_BO12_out_c3.nii.gz
# => Saved to labels_output_unet/535_M_BR18_out_bg.nii.gz
# => Saved to labels_output_unet/535_M_BR18_out_c1.nii.gz
# => Saved to labels_output_unet/535_M_BR18_out_c2.nii.gz
# => Saved to labels_output_unet/535_M_BR18_out_c3.nii.gz
# => Saved to labels_output_unet/537_F_BV6_out_bg.nii.gz
# => Saved to labels_output_unet/537_F_BV6_out_c1.nii.gz
# => Saved to labels_output_unet/537_F_BV6_out_c2.nii.gz
# => Saved to labels_output_unet/537_F_BV6_out_c3.nii.gz
# => Saved to labels_output_unet/538_F_BU3_out_bg.nii.gz
# => Saved to labels_output_unet/538_F_BU3_out_c1.nii.gz
# => Saved to labels_output_unet/538_F_BU3_out_c2.nii.gz
# => Saved to labels_output_unet/538_F_BU3_out_c3.nii.gz
# => Saved to labels_output_unet/539_F_BX17_out_bg.nii.gz
# => Saved to labels_output_unet/539_F_BX17_out_c1.nii.gz
# => Saved to labels_output_unet/539_F_BX17_out_c2.nii.gz
# => Saved to labels_output_unet/539_F_BX17_out_c3.nii.gz
# => Saved to labels_output_unet/540_M_BL5_out_bg.nii.gz
# => Saved to labels_output_unet/540_M_BL5_out_c1.nii.gz
# => Saved to labels_output_unet/540_M_BL5_out_c2.nii.gz
# => Saved to labels_output_unet/540_M_BL5_out_c3.nii.gz
# => Saved to labels_output_unet/542_M_BO13_out_bg.nii.gz
# => Saved to labels_output_unet/542_M_BO13_out_c1.nii.gz
# => Saved to labels_output_unet/542_M_BO13_out_c2.nii.gz
# => Saved to labels_output_unet/542_M_BO13_out_c3.nii.gz
# => Saved to labels_output_unet/548_F_BW14_out_bg.nii.gz
# => Saved to labels_output_unet/548_F_BW14_out_c1.nii.gz
# => Saved to labels_output_unet/548_F_BW14_out_c2.nii.gz
# => Saved to labels_output_unet/548_F_BW14_out_c3.nii.gz
# => Saved to labels_output_unet/549_F_BV7_out_bg.nii.gz
# => Saved to labels_output_unet/549_F_BV7_out_c1.nii.gz
# => Saved to labels_output_unet/549_F_BV7_out_c2.nii.gz
# => Saved to labels_output_unet/549_F_BV7_out_c3.nii.gz
# => Saved to labels_output_unet/550_F_BU4_out_bg.nii.gz
# => Saved to labels_output_unet/550_F_BU4_out_c1.nii.gz
# => Saved to labels_output_unet/550_F_BU4_out_c2.nii.gz
# => Saved to labels_output_unet/550_F_BU4_out_c3.nii.gz
# => Saved to labels_output_unet/552_F_BW15_out_bg.nii.gz
# => Saved to labels_output_unet/552_F_BW15_out_c1.nii.gz
# => Saved to labels_output_unet/552_F_BW15_out_c2.nii.gz
# => Saved to labels_output_unet/552_F_BW15_out_c3.nii.gz
# => Saved to labels_output_unet/553_M_BQ17_out_bg.nii.gz
# => Saved to labels_output_unet/553_M_BQ17_out_c1.nii.gz
# => Saved to labels_output_unet/553_M_BQ17_out_c2.nii.gz
# => Saved to labels_output_unet/553_M_BQ17_out_c3.nii.gz
# => Saved to labels_output_unet/555_F_BP0_out_bg.nii.gz
# => Saved to labels_output_unet/555_F_BP0_out_c1.nii.gz
# => Saved to labels_output_unet/555_F_BP0_out_c2.nii.gz
# => Saved to labels_output_unet/555_F_BP0_out_c3.nii.gz
# => Saved to labels_output_unet/556_M_BT23_out_bg.nii.gz
# => Saved to labels_output_unet/556_M_BT23_out_c1.nii.gz
# => Saved to labels_output_unet/556_M_BT23_out_c2.nii.gz
# => Saved to labels_output_unet/556_M_BT23_out_c3.nii.gz
# => Saved to labels_output_unet/557_F_BV8_out_bg.nii.gz
# => Saved to labels_output_unet/557_F_BV8_out_c1.nii.gz
# => Saved to labels_output_unet/557_F_BV8_out_c2.nii.gz
# => Saved to labels_output_unet/557_F_BV8_out_c3.nii.gz
# => Saved to labels_output_unet/558_F_BU5_out_bg.nii.gz
# => Saved to labels_output_unet/558_F_BU5_out_c1.nii.gz
# => Saved to labels_output_unet/558_F_BU5_out_c2.nii.gz
# => Saved to labels_output_unet/558_F_BU5_out_c3.nii.gz
# => Saved to labels_output_unet/559_F_BX18_out_bg.nii.gz
# => Saved to labels_output_unet/559_F_BX18_out_c1.nii.gz
# => Saved to labels_output_unet/559_F_BX18_out_c2.nii.gz
# => Saved to labels_output_unet/559_F_BX18_out_c3.nii.gz
# => Saved to labels_output_unet/563_M_BP15_out_bg.nii.gz
# => Saved to labels_output_unet/563_M_BP15_out_c1.nii.gz
# => Saved to labels_output_unet/563_M_BP15_out_c2.nii.gz
# => Saved to labels_output_unet/563_M_BP15_out_c3.nii.gz
# => Saved to labels_output_unet/564_M_BR19_out_bg.nii.gz
# => Saved to labels_output_unet/564_M_BR19_out_c1.nii.gz
# => Saved to labels_output_unet/564_M_BR19_out_c2.nii.gz
# => Saved to labels_output_unet/564_M_BR19_out_c3.nii.gz
# => Saved to labels_output_unet/566_M_BT24_out_bg.nii.gz
# => Saved to labels_output_unet/566_M_BT24_out_c1.nii.gz
# => Saved to labels_output_unet/566_M_BT24_out_c2.nii.gz
# => Saved to labels_output_unet/566_M_BT24_out_c3.nii.gz
# => Saved to labels_output_unet/567_F_BV9_out_bg.nii.gz
# => Saved to labels_output_unet/567_F_BV9_out_c1.nii.gz
# => Saved to labels_output_unet/567_F_BV9_out_c2.nii.gz
# => Saved to labels_output_unet/567_F_BV9_out_c3.nii.gz
# => Saved to labels_output_unet/568_F_BX19_out_bg.nii.gz
# => Saved to labels_output_unet/568_F_BX19_out_c1.nii.gz
# => Saved to labels_output_unet/568_F_BX19_out_c2.nii.gz
# => Saved to labels_output_unet/568_F_BX19_out_c3.nii.gz
# => Saved to labels_output_unet/575_M_BR20_out_bg.nii.gz
# => Saved to labels_output_unet/575_M_BR20_out_c1.nii.gz
# => Saved to labels_output_unet/575_M_BR20_out_c2.nii.gz
# => Saved to labels_output_unet/575_M_BR20_out_c3.nii.gz
# => Saved to labels_output_unet/577_M_BT25_out_bg.nii.gz
# => Saved to labels_output_unet/577_M_BT25_out_c1.nii.gz
# => Saved to labels_output_unet/577_M_BT25_out_c2.nii.gz
# => Saved to labels_output_unet/577_M_BT25_out_c3.nii.gz
# => Saved to labels_output_unet/578_F_BV10_out_bg.nii.gz
# => Saved to labels_output_unet/578_F_BV10_out_c1.nii.gz
# => Saved to labels_output_unet/578_F_BV10_out_c2.nii.gz
# => Saved to labels_output_unet/578_F_BV10_out_c3.nii.gz
# => Saved to labels_output_unet/579_F_BX20_out_bg.nii.gz
# => Saved to labels_output_unet/579_F_BX20_out_c1.nii.gz
# => Saved to labels_output_unet/579_F_BX20_out_c2.nii.gz
# => Saved to labels_output_unet/579_F_BX20_out_c3.nii.gz
# => Saved to labels_output_unet/582_M_BM6_out_bg.nii.gz
# => Saved to labels_output_unet/582_M_BM6_out_c1.nii.gz
# => Saved to labels_output_unet/582_M_BM6_out_c2.nii.gz
# => Saved to labels_output_unet/582_M_BM6_out_c3.nii.gz
# => Saved to labels_output_unet/583_M_BN9_out_bg.nii.gz
# => Saved to labels_output_unet/583_M_BN9_out_c1.nii.gz
# => Saved to labels_output_unet/583_M_BN9_out_c2.nii.gz
# => Saved to labels_output_unet/583_M_BN9_out_c3.nii.gz
# => Saved to labels_output_unet/584_M_BN10_out_bg.nii.gz
# => Saved to labels_output_unet/584_M_BN10_out_c1.nii.gz
# => Saved to labels_output_unet/584_M_BN10_out_c2.nii.gz
# => Saved to labels_output_unet/584_M_BN10_out_c3.nii.gz
# => Saved to labels_output_unet/587_F_BY21_out_bg.nii.gz
# => Saved to labels_output_unet/587_F_BY21_out_c1.nii.gz
# => Saved to labels_output_unet/587_F_BY21_out_c2.nii.gz
# => Saved to labels_output_unet/587_F_BY21_out_c3.nii.gz
# => Saved to labels_output_unet/588_F_BY22_out_bg.nii.gz
# => Saved to labels_output_unet/588_F_BY22_out_c1.nii.gz
# => Saved to labels_output_unet/588_F_BY22_out_c2.nii.gz
# => Saved to labels_output_unet/588_F_BY22_out_c3.nii.gz
# => Saved to labels_output_unet/589_F_BY23_out_bg.nii.gz
# => Saved to labels_output_unet/589_F_BY23_out_c1.nii.gz
# => Saved to labels_output_unet/589_F_BY23_out_c2.nii.gz
# => Saved to labels_output_unet/589_F_BY23_out_c3.nii.gz
# => Saved to labels_output_unet/590_F_BY24_out_bg.nii.gz
# => Saved to labels_output_unet/590_F_BY24_out_c1.nii.gz
# => Saved to labels_output_unet/590_F_BY24_out_c2.nii.gz
# => Saved to labels_output_unet/590_F_BY24_out_c3.nii.gz
# => Saved to labels_output_unet/591_M_BM7_out_bg.nii.gz
# => Saved to labels_output_unet/591_M_BM7_out_c1.nii.gz
# => Saved to labels_output_unet/591_M_BM7_out_c2.nii.gz
# => Saved to labels_output_unet/591_M_BM7_out_c3.nii.gz
# => Saved to labels_output_unet/592_M_BM8_out_bg.nii.gz
# => Saved to labels_output_unet/592_M_BM8_out_c1.nii.gz
# => Saved to labels_output_unet/592_M_BM8_out_c2.nii.gz
# => Saved to labels_output_unet/592_M_BM8_out_c3.nii.gz
# => Saved to labels_output_unet/593_F_BY25_out_bg.nii.gz
# => Saved to labels_output_unet/593_F_BY25_out_c1.nii.gz
# => Saved to labels_output_unet/593_F_BY25_out_c2.nii.gz
# => Saved to labels_output_unet/593_F_BY25_out_c3.nii.gz
# => Saved to labels_output_unet/594_M_CB6_out_bg.nii.gz
# => Saved to labels_output_unet/594_M_CB6_out_c1.nii.gz
# => Saved to labels_output_unet/594_M_CB6_out_c2.nii.gz
# => Saved to labels_output_unet/594_M_CB6_out_c3.nii.gz
# => Saved to labels_output_unet/595_M_CF16_out_bg.nii.gz
# => Saved to labels_output_unet/595_M_CF16_out_c1.nii.gz
# => Saved to labels_output_unet/595_M_CF16_out_c2.nii.gz
# => Saved to labels_output_unet/595_M_CF16_out_c3.nii.gz
# => Saved to labels_output_unet/597_F_CK11_out_bg.nii.gz
# => Saved to labels_output_unet/597_F_CK11_out_c1.nii.gz
# => Saved to labels_output_unet/597_F_CK11_out_c2.nii.gz
# => Saved to labels_output_unet/597_F_CK11_out_c3.nii.gz
# => Saved to labels_output_unet/600_F_CM6_out_bg.nii.gz
# => Saved to labels_output_unet/600_F_CM6_out_c1.nii.gz
# => Saved to labels_output_unet/600_F_CM6_out_c2.nii.gz
# => Saved to labels_output_unet/600_F_CM6_out_c3.nii.gz
# => Saved to labels_output_unet/602_M_CB7_out_bg.nii.gz
# => Saved to labels_output_unet/602_M_CB7_out_c1.nii.gz
# => Saved to labels_output_unet/602_M_CB7_out_c2.nii.gz
# => Saved to labels_output_unet/602_M_CB7_out_c3.nii.gz
# => Saved to labels_output_unet/603_M_CF17_out_bg.nii.gz
# => Saved to labels_output_unet/603_M_CF17_out_c1.nii.gz
# => Saved to labels_output_unet/603_M_CF17_out_c2.nii.gz
# => Saved to labels_output_unet/603_M_CF17_out_c3.nii.gz
# => Saved to labels_output_unet/607_F_CK12_out_bg.nii.gz
# => Saved to labels_output_unet/607_F_CK12_out_c1.nii.gz
# => Saved to labels_output_unet/607_F_CK12_out_c2.nii.gz
# => Saved to labels_output_unet/607_F_CK12_out_c3.nii.gz
# => Saved to labels_output_unet/608_F_CL16_out_bg.nii.gz
# => Saved to labels_output_unet/608_F_CL16_out_c1.nii.gz
# => Saved to labels_output_unet/608_F_CL16_out_c2.nii.gz
# => Saved to labels_output_unet/608_F_CL16_out_c3.nii.gz
# => Saved to labels_output_unet/610_F_CN21_out_bg.nii.gz
# => Saved to labels_output_unet/610_F_CN21_out_c1.nii.gz
# => Saved to labels_output_unet/610_F_CN21_out_c2.nii.gz
# => Saved to labels_output_unet/610_F_CN21_out_c3.nii.gz
# => Saved to labels_output_unet/612_M_CH21_out_bg.nii.gz
# => Saved to labels_output_unet/612_M_CH21_out_c1.nii.gz
# => Saved to labels_output_unet/612_M_CH21_out_c2.nii.gz
# => Saved to labels_output_unet/612_M_CH21_out_c3.nii.gz
# => Saved to labels_output_unet/618_F_CL17_out_bg.nii.gz
# => Saved to labels_output_unet/618_F_CL17_out_c1.nii.gz
# => Saved to labels_output_unet/618_F_CL17_out_c2.nii.gz
# => Saved to labels_output_unet/618_F_CL17_out_c3.nii.gz
# => Saved to labels_output_unet/619_F_CN22_out_bg.nii.gz
# => Saved to labels_output_unet/619_F_CN22_out_c1.nii.gz
# => Saved to labels_output_unet/619_F_CN22_out_c2.nii.gz
# => Saved to labels_output_unet/619_F_CN22_out_c3.nii.gz
# => Saved to labels_output_unet/620_F_CM7_out_bg.nii.gz
# => Saved to labels_output_unet/620_F_CM7_out_c1.nii.gz
# => Saved to labels_output_unet/620_F_CM7_out_c2.nii.gz
# => Saved to labels_output_unet/620_F_CM7_out_c3.nii.gz
# => Saved to labels_output_unet/623_M_CC9_out_bg.nii.gz
# => Saved to labels_output_unet/623_M_CC9_out_c1.nii.gz
# => Saved to labels_output_unet/623_M_CC9_out_c2.nii.gz
# => Saved to labels_output_unet/623_M_CC9_out_c3.nii.gz
# => Saved to labels_output_unet/625_M_CH22_out_bg.nii.gz
# => Saved to labels_output_unet/625_M_CH22_out_c1.nii.gz
# => Saved to labels_output_unet/625_M_CH22_out_c2.nii.gz
# => Saved to labels_output_unet/625_M_CH22_out_c3.nii.gz
# => Saved to labels_output_unet/629_F_CL18_out_bg.nii.gz
# => Saved to labels_output_unet/629_F_CL18_out_c1.nii.gz
# => Saved to labels_output_unet/629_F_CL18_out_c2.nii.gz
# => Saved to labels_output_unet/629_F_CL18_out_c3.nii.gz
# => Saved to labels_output_unet/631_M_CD12_out_bg.nii.gz
# => Saved to labels_output_unet/631_M_CD12_out_c1.nii.gz
# => Saved to labels_output_unet/631_M_CD12_out_c2.nii.gz
# => Saved to labels_output_unet/631_M_CD12_out_c3.nii.gz
# => Saved to labels_output_unet/634_F_CL19_out_bg.nii.gz
# => Saved to labels_output_unet/634_F_CL19_out_c1.nii.gz
# => Saved to labels_output_unet/634_F_CL19_out_c2.nii.gz
# => Saved to labels_output_unet/634_F_CL19_out_c3.nii.gz
# => Saved to labels_output_unet/636_F_CN23_out_bg.nii.gz
# => Saved to labels_output_unet/636_F_CN23_out_c1.nii.gz
# => Saved to labels_output_unet/636_F_CN23_out_c2.nii.gz
# => Saved to labels_output_unet/636_F_CN23_out_c3.nii.gz
# => Saved to labels_output_unet/638_F_CM8_out_bg.nii.gz
# => Saved to labels_output_unet/638_F_CM8_out_c1.nii.gz
# => Saved to labels_output_unet/638_F_CM8_out_c2.nii.gz
# => Saved to labels_output_unet/638_F_CM8_out_c3.nii.gz
# => Saved to labels_output_unet/642_M_CC9_out_bg.nii.gz
# => Saved to labels_output_unet/642_M_CC9_out_c1.nii.gz
# => Saved to labels_output_unet/642_M_CC9_out_c2.nii.gz
# => Saved to labels_output_unet/642_M_CC9_out_c3.nii.gz
# => Saved to labels_output_unet/643_M_CD13_out_bg.nii.gz
# => Saved to labels_output_unet/643_M_CD13_out_c1.nii.gz
# => Saved to labels_output_unet/643_M_CD13_out_c2.nii.gz
# => Saved to labels_output_unet/643_M_CD13_out_c3.nii.gz
# => Saved to labels_output_unet/644_M_CH23_out_bg.nii.gz
# => Saved to labels_output_unet/644_M_CH23_out_c1.nii.gz
# => Saved to labels_output_unet/644_M_CH23_out_c2.nii.gz
# => Saved to labels_output_unet/644_M_CH23_out_c3.nii.gz
# => Saved to labels_output_unet/647_F_CL20_out_bg.nii.gz
# => Saved to labels_output_unet/647_F_CL20_out_c1.nii.gz
# => Saved to labels_output_unet/647_F_CL20_out_c2.nii.gz
# => Saved to labels_output_unet/647_F_CL20_out_c3.nii.gz
# => Saved to labels_output_unet/649_F_CN24_out_bg.nii.gz
# => Saved to labels_output_unet/649_F_CN24_out_c1.nii.gz
# => Saved to labels_output_unet/649_F_CN24_out_c2.nii.gz
# => Saved to labels_output_unet/649_F_CN24_out_c3.nii.gz
# => Saved to labels_output_unet/652_M_CG18_out_bg.nii.gz
# => Saved to labels_output_unet/652_M_CG18_out_c1.nii.gz
# => Saved to labels_output_unet/652_M_CG18_out_c2.nii.gz
# => Saved to labels_output_unet/652_M_CG18_out_c3.nii.gz
# => Saved to labels_output_unet/657_F_CK13_out_bg.nii.gz
# => Saved to labels_output_unet/657_F_CK13_out_c1.nii.gz
# => Saved to labels_output_unet/657_F_CK13_out_c2.nii.gz
# => Saved to labels_output_unet/657_F_CK13_out_c3.nii.gz
# => Saved to labels_output_unet/658_M_CG19_out_bg.nii.gz
# => Saved to labels_output_unet/658_M_CG19_out_c1.nii.gz
# => Saved to labels_output_unet/658_M_CG19_out_c2.nii.gz
# => Saved to labels_output_unet/658_M_CG19_out_c3.nii.gz
# => Saved to labels_output_unet/660_F_CK14_out_bg.nii.gz
# => Saved to labels_output_unet/660_F_CK14_out_c1.nii.gz
# => Saved to labels_output_unet/660_F_CK14_out_c2.nii.gz
# => Saved to labels_output_unet/660_F_CK14_out_c3.nii.gz
# => Saved to labels_output_unet/661_F_CN25_out_bg.nii.gz
# => Saved to labels_output_unet/661_F_CN25_out_c1.nii.gz
# => Saved to labels_output_unet/661_F_CN25_out_c2.nii.gz
# => Saved to labels_output_unet/661_F_CN25_out_c3.nii.gz
# => Saved to labels_output_unet/663_F_CM9_out_bg.nii.gz
# => Saved to labels_output_unet/663_F_CM9_out_c1.nii.gz
# => Saved to labels_output_unet/663_F_CM9_out_c2.nii.gz
# => Saved to labels_output_unet/663_F_CM9_out_c3.nii.gz
# => Saved to labels_output_unet/668_M_CE15_out_bg.nii.gz
# => Saved to labels_output_unet/668_M_CE15_out_c1.nii.gz
# => Saved to labels_output_unet/668_M_CE15_out_c2.nii.gz
# => Saved to labels_output_unet/668_M_CE15_out_c3.nii.gz
# => Saved to labels_output_unet/669_M_CG20_out_bg.nii.gz
# => Saved to labels_output_unet/669_M_CG20_out_c1.nii.gz
# => Saved to labels_output_unet/669_M_CG20_out_c2.nii.gz
# => Saved to labels_output_unet/669_M_CG20_out_c3.nii.gz
# => Saved to labels_output_unet/670_M_CI25_out_bg.nii.gz
# => Saved to labels_output_unet/670_M_CI25_out_c1.nii.gz
# => Saved to labels_output_unet/670_M_CI25_out_c2.nii.gz
# => Saved to labels_output_unet/670_M_CI25_out_c3.nii.gz
# => Saved to labels_output_unet/673_F_CK15_out_bg.nii.gz
# => Saved to labels_output_unet/673_F_CK15_out_c1.nii.gz
# => Saved to labels_output_unet/673_F_CK15_out_c2.nii.gz
# => Saved to labels_output_unet/673_F_CK15_out_c3.nii.gz
# => Saved to labels_output_unet/675_F_CM10_out_bg.nii.gz
# => Saved to labels_output_unet/675_F_CM10_out_c1.nii.gz
# => Saved to labels_output_unet/675_F_CM10_out_c2.nii.gz
# => Saved to labels_output_unet/675_F_CM10_out_c3.nii.gz
# => Saved to labels_output_unet/678_M_BZ1_out_bg.nii.gz
# => Saved to labels_output_unet/678_M_BZ1_out_c1.nii.gz
# => Saved to labels_output_unet/678_M_BZ1_out_c2.nii.gz
# => Saved to labels_output_unet/678_M_BZ1_out_c3.nii.gz
# => Saved to labels_output_unet/679_M_BZ2_out_bg.nii.gz
# => Saved to labels_output_unet/679_M_BZ2_out_c1.nii.gz
# => Saved to labels_output_unet/679_M_BZ2_out_c2.nii.gz
# => Saved to labels_output_unet/679_M_BZ2_out_c3.nii.gz
# => Saved to labels_output_unet/685_F_CJ1_out_bg.nii.gz
# => Saved to labels_output_unet/685_F_CJ1_out_c1.nii.gz
# => Saved to labels_output_unet/685_F_CJ1_out_c2.nii.gz
# => Saved to labels_output_unet/685_F_CJ1_out_c3.nii.gz
# => Saved to labels_output_unet/686_F_CJ2_out_bg.nii.gz
# => Saved to labels_output_unet/686_F_CJ2_out_c1.nii.gz
# => Saved to labels_output_unet/686_F_CJ2_out_c2.nii.gz
# => Saved to labels_output_unet/686_F_CJ2_out_c3.nii.gz
# => Saved to labels_output_unet/687_F_CJ3_out_bg.nii.gz
# => Saved to labels_output_unet/687_F_CJ3_out_c1.nii.gz
# => Saved to labels_output_unet/687_F_CJ3_out_c2.nii.gz
# => Saved to labels_output_unet/687_F_CJ3_out_c3.nii.gz
# => Saved to labels_output_unet/689_M_BZ3_out_bg.nii.gz
# => Saved to labels_output_unet/689_M_BZ3_out_c1.nii.gz
# => Saved to labels_output_unet/689_M_BZ3_out_c2.nii.gz
# => Saved to labels_output_unet/689_M_BZ3_out_c3.nii.gz
# => Saved to labels_output_unet/690_M_CA4_out_bg.nii.gz
# => Saved to labels_output_unet/690_M_CA4_out_c1.nii.gz
# => Saved to labels_output_unet/690_M_CA4_out_c2.nii.gz
# => Saved to labels_output_unet/690_M_CA4_out_c3.nii.gz
# => Saved to labels_output_unet/691_M_CA5_out_bg.nii.gz
# => Saved to labels_output_unet/691_M_CA5_out_c1.nii.gz
# => Saved to labels_output_unet/691_M_CA5_out_c2.nii.gz
# => Saved to labels_output_unet/691_M_CA5_out_c3.nii.gz
# => Saved to labels_output_unet/697_F_CJ4_out_bg.nii.gz
# => Saved to labels_output_unet/697_F_CJ4_out_c1.nii.gz
# => Saved to labels_output_unet/697_F_CJ4_out_c2.nii.gz
# => Saved to labels_output_unet/697_F_CJ4_out_c3.nii.gz
# => Saved to labels_output_unet/698_F_CJ5_out_bg.nii.gz
# => Saved to labels_output_unet/698_F_CJ5_out_c1.nii.gz
# => Saved to labels_output_unet/698_F_CJ5_out_c2.nii.gz
# => Saved to labels_output_unet/698_F_CJ5_out_c3.nii.gz
# dice: 0.4174
# dices: 0.9580, 0.3942, 0.3120, 0.0055

# %%
#labels_output
labels = sorted(glob(os.path.join("dataset", "Painfact-Segmentation-Raw", 'Label-0.2', "*.nii.gz")))
preds_bgs = sorted(glob(os.path.join("labels_output_unet", "*_out_bg.nii.gz")))
preds_c1s = sorted(glob(os.path.join("labels_output_unet", "*_out_c1.nii.gz")))
preds_c2s = sorted(glob(os.path.join("labels_output_unet", "*_out_c2.nii.gz")))
preds_c3s = sorted(glob(os.path.join("labels_output_unet", "*_out_c3.nii.gz")))

preds = [preds_bgs, preds_c1s, preds_c2s, preds_c3s]

metrics = [[], [], [], []]

for i in range(len(preds_bgs)):
    if i>(165+55):# and i<(165+55):
        y = labels[i]
        y = nib.load(y).get_fdata()  
        y = GetLabelsAsOneHot(get=True, skip=False)(y)
        for j in range(4):
            truth = y[j,:,:,:]
            x = preds[j][i]
            x = nib.load(x).get_fdata()
            metric = dice(truth,x)
            metrics[j].append(metric)
    
epoch_metrics = [np.mean(x) for x in metrics]
epoch_metric = np.mean(epoch_metrics)


print(
        "dice: {:.4f}".format(
            epoch_metric
        )
    )
print("dices: {:.4f}, {:.4f}, {:.4f}, {:.4f}".format(epoch_metrics[0], epoch_metrics[1], epoch_metrics[2], epoch_metrics[3]))
# Out:
# dice: 0.7377
# dices: 0.9924, 0.8901, 0.8134, 0.2550

# %%
#labels_output
labels = sorted(glob(os.path.join("dataset", "Painfact-Segmentation-Raw", 'Label-0.2', "*.nii.gz")))
preds_bgs = sorted(glob(os.path.join("labels_output", "*_out_bg.nii.gz")))
preds_c1s = sorted(glob(os.path.join("labels_output", "*_out_c1.nii.gz")))
preds_c2s = sorted(glob(os.path.join("labels_output", "*_out_c2.nii.gz")))
preds_c3s = sorted(glob(os.path.join("labels_output", "*_out_c3.nii.gz")))

preds = [preds_bgs, preds_c1s, preds_c2s, preds_c3s]

metrics = [[], [], [], []]

for i in range(len(preds_bgs)):
    if i>(165+55):# and i<(165+55):
        y = labels[i]
        y = nib.load(y).get_fdata()  
        y = GetLabelsAsOneHot(get=True, skip=False)(y)
        for j in range(4):
            truth = y[j,:,:,:]
            x = preds[j][i]
            x = nib.load(x).get_fdata()
            metric = dice(truth,x)
            metrics[j].append(metric)
    
epoch_metrics = [np.mean(x) for x in metrics]
epoch_metric = np.mean(epoch_metrics)


print(
        "dice: {:.4f}".format(
            epoch_metric
        )
    )
print("dices: {:.4f}, {:.4f}, {:.4f}, {:.4f}".format(epoch_metrics[0], epoch_metrics[1], epoch_metrics[2], epoch_metrics[3]))
# Out:
# dice: 0.7498
# dices: 0.9927, 0.9034, 0.8180, 0.2851

# %%
#labels_output
labels = sorted(glob(os.path.join("dataset", "Painfact-Segmentation-Raw", 'Label-0.2', "*.nii.gz")))
preds_bgs = sorted(glob(os.path.join("labels_output_new", "*_out_bg.nii.gz")))
preds_c1s = sorted(glob(os.path.join("labels_output_new", "*_out_c1.nii.gz")))
preds_c2s = sorted(glob(os.path.join("labels_output_new", "*_out_c2.nii.gz")))
preds_c3s = sorted(glob(os.path.join("labels_output_new", "*_out_c3.nii.gz")))

preds = [preds_bgs, preds_c1s, preds_c2s, preds_c3s]

metrics = [[], [], [], []]

for i in range(len(preds_bgs)):
    if i>(165+55):# and i<(165+55):
        y = labels[i]
        y = nib.load(y).get_fdata()  
        y = GetLabelsAsOneHot(get=True, skip=False)(y)
        for j in range(4):
            truth = y[j,:,:,:]
            x = preds[j][i]
            x = nib.load(x).get_fdata()
            metric = dice(truth,x)
            metrics[j].append(metric)
    
epoch_metrics = [np.mean(x) for x in metrics]
epoch_metrics.append(0.9913)
epoch_metric = np.mean(epoch_metrics[1:4])

print(
        "dice: {:.4f}".format(
            epoch_metric
        )
    )
print("dices: {:.4f}, {:.4f}, {:.4f}, {:.4f}".format(epoch_metrics[4], epoch_metrics[1], epoch_metrics[2], epoch_metrics[3]))
# Out:
# dice: 0.6171
# dices: 0.9913, 0.8649, 0.6857, 0.3008
