# %%
import argparse
import logging
import sys

import monai
import torch
from torch.utils.tensorboard import SummaryWriter
from monai.utils import set_determinism
import numpy as np
from glob import glob
import os

from monai.transforms.transform import Transform
from monai.transforms import Activations, EnsureType, Compose
from transforms import CropMRId, BinaryMask, GetLargestComponent, GetLabelsAsOneHotd, Shaped, InverseOneHot
from torch import nn
from transforms_dict import getSegmentationEvalTransformsForMRI
from transforms_dict import getSegmentationInverseTransformForLabels

from seg_data import getDataset
from seg_model import getUNetForSegmentation
from utils import compute_mean_dice, getReducePlateauScheduler, getAdamOptimizer, loadExistingModel
from utils import print_model_output, check_model_name, getDevice

# %%
#Parameters
N4 = False
resample = False
save_tmp = False
get_largest_component = False

# %%
#Modelname and device

def getUNETRForSegmentation():
    device = getDevice()
    model = monai.networks.nets.UNETR(
        in_channels=1,
        out_channels=4,
        img_size=(96, 96, 96),
        feature_size=16,
        hidden_size=768,
        mlp_dim=3072,
        num_heads=12,
        pos_embed="perceptron",
        norm_name="instance",
        res_block=True,
        dropout_rate=0.0,
    ).to(device)
    return model

model = getUNETRForSegmentation()
modelname = "labels/seg_labels_unetr_1.pth"

#model = getUNetForSegmentation()
#modelname = "labels/seg_labels_2.pth"

modelname = check_model_name(modelname)
set_determinism(seed=0)
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
device = getDevice()

# %%
def max_channel_wise(labels):
    labels = labels.detach().cpu().numpy()
    labels[np.where(labels == np.amax(labels, axis=1))] = 1
    labels[labels != 1] = 0
    return labels


class GetMaxChannelWise(Transform):
    def __call__(self, labels):
        labels = max_channel_wise(labels)
        return labels

# %%
def getSegmentationPostProcessingForLabel():
    device = getDevice()
    postprocessing_transforms = Compose(
        [
            EnsureType(),
            GetMaxChannelWise(),
            EnsureType(data_type="tensor", device=device),
        ]
    )
    return postprocessing_transforms


def getSegmentationPostProcessingForLabelOutput():
    device = getDevice()
    postprocessing_transforms = Compose(
        [
            EnsureType(),
            Activations(other=nn.Softmax(dim=1)),
            GetMaxChannelWise(),
            EnsureType(data_type="tensor", device=device),
        ]
    )
    return postprocessing_transforms

def getSegmentationPostProcessingForAllLabelsOutput():
    device = getDevice()
    postprocessing_transforms = Compose(
        [
            EnsureType(),
            Activations(other=nn.Softmax(dim=1)),
            InverseOneHot(),
            EnsureType(data_type="tensor", device=device),
        ]
    )
    return postprocessing_transforms

# %%
#postprocessing
device = getDevice()
outputs_processing = getSegmentationPostProcessingForLabelOutput()
all_outputs_processing = getSegmentationPostProcessingForAllLabelsOutput()
labels_processing = getSegmentationPostProcessingForLabel()
test_proba = Compose([
    EnsureType(),
    Activations(other=nn.Softmax(dim=1)),
    EnsureType(data_type="tensor", device=device)
])

#activations
softmax = Activations(other=nn.Softmax(dim=1))

# %%
#Model
loadExistingModel(model, None, ft=modelname)
model.eval()

mris = sorted(glob(os.path.join("dataset", "Painfact-Segmentation", 'MRI', "*.nii.gz")))
for mri in mris:
    mriname = mri
    outname = "labels_output/" + mriname.split('/')[-1].split('.')[0]

    mri_preprocessing = getSegmentationEvalTransformsForMRI(N4=N4, outname=outname, save=save_tmp)

    with torch.no_grad():
        inputs = mri_preprocessing(mriname).to(device)
        outputs = model(inputs).cpu()  

        preds = outputs_processing(outputs)
        all_preds = all_outputs_processing(outputs)
        probs = test_proba(outputs)

        suffix = ["bg", "c1", "c2", "c3"]
        for i in range(len(suffix)):
            transform = getSegmentationInverseTransformForLabels(mriname, out_name=outname, suffix=suffix[i], save=True)
            transform(preds[0, i, :, :, :])        
        #for i in range(len(suffix)):
        #    transform = getSegmentationInverseTransformForLabels(mriname, out_name=outname, suffix=suffix[i]+'_prob', save=True)
        #    transform(probs[0, i, :, :, :])
        transform = getSegmentationInverseTransformForLabels(mriname, out_name=outname, suffix=None, save=True)
        transform(all_preds[0,:,:,:])
# Out:
# => Saved to labels_output/000_M_I23_out_bg.nii.gz
# => Saved to labels_output/000_M_I23_out_c1.nii.gz
# => Saved to labels_output/000_M_I23_out_c2.nii.gz
# => Saved to labels_output/000_M_I23_out_c3.nii.gz
# => Saved to labels_output/000_M_I23_out.nii.gz
# => Saved to labels_output/101_M_A1_out_bg.nii.gz
# => Saved to labels_output/101_M_A1_out_c1.nii.gz
# => Saved to labels_output/101_M_A1_out_c2.nii.gz
# => Saved to labels_output/101_M_A1_out_c3.nii.gz
# => Saved to labels_output/101_M_A1_out.nii.gz
# => Saved to labels_output/102_M_A2_out_bg.nii.gz
# => Saved to labels_output/102_M_A2_out_c1.nii.gz
# => Saved to labels_output/102_M_A2_out_c2.nii.gz
# => Saved to labels_output/102_M_A2_out_c3.nii.gz
# => Saved to labels_output/102_M_A2_out.nii.gz
# => Saved to labels_output/103_M_I21_out_bg.nii.gz
# => Saved to labels_output/103_M_I21_out_c1.nii.gz
# => Saved to labels_output/103_M_I21_out_c2.nii.gz
# => Saved to labels_output/103_M_I21_out_c3.nii.gz
# => Saved to labels_output/103_M_I21_out.nii.gz
# => Saved to labels_output/109_F_K2_out_bg.nii.gz
# => Saved to labels_output/109_F_K2_out_c1.nii.gz
# => Saved to labels_output/109_F_K2_out_c2.nii.gz
# => Saved to labels_output/109_F_K2_out_c3.nii.gz
# => Saved to labels_output/109_F_K2_out.nii.gz
# => Saved to labels_output/110_F_K1_out_bg.nii.gz
# => Saved to labels_output/110_F_K1_out_c1.nii.gz
# => Saved to labels_output/110_F_K1_out_c2.nii.gz
# => Saved to labels_output/110_F_K1_out_c3.nii.gz
# => Saved to labels_output/110_F_K1_out.nii.gz
# => Saved to labels_output/113_M_A3_out_bg.nii.gz
# => Saved to labels_output/113_M_A3_out_c1.nii.gz
# => Saved to labels_output/113_M_A3_out_c2.nii.gz
# => Saved to labels_output/113_M_A3_out_c3.nii.gz
# => Saved to labels_output/113_M_A3_out.nii.gz
# => Saved to labels_output/114_M_A4_out_bg.nii.gz
# => Saved to labels_output/114_M_A4_out_c1.nii.gz
# => Saved to labels_output/114_M_A4_out_c2.nii.gz
# => Saved to labels_output/114_M_A4_out_c3.nii.gz
# => Saved to labels_output/114_M_A4_out.nii.gz
# => Saved to labels_output/115_M_E13_out_bg.nii.gz
# => Saved to labels_output/115_M_E13_out_c1.nii.gz
# => Saved to labels_output/115_M_E13_out_c2.nii.gz
# => Saved to labels_output/115_M_E13_out_c3.nii.gz
# => Saved to labels_output/115_M_E13_out.nii.gz
# => Saved to labels_output/116_F_K3_out_bg.nii.gz
# => Saved to labels_output/116_F_K3_out_c1.nii.gz
# => Saved to labels_output/116_F_K3_out_c2.nii.gz
# => Saved to labels_output/116_F_K3_out_c3.nii.gz
# => Saved to labels_output/116_F_K3_out.nii.gz
# => Saved to labels_output/117_F_K4_out_bg.nii.gz
# => Saved to labels_output/117_F_K4_out_c1.nii.gz
# => Saved to labels_output/117_F_K4_out_c2.nii.gz
# => Saved to labels_output/117_F_K4_out_c3.nii.gz
# => Saved to labels_output/117_F_K4_out.nii.gz
# => Saved to labels_output/120_M_B5_out_bg.nii.gz
# => Saved to labels_output/120_M_B5_out_c1.nii.gz
# => Saved to labels_output/120_M_B5_out_c2.nii.gz
# => Saved to labels_output/120_M_B5_out_c3.nii.gz
# => Saved to labels_output/120_M_B5_out.nii.gz
# => Saved to labels_output/123_F_K5_out_bg.nii.gz
# => Saved to labels_output/123_F_K5_out_c1.nii.gz
# => Saved to labels_output/123_F_K5_out_c2.nii.gz
# => Saved to labels_output/123_F_K5_out_c3.nii.gz
# => Saved to labels_output/123_F_K5_out.nii.gz
# => Saved to labels_output/124_F_L6_out_bg.nii.gz
# => Saved to labels_output/124_F_L6_out_c1.nii.gz
# => Saved to labels_output/124_F_L6_out_c2.nii.gz
# => Saved to labels_output/124_F_L6_out_c3.nii.gz
# => Saved to labels_output/124_F_L6_out.nii.gz
# => Saved to labels_output/130_M_C8_out_bg.nii.gz
# => Saved to labels_output/130_M_C8_out_c1.nii.gz
# => Saved to labels_output/130_M_C8_out_c2.nii.gz
# => Saved to labels_output/130_M_C8_out_c3.nii.gz
# => Saved to labels_output/130_M_C8_out.nii.gz
# => Saved to labels_output/131_M_D9_out_bg.nii.gz
# => Saved to labels_output/131_M_D9_out_c1.nii.gz
# => Saved to labels_output/131_M_D9_out_c2.nii.gz
# => Saved to labels_output/131_M_D9_out_c3.nii.gz
# => Saved to labels_output/131_M_D9_out.nii.gz
# => Saved to labels_output/132_M_I22_out_bg.nii.gz
# => Saved to labels_output/132_M_I22_out_c1.nii.gz
# => Saved to labels_output/132_M_I22_out_c2.nii.gz
# => Saved to labels_output/132_M_I22_out_c3.nii.gz
# => Saved to labels_output/132_M_I22_out.nii.gz
# => Saved to labels_output/135_F_L10_out_bg.nii.gz
# => Saved to labels_output/135_F_L10_out_c1.nii.gz
# => Saved to labels_output/135_F_L10_out_c2.nii.gz
# => Saved to labels_output/135_F_L10_out_c3.nii.gz
# => Saved to labels_output/135_F_L10_out.nii.gz
# => Saved to labels_output/136_F_L8_out_bg.nii.gz
# => Saved to labels_output/136_F_L8_out_c1.nii.gz
# => Saved to labels_output/136_F_L8_out_c2.nii.gz
# => Saved to labels_output/136_F_L8_out_c3.nii.gz
# => Saved to labels_output/136_F_L8_out.nii.gz
# => Saved to labels_output/141_M_D10_out_bg.nii.gz
# => Saved to labels_output/141_M_D10_out_c1.nii.gz
# => Saved to labels_output/141_M_D10_out_c2.nii.gz
# => Saved to labels_output/141_M_D10_out_c3.nii.gz
# => Saved to labels_output/141_M_D10_out.nii.gz
# => Saved to labels_output/142_M_C7_out_bg.nii.gz
# => Saved to labels_output/142_M_C7_out_c1.nii.gz
# => Saved to labels_output/142_M_C7_out_c2.nii.gz
# => Saved to labels_output/142_M_C7_out_c3.nii.gz
# => Saved to labels_output/142_M_C7_out.nii.gz
# => Saved to labels_output/145_F_L7_out_bg.nii.gz
# => Saved to labels_output/145_F_L7_out_c1.nii.gz
# => Saved to labels_output/145_F_L7_out_c2.nii.gz
# => Saved to labels_output/145_F_L7_out_c3.nii.gz
# => Saved to labels_output/145_F_L7_out.nii.gz
# => Saved to labels_output/146_F_L9_out_bg.nii.gz
# => Saved to labels_output/146_F_L9_out_c1.nii.gz
# => Saved to labels_output/146_F_L9_out_c2.nii.gz
# => Saved to labels_output/146_F_L9_out_c3.nii.gz
# => Saved to labels_output/146_F_L9_out.nii.gz
# => Saved to labels_output/150_M_F15_out_bg.nii.gz
# => Saved to labels_output/150_M_F15_out_c1.nii.gz
# => Saved to labels_output/150_M_F15_out_c2.nii.gz
# => Saved to labels_output/150_M_F15_out_c3.nii.gz
# => Saved to labels_output/150_M_F15_out.nii.gz
# => Saved to labels_output/151_F_M11_out_bg.nii.gz
# => Saved to labels_output/151_F_M11_out_c1.nii.gz
# => Saved to labels_output/151_F_M11_out_c2.nii.gz
# => Saved to labels_output/151_F_M11_out_c3.nii.gz
# => Saved to labels_output/151_F_M11_out.nii.gz
# => Saved to labels_output/152_F_M15_out_bg.nii.gz
# => Saved to labels_output/152_F_M15_out_c1.nii.gz
# => Saved to labels_output/152_F_M15_out_c2.nii.gz
# => Saved to labels_output/152_F_M15_out_c3.nii.gz
# => Saved to labels_output/152_F_M15_out.nii.gz
# => Saved to labels_output/159_M_G17_out_bg.nii.gz
# => Saved to labels_output/159_M_G17_out_c1.nii.gz
# => Saved to labels_output/159_M_G17_out_c2.nii.gz
# => Saved to labels_output/159_M_G17_out_c3.nii.gz
# => Saved to labels_output/159_M_G17_out.nii.gz
# => Saved to labels_output/160_F_M13_out_bg.nii.gz
# => Saved to labels_output/160_F_M13_out_c1.nii.gz
# => Saved to labels_output/160_F_M13_out_c2.nii.gz
# => Saved to labels_output/160_F_M13_out_c3.nii.gz
# => Saved to labels_output/160_F_M13_out.nii.gz
# => Saved to labels_output/161_F_M12_out_bg.nii.gz
# => Saved to labels_output/161_F_M12_out_c1.nii.gz
# => Saved to labels_output/161_F_M12_out_c2.nii.gz
# => Saved to labels_output/161_F_M12_out_c3.nii.gz
# => Saved to labels_output/161_F_M12_out.nii.gz
# => Saved to labels_output/162_M_G19_out_bg.nii.gz
# => Saved to labels_output/162_M_G19_out_c1.nii.gz
# => Saved to labels_output/162_M_G19_out_c2.nii.gz
# => Saved to labels_output/162_M_G19_out_c3.nii.gz
# => Saved to labels_output/162_M_G19_out.nii.gz
# => Saved to labels_output/163_M_G18_out_bg.nii.gz
# => Saved to labels_output/163_M_G18_out_c1.nii.gz
# => Saved to labels_output/163_M_G18_out_c2.nii.gz
# => Saved to labels_output/163_M_G18_out_c3.nii.gz
# => Saved to labels_output/163_M_G18_out.nii.gz
# => Saved to labels_output/164_M_J24_out_bg.nii.gz
# => Saved to labels_output/164_M_J24_out_c1.nii.gz
# => Saved to labels_output/164_M_J24_out_c2.nii.gz
# => Saved to labels_output/164_M_J24_out_c3.nii.gz
# => Saved to labels_output/164_M_J24_out.nii.gz
# => Saved to labels_output/170_F_N20_out_bg.nii.gz
# => Saved to labels_output/170_F_N20_out_c1.nii.gz
# => Saved to labels_output/170_F_N20_out_c2.nii.gz
# => Saved to labels_output/170_F_N20_out_c3.nii.gz
# => Saved to labels_output/170_F_N20_out.nii.gz
# => Saved to labels_output/177_F_N19_out_bg.nii.gz
# => Saved to labels_output/177_F_N19_out_c1.nii.gz
# => Saved to labels_output/177_F_N19_out_c2.nii.gz
# => Saved to labels_output/177_F_N19_out_c3.nii.gz
# => Saved to labels_output/177_F_N19_out.nii.gz
# => Saved to labels_output/178_F_N17_out_bg.nii.gz
# => Saved to labels_output/178_F_N17_out_c1.nii.gz
# => Saved to labels_output/178_F_N17_out_c2.nii.gz
# => Saved to labels_output/178_F_N17_out_c3.nii.gz
# => Saved to labels_output/178_F_N17_out.nii.gz
# => Saved to labels_output/185_F_N18_out_bg.nii.gz
# => Saved to labels_output/185_F_N18_out_c1.nii.gz
# => Saved to labels_output/185_F_N18_out_c2.nii.gz
# => Saved to labels_output/185_F_N18_out_c3.nii.gz
# => Saved to labels_output/185_F_N18_out.nii.gz
# => Saved to labels_output/186_F_N16_out_bg.nii.gz
# => Saved to labels_output/186_F_N16_out_c1.nii.gz
# => Saved to labels_output/186_F_N16_out_c2.nii.gz
# => Saved to labels_output/186_F_N16_out_c3.nii.gz
# => Saved to labels_output/186_F_N16_out.nii.gz
# => Saved to labels_output/187_M_H20_out_bg.nii.gz
# => Saved to labels_output/187_M_H20_out_c1.nii.gz
# => Saved to labels_output/187_M_H20_out_c2.nii.gz
# => Saved to labels_output/187_M_H20_out_c3.nii.gz
# => Saved to labels_output/187_M_H20_out.nii.gz
# => Saved to labels_output/189_M_J25_out_bg.nii.gz
# => Saved to labels_output/189_M_J25_out_c1.nii.gz
# => Saved to labels_output/189_M_J25_out_c2.nii.gz
# => Saved to labels_output/189_M_J25_out_c3.nii.gz
# => Saved to labels_output/189_M_J25_out.nii.gz
# => Saved to labels_output/195_F_O21_out_bg.nii.gz
# => Saved to labels_output/195_F_O21_out_c1.nii.gz
# => Saved to labels_output/195_F_O21_out_c2.nii.gz
# => Saved to labels_output/195_F_O21_out_c3.nii.gz
# => Saved to labels_output/195_F_O21_out.nii.gz
# => Saved to labels_output/196_F_O22_out_bg.nii.gz
# => Saved to labels_output/196_F_O22_out_c1.nii.gz
# => Saved to labels_output/196_F_O22_out_c2.nii.gz
# => Saved to labels_output/196_F_O22_out_c3.nii.gz
# => Saved to labels_output/196_F_O22_out.nii.gz
# => Saved to labels_output/197_M_E11_out_bg.nii.gz
# => Saved to labels_output/197_M_E11_out_c1.nii.gz
# => Saved to labels_output/197_M_E11_out_c2.nii.gz
# => Saved to labels_output/197_M_E11_out_c3.nii.gz
# => Saved to labels_output/197_M_E11_out.nii.gz
# => Saved to labels_output/198_M_E14_out_bg.nii.gz
# => Saved to labels_output/198_M_E14_out_c1.nii.gz
# => Saved to labels_output/198_M_E14_out_c2.nii.gz
# => Saved to labels_output/198_M_E14_out_c3.nii.gz
# => Saved to labels_output/198_M_E14_out.nii.gz
# => Saved to labels_output/199_M_E12_out_bg.nii.gz
# => Saved to labels_output/199_M_E12_out_c1.nii.gz
# => Saved to labels_output/199_M_E12_out_c2.nii.gz
# => Saved to labels_output/199_M_E12_out_c3.nii.gz
# => Saved to labels_output/199_M_E12_out.nii.gz
# => Saved to labels_output/201_F_O25_out_bg.nii.gz
# => Saved to labels_output/201_F_O25_out_c1.nii.gz
# => Saved to labels_output/201_F_O25_out_c2.nii.gz
# => Saved to labels_output/201_F_O25_out_c3.nii.gz
# => Saved to labels_output/201_F_O25_out.nii.gz
# => Saved to labels_output/202_F_O23_out_bg.nii.gz
# => Saved to labels_output/202_F_O23_out_c1.nii.gz
# => Saved to labels_output/202_F_O23_out_c2.nii.gz
# => Saved to labels_output/202_F_O23_out_c3.nii.gz
# => Saved to labels_output/202_F_O23_out.nii.gz
# => Saved to labels_output/203_F_O24_out_bg.nii.gz
# => Saved to labels_output/203_F_O24_out_c1.nii.gz
# => Saved to labels_output/203_F_O24_out_c2.nii.gz
# => Saved to labels_output/203_F_O24_out_c3.nii.gz
# => Saved to labels_output/203_F_O24_out.nii.gz
# => Saved to labels_output/207_M_P1_out_bg.nii.gz
# => Saved to labels_output/207_M_P1_out_c1.nii.gz
# => Saved to labels_output/207_M_P1_out_c2.nii.gz
# => Saved to labels_output/207_M_P1_out_c3.nii.gz
# => Saved to labels_output/207_M_P1_out.nii.gz
# => Saved to labels_output/208_M_Q4_out_bg.nii.gz
# => Saved to labels_output/208_M_Q4_out_c1.nii.gz
# => Saved to labels_output/208_M_Q4_out_c2.nii.gz
# => Saved to labels_output/208_M_Q4_out_c3.nii.gz
# => Saved to labels_output/208_M_Q4_out.nii.gz
# => Saved to labels_output/209_M_P2_out_bg.nii.gz
# => Saved to labels_output/209_M_P2_out_c1.nii.gz
# => Saved to labels_output/209_M_P2_out_c2.nii.gz
# => Saved to labels_output/209_M_P2_out_c3.nii.gz
# => Saved to labels_output/209_M_P2_out.nii.gz
# => Saved to labels_output/213_F_AE16_out_bg.nii.gz
# => Saved to labels_output/213_F_AE16_out_c1.nii.gz
# => Saved to labels_output/213_F_AE16_out_c2.nii.gz
# => Saved to labels_output/213_F_AE16_out_c3.nii.gz
# => Saved to labels_output/213_F_AE16_out.nii.gz
# => Saved to labels_output/214_F_AE17_out_bg.nii.gz
# => Saved to labels_output/214_F_AE17_out_c1.nii.gz
# => Saved to labels_output/214_F_AE17_out_c2.nii.gz
# => Saved to labels_output/214_F_AE17_out_c3.nii.gz
# => Saved to labels_output/214_F_AE17_out.nii.gz
# => Saved to labels_output/215_F_AE18_out_bg.nii.gz
# => Saved to labels_output/215_F_AE18_out_c1.nii.gz
# => Saved to labels_output/215_F_AE18_out_c2.nii.gz
# => Saved to labels_output/215_F_AE18_out_c3.nii.gz
# => Saved to labels_output/215_F_AE18_out.nii.gz
# => Saved to labels_output/216_F_AE19_out_bg.nii.gz
# => Saved to labels_output/216_F_AE19_out_c1.nii.gz
# => Saved to labels_output/216_F_AE19_out_c2.nii.gz
# => Saved to labels_output/216_F_AE19_out_c3.nii.gz
# => Saved to labels_output/216_F_AE19_out.nii.gz
# => Saved to labels_output/220_M_P3_out_bg.nii.gz
# => Saved to labels_output/220_M_P3_out_c1.nii.gz
# => Saved to labels_output/220_M_P3_out_c2.nii.gz
# => Saved to labels_output/220_M_P3_out_c3.nii.gz
# => Saved to labels_output/220_M_P3_out.nii.gz
# => Saved to labels_output/221_M_Q5_out_bg.nii.gz
# => Saved to labels_output/221_M_Q5_out_c1.nii.gz
# => Saved to labels_output/221_M_Q5_out_c2.nii.gz
# => Saved to labels_output/221_M_Q5_out_c3.nii.gz
# => Saved to labels_output/221_M_Q5_out.nii.gz
# => Saved to labels_output/223_M_AA23_out_bg.nii.gz
# => Saved to labels_output/223_M_AA23_out_c1.nii.gz
# => Saved to labels_output/223_M_AA23_out_c2.nii.gz
# => Saved to labels_output/223_M_AA23_out_c3.nii.gz
# => Saved to labels_output/223_M_AA23_out.nii.gz
# => Saved to labels_output/226_F_AE20_out_bg.nii.gz
# => Saved to labels_output/226_F_AE20_out_c1.nii.gz
# => Saved to labels_output/226_F_AE20_out_c2.nii.gz
# => Saved to labels_output/226_F_AE20_out_c3.nii.gz
# => Saved to labels_output/226_F_AE20_out.nii.gz
# => Saved to labels_output/227_F_AB1_out_bg.nii.gz
# => Saved to labels_output/227_F_AB1_out_c1.nii.gz
# => Saved to labels_output/227_F_AB1_out_c2.nii.gz
# => Saved to labels_output/227_F_AB1_out_c3.nii.gz
# => Saved to labels_output/227_F_AB1_out.nii.gz
# => Saved to labels_output/231_M_AA24_out_bg.nii.gz
# => Saved to labels_output/231_M_AA24_out_c1.nii.gz
# => Saved to labels_output/231_M_AA24_out_c2.nii.gz
# => Saved to labels_output/231_M_AA24_out_c3.nii.gz
# => Saved to labels_output/231_M_AA24_out.nii.gz
# => Saved to labels_output/234_F_AB2_out_bg.nii.gz
# => Saved to labels_output/234_F_AB2_out_c1.nii.gz
# => Saved to labels_output/234_F_AB2_out_c2.nii.gz
# => Saved to labels_output/234_F_AB2_out_c3.nii.gz
# => Saved to labels_output/234_F_AB2_out.nii.gz
# => Saved to labels_output/235_F_AB3_out_bg.nii.gz
# => Saved to labels_output/235_F_AB3_out_c1.nii.gz
# => Saved to labels_output/235_F_AB3_out_c2.nii.gz
# => Saved to labels_output/235_F_AB3_out_c3.nii.gz
# => Saved to labels_output/235_F_AB3_out.nii.gz
# => Saved to labels_output/236_F_AB4_out_bg.nii.gz
# => Saved to labels_output/236_F_AB4_out_c1.nii.gz
# => Saved to labels_output/236_F_AB4_out_c2.nii.gz
# => Saved to labels_output/236_F_AB4_out_c3.nii.gz
# => Saved to labels_output/236_F_AB4_out.nii.gz
# => Saved to labels_output/237_F_AB5_out_bg.nii.gz
# => Saved to labels_output/237_F_AB5_out_c1.nii.gz
# => Saved to labels_output/237_F_AB5_out_c2.nii.gz
# => Saved to labels_output/237_F_AB5_out_c3.nii.gz
# => Saved to labels_output/237_F_AB5_out.nii.gz
# => Saved to labels_output/239_M_R6_out_bg.nii.gz
# => Saved to labels_output/239_M_R6_out_c1.nii.gz
# => Saved to labels_output/239_M_R6_out_c2.nii.gz
# => Saved to labels_output/239_M_R6_out_c3.nii.gz
# => Saved to labels_output/239_M_R6_out.nii.gz
# => Saved to labels_output/240_M_R7_out_bg.nii.gz
# => Saved to labels_output/240_M_R7_out_c1.nii.gz
# => Saved to labels_output/240_M_R7_out_c2.nii.gz
# => Saved to labels_output/240_M_R7_out_c3.nii.gz
# => Saved to labels_output/240_M_R7_out.nii.gz
# => Saved to labels_output/241_F_AC6_out_bg.nii.gz
# => Saved to labels_output/241_F_AC6_out_c1.nii.gz
# => Saved to labels_output/241_F_AC6_out_c2.nii.gz
# => Saved to labels_output/241_F_AC6_out_c3.nii.gz
# => Saved to labels_output/241_F_AC6_out.nii.gz
# => Saved to labels_output/242_F_AC7_out_bg.nii.gz
# => Saved to labels_output/242_F_AC7_out_c1.nii.gz
# => Saved to labels_output/242_F_AC7_out_c2.nii.gz
# => Saved to labels_output/242_F_AC7_out_c3.nii.gz
# => Saved to labels_output/242_F_AC7_out.nii.gz
# => Saved to labels_output/243_F_AC8_out_bg.nii.gz
# => Saved to labels_output/243_F_AC8_out_c1.nii.gz
# => Saved to labels_output/243_F_AC8_out_c2.nii.gz
# => Saved to labels_output/243_F_AC8_out_c3.nii.gz
# => Saved to labels_output/243_F_AC8_out.nii.gz
# => Saved to labels_output/244_M_R8_out_bg.nii.gz
# => Saved to labels_output/244_M_R8_out_c1.nii.gz
# => Saved to labels_output/244_M_R8_out_c2.nii.gz
# => Saved to labels_output/244_M_R8_out_c3.nii.gz
# => Saved to labels_output/244_M_R8_out.nii.gz
# => Saved to labels_output/246_M_S10_out_bg.nii.gz
# => Saved to labels_output/246_M_S10_out_c1.nii.gz
# => Saved to labels_output/246_M_S10_out_c2.nii.gz
# => Saved to labels_output/246_M_S10_out_c3.nii.gz
# => Saved to labels_output/246_M_S10_out.nii.gz
# => Saved to labels_output/247_M_Z22_out_bg.nii.gz
# => Saved to labels_output/247_M_Z22_out_c1.nii.gz
# => Saved to labels_output/247_M_Z22_out_c2.nii.gz
# => Saved to labels_output/247_M_Z22_out_c3.nii.gz
# => Saved to labels_output/247_M_Z22_out.nii.gz
# => Saved to labels_output/250_F_AC9_out_bg.nii.gz
# => Saved to labels_output/250_F_AC9_out_c1.nii.gz
# => Saved to labels_output/250_F_AC9_out_c2.nii.gz
# => Saved to labels_output/250_F_AC9_out_c3.nii.gz
# => Saved to labels_output/250_F_AC9_out.nii.gz
# => Saved to labels_output/251_F_AC10_out_bg.nii.gz
# => Saved to labels_output/251_F_AC10_out_c1.nii.gz
# => Saved to labels_output/251_F_AC10_out_c2.nii.gz
# => Saved to labels_output/251_F_AC10_out_c3.nii.gz
# => Saved to labels_output/251_F_AC10_out.nii.gz
# => Saved to labels_output/252_M_T11_out_bg.nii.gz
# => Saved to labels_output/252_M_T11_out_c1.nii.gz
# => Saved to labels_output/252_M_T11_out_c2.nii.gz
# => Saved to labels_output/252_M_T11_out_c3.nii.gz
# => Saved to labels_output/252_M_T11_out.nii.gz
# => Saved to labels_output/253_M_T12_out_bg.nii.gz
# => Saved to labels_output/253_M_T12_out_c1.nii.gz
# => Saved to labels_output/253_M_T12_out_c2.nii.gz
# => Saved to labels_output/253_M_T12_out_c3.nii.gz
# => Saved to labels_output/253_M_T12_out.nii.gz
# => Saved to labels_output/254_M_U13_out_bg.nii.gz
# => Saved to labels_output/254_M_U13_out_c1.nii.gz
# => Saved to labels_output/254_M_U13_out_c2.nii.gz
# => Saved to labels_output/254_M_U13_out_c3.nii.gz
# => Saved to labels_output/254_M_U13_out.nii.gz
# => Saved to labels_output/257_F_AD11_out_bg.nii.gz
# => Saved to labels_output/257_F_AD11_out_c1.nii.gz
# => Saved to labels_output/257_F_AD11_out_c2.nii.gz
# => Saved to labels_output/257_F_AD11_out_c3.nii.gz
# => Saved to labels_output/257_F_AD11_out.nii.gz
# => Saved to labels_output/258_F_AD12_out_bg.nii.gz
# => Saved to labels_output/258_F_AD12_out_c1.nii.gz
# => Saved to labels_output/258_F_AD12_out_c2.nii.gz
# => Saved to labels_output/258_F_AD12_out_c3.nii.gz
# => Saved to labels_output/258_F_AD12_out.nii.gz
# => Saved to labels_output/259_F_AD1_out_bg.nii.gz
# => Saved to labels_output/259_F_AD1_out_c1.nii.gz
# => Saved to labels_output/259_F_AD1_out_c2.nii.gz
# => Saved to labels_output/259_F_AD1_out_c3.nii.gz
# => Saved to labels_output/259_F_AD1_out.nii.gz
# => Saved to labels_output/263_F_AD14_out_bg.nii.gz
# => Saved to labels_output/263_F_AD14_out_c1.nii.gz
# => Saved to labels_output/263_F_AD14_out_c2.nii.gz
# => Saved to labels_output/263_F_AD14_out_c3.nii.gz
# => Saved to labels_output/263_F_AD14_out.nii.gz
# => Saved to labels_output/265_M_U15_out_bg.nii.gz
# => Saved to labels_output/265_M_U15_out_c1.nii.gz
# => Saved to labels_output/265_M_U15_out_c2.nii.gz
# => Saved to labels_output/265_M_U15_out_c3.nii.gz
# => Saved to labels_output/265_M_U15_out.nii.gz
# => Saved to labels_output/266_M_W16_out_bg.nii.gz
# => Saved to labels_output/266_M_W16_out_c1.nii.gz
# => Saved to labels_output/266_M_W16_out_c2.nii.gz
# => Saved to labels_output/266_M_W16_out_c3.nii.gz
# => Saved to labels_output/266_M_W16_out.nii.gz
# => Saved to labels_output/269_F_AD15_out_bg.nii.gz
# => Saved to labels_output/269_F_AD15_out_c1.nii.gz
# => Saved to labels_output/269_F_AD15_out_c2.nii.gz
# => Saved to labels_output/269_F_AD15_out_c3.nii.gz
# => Saved to labels_output/269_F_AD15_out.nii.gz
# => Saved to labels_output/270_F_AF21_out_bg.nii.gz
# => Saved to labels_output/270_F_AF21_out_c1.nii.gz
# => Saved to labels_output/270_F_AF21_out_c2.nii.gz
# => Saved to labels_output/270_F_AF21_out_c3.nii.gz
# => Saved to labels_output/270_F_AF21_out.nii.gz
# => Saved to labels_output/271_F_AF22_out_bg.nii.gz
# => Saved to labels_output/271_F_AF22_out_c1.nii.gz
# => Saved to labels_output/271_F_AF22_out_c2.nii.gz
# => Saved to labels_output/271_F_AF22_out_c3.nii.gz
# => Saved to labels_output/271_F_AF22_out.nii.gz
# => Saved to labels_output/274_M_X17_out_bg.nii.gz
# => Saved to labels_output/274_M_X17_out_c1.nii.gz
# => Saved to labels_output/274_M_X17_out_c2.nii.gz
# => Saved to labels_output/274_M_X17_out_c3.nii.gz
# => Saved to labels_output/274_M_X17_out.nii.gz
# => Saved to labels_output/275_M_Y20_out_bg.nii.gz
# => Saved to labels_output/275_M_Y20_out_c1.nii.gz
# => Saved to labels_output/275_M_Y20_out_c2.nii.gz
# => Saved to labels_output/275_M_Y20_out_c3.nii.gz
# => Saved to labels_output/275_M_Y20_out.nii.gz
# => Saved to labels_output/276_M_Y19_out_bg.nii.gz
# => Saved to labels_output/276_M_Y19_out_c1.nii.gz
# => Saved to labels_output/276_M_Y19_out_c2.nii.gz
# => Saved to labels_output/276_M_Y19_out_c3.nii.gz
# => Saved to labels_output/276_M_Y19_out.nii.gz
# => Saved to labels_output/277_M_X18_out_bg.nii.gz
# => Saved to labels_output/277_M_X18_out_c1.nii.gz
# => Saved to labels_output/277_M_X18_out_c2.nii.gz
# => Saved to labels_output/277_M_X18_out_c3.nii.gz
# => Saved to labels_output/277_M_X18_out.nii.gz
# => Saved to labels_output/280_F_AF23_out_bg.nii.gz
# => Saved to labels_output/280_F_AF23_out_c1.nii.gz
# => Saved to labels_output/280_F_AF23_out_c2.nii.gz
# => Saved to labels_output/280_F_AF23_out_c3.nii.gz
# => Saved to labels_output/280_F_AF23_out.nii.gz
# => Saved to labels_output/281_F_AF24_out_bg.nii.gz
# => Saved to labels_output/281_F_AF24_out_c1.nii.gz
# => Saved to labels_output/281_F_AF24_out_c2.nii.gz
# => Saved to labels_output/281_F_AF24_out_c3.nii.gz
# => Saved to labels_output/281_F_AF24_out.nii.gz
# => Saved to labels_output/282_F_AF25_out_bg.nii.gz
# => Saved to labels_output/282_F_AF25_out_c1.nii.gz
# => Saved to labels_output/282_F_AF25_out_c2.nii.gz
# => Saved to labels_output/282_F_AF25_out_c3.nii.gz
# => Saved to labels_output/282_F_AF25_out.nii.gz
# => Saved to labels_output/284_M_AK11_out_bg.nii.gz
# => Saved to labels_output/284_M_AK11_out_c1.nii.gz
# => Saved to labels_output/284_M_AK11_out_c2.nii.gz
# => Saved to labels_output/284_M_AK11_out_c3.nii.gz
# => Saved to labels_output/284_M_AK11_out.nii.gz
# => Saved to labels_output/285_M_AK12_out_bg.nii.gz
# => Saved to labels_output/285_M_AK12_out_c1.nii.gz
# => Saved to labels_output/285_M_AK12_out_c2.nii.gz
# => Saved to labels_output/285_M_AK12_out_c3.nii.gz
# => Saved to labels_output/285_M_AK12_out.nii.gz
# => Saved to labels_output/287_F_AR6_out_bg.nii.gz
# => Saved to labels_output/287_F_AR6_out_c1.nii.gz
# => Saved to labels_output/287_F_AR6_out_c2.nii.gz
# => Saved to labels_output/287_F_AR6_out_c3.nii.gz
# => Saved to labels_output/287_F_AR6_out.nii.gz
# => Saved to labels_output/289_F_AQ_out_bg.nii.gz
# => Saved to labels_output/289_F_AQ_out_c1.nii.gz
# => Saved to labels_output/289_F_AQ_out_c2.nii.gz
# => Saved to labels_output/289_F_AQ_out_c3.nii.gz
# => Saved to labels_output/289_F_AQ_out.nii.gz
# => Saved to labels_output/295_M_AI17_out_bg.nii.gz
# => Saved to labels_output/295_M_AI17_out_c1.nii.gz
# => Saved to labels_output/295_M_AI17_out_c2.nii.gz
# => Saved to labels_output/295_M_AI17_out_c3.nii.gz
# => Saved to labels_output/295_M_AI17_out.nii.gz
# => Saved to labels_output/296_M_AI18_out_bg.nii.gz
# => Saved to labels_output/296_M_AI18_out_c1.nii.gz
# => Saved to labels_output/296_M_AI18_out_c2.nii.gz
# => Saved to labels_output/296_M_AI18_out_c3.nii.gz
# => Saved to labels_output/296_M_AI18_out.nii.gz
# => Saved to labels_output/297_M_AK13_out_bg.nii.gz
# => Saved to labels_output/297_M_AK13_out_c1.nii.gz
# => Saved to labels_output/297_M_AK13_out_c2.nii.gz
# => Saved to labels_output/297_M_AK13_out_c3.nii.gz
# => Saved to labels_output/297_M_AK13_out.nii.gz
# => Saved to labels_output/301_F_AR7_out_bg.nii.gz
# => Saved to labels_output/301_F_AR7_out_c1.nii.gz
# => Saved to labels_output/301_F_AR7_out_c2.nii.gz
# => Saved to labels_output/301_F_AR7_out_c3.nii.gz
# => Saved to labels_output/301_F_AR7_out.nii.gz
# => Saved to labels_output/304_F_AQ2_out_bg.nii.gz
# => Saved to labels_output/304_F_AQ2_out_c1.nii.gz
# => Saved to labels_output/304_F_AQ2_out_c2.nii.gz
# => Saved to labels_output/304_F_AQ2_out_c3.nii.gz
# => Saved to labels_output/304_F_AQ2_out.nii.gz
# => Saved to labels_output/306_M_AJ9_out_bg.nii.gz
# => Saved to labels_output/306_M_AJ9_out_c1.nii.gz
# => Saved to labels_output/306_M_AJ9_out_c2.nii.gz
# => Saved to labels_output/306_M_AJ9_out_c3.nii.gz
# => Saved to labels_output/306_M_AJ9_out.nii.gz
# => Saved to labels_output/307_M_AL14_out_bg.nii.gz
# => Saved to labels_output/307_M_AL14_out_c1.nii.gz
# => Saved to labels_output/307_M_AL14_out_c2.nii.gz
# => Saved to labels_output/307_M_AL14_out_c3.nii.gz
# => Saved to labels_output/307_M_AL14_out.nii.gz
# => Saved to labels_output/310_F_AR8_out_bg.nii.gz
# => Saved to labels_output/310_F_AR8_out_c1.nii.gz
# => Saved to labels_output/310_F_AR8_out_c2.nii.gz
# => Saved to labels_output/310_F_AR8_out_c3.nii.gz
# => Saved to labels_output/310_F_AR8_out.nii.gz
# => Saved to labels_output/312_F_AQ3_out_bg.nii.gz
# => Saved to labels_output/312_F_AQ3_out_c1.nii.gz
# => Saved to labels_output/312_F_AQ3_out_c2.nii.gz
# => Saved to labels_output/312_F_AQ3_out_c3.nii.gz
# => Saved to labels_output/312_F_AQ3_out.nii.gz
# => Saved to labels_output/316_M_AJ9_out_bg.nii.gz
# => Saved to labels_output/316_M_AJ9_out_c1.nii.gz
# => Saved to labels_output/316_M_AJ9_out_c2.nii.gz
# => Saved to labels_output/316_M_AJ9_out_c3.nii.gz
# => Saved to labels_output/316_M_AJ9_out.nii.gz
# => Saved to labels_output/317_M_AL15_out_bg.nii.gz
# => Saved to labels_output/317_M_AL15_out_c1.nii.gz
# => Saved to labels_output/317_M_AL15_out_c2.nii.gz
# => Saved to labels_output/317_M_AL15_out_c3.nii.gz
# => Saved to labels_output/317_M_AL15_out.nii.gz
# => Saved to labels_output/318_F_AR9_out_bg.nii.gz
# => Saved to labels_output/318_F_AR9_out_c1.nii.gz
# => Saved to labels_output/318_F_AR9_out_c2.nii.gz
# => Saved to labels_output/318_F_AR9_out_c3.nii.gz
# => Saved to labels_output/318_F_AR9_out.nii.gz
# => Saved to labels_output/322_F_AQ5_out_bg.nii.gz
# => Saved to labels_output/322_F_AQ5_out_c1.nii.gz
# => Saved to labels_output/322_F_AQ5_out_c2.nii.gz
# => Saved to labels_output/322_F_AQ5_out_c3.nii.gz
# => Saved to labels_output/322_F_AQ5_out.nii.gz
# => Saved to labels_output/324_M_AM16_out_bg.nii.gz
# => Saved to labels_output/324_M_AM16_out_c1.nii.gz
# => Saved to labels_output/324_M_AM16_out_c2.nii.gz
# => Saved to labels_output/324_M_AM16_out_c3.nii.gz
# => Saved to labels_output/324_M_AM16_out.nii.gz
# => Saved to labels_output/326_M_AO21_out_bg.nii.gz
# => Saved to labels_output/326_M_AO21_out_c1.nii.gz
# => Saved to labels_output/326_M_AO21_out_c2.nii.gz
# => Saved to labels_output/326_M_AO21_out_c3.nii.gz
# => Saved to labels_output/326_M_AO21_out.nii.gz
# => Saved to labels_output/328_F_AT16_out_bg.nii.gz
# => Saved to labels_output/328_F_AT16_out_c1.nii.gz
# => Saved to labels_output/328_F_AT16_out_c2.nii.gz
# => Saved to labels_output/328_F_AT16_out_c3.nii.gz
# => Saved to labels_output/328_F_AT16_out.nii.gz
# => Saved to labels_output/329_F_AS11_out_bg.nii.gz
# => Saved to labels_output/329_F_AS11_out_c1.nii.gz
# => Saved to labels_output/329_F_AS11_out_c2.nii.gz
# => Saved to labels_output/329_F_AS11_out_c3.nii.gz
# => Saved to labels_output/329_F_AS11_out.nii.gz
# => Saved to labels_output/333_M_AN18_out_bg.nii.gz
# => Saved to labels_output/333_M_AN18_out_c1.nii.gz
# => Saved to labels_output/333_M_AN18_out_c2.nii.gz
# => Saved to labels_output/333_M_AN18_out_c3.nii.gz
# => Saved to labels_output/333_M_AN18_out.nii.gz
# => Saved to labels_output/335_F_AT17_out_bg.nii.gz
# => Saved to labels_output/335_F_AT17_out_c1.nii.gz
# => Saved to labels_output/335_F_AT17_out_c2.nii.gz
# => Saved to labels_output/335_F_AT17_out_c3.nii.gz
# => Saved to labels_output/335_F_AT17_out.nii.gz
# => Saved to labels_output/336_F_AS12_out_bg.nii.gz
# => Saved to labels_output/336_F_AS12_out_c1.nii.gz
# => Saved to labels_output/336_F_AS12_out_c2.nii.gz
# => Saved to labels_output/336_F_AS12_out_c3.nii.gz
# => Saved to labels_output/336_F_AS12_out.nii.gz
# => Saved to labels_output/340_M_AN19_out_bg.nii.gz
# => Saved to labels_output/340_M_AN19_out_c1.nii.gz
# => Saved to labels_output/340_M_AN19_out_c2.nii.gz
# => Saved to labels_output/340_M_AN19_out_c3.nii.gz
# => Saved to labels_output/340_M_AN19_out.nii.gz
# => Saved to labels_output/342_M_AO22_out_bg.nii.gz
# => Saved to labels_output/342_M_AO22_out_c1.nii.gz
# => Saved to labels_output/342_M_AO22_out_c2.nii.gz
# => Saved to labels_output/342_M_AO22_out_c3.nii.gz
# => Saved to labels_output/342_M_AO22_out.nii.gz
# => Saved to labels_output/344_M_AG2_out_bg.nii.gz
# => Saved to labels_output/344_M_AG2_out_c1.nii.gz
# => Saved to labels_output/344_M_AG2_out_c2.nii.gz
# => Saved to labels_output/344_M_AG2_out_c3.nii.gz
# => Saved to labels_output/344_M_AG2_out.nii.gz
# => Saved to labels_output/350_F_AT18_out_bg.nii.gz
# => Saved to labels_output/350_F_AT18_out_c1.nii.gz
# => Saved to labels_output/350_F_AT18_out_c2.nii.gz
# => Saved to labels_output/350_F_AT18_out_c3.nii.gz
# => Saved to labels_output/350_F_AT18_out.nii.gz
# => Saved to labels_output/351_F_AU21_out_bg.nii.gz
# => Saved to labels_output/351_F_AU21_out_c1.nii.gz
# => Saved to labels_output/351_F_AU21_out_c2.nii.gz
# => Saved to labels_output/351_F_AU21_out_c3.nii.gz
# => Saved to labels_output/351_F_AU21_out.nii.gz
# => Saved to labels_output/353_M_AN20_out_bg.nii.gz
# => Saved to labels_output/353_M_AN20_out_c1.nii.gz
# => Saved to labels_output/353_M_AN20_out_c2.nii.gz
# => Saved to labels_output/353_M_AN20_out_c3.nii.gz
# => Saved to labels_output/353_M_AN20_out.nii.gz
# => Saved to labels_output/355_M_AP24_out_bg.nii.gz
# => Saved to labels_output/355_M_AP24_out_c1.nii.gz
# => Saved to labels_output/355_M_AP24_out_c2.nii.gz
# => Saved to labels_output/355_M_AP24_out_c3.nii.gz
# => Saved to labels_output/355_M_AP24_out.nii.gz
# => Saved to labels_output/359_F_AT19_out_bg.nii.gz
# => Saved to labels_output/359_F_AT19_out_c1.nii.gz
# => Saved to labels_output/359_F_AT19_out_c2.nii.gz
# => Saved to labels_output/359_F_AT19_out_c3.nii.gz
# => Saved to labels_output/359_F_AT19_out.nii.gz
# => Saved to labels_output/360_F_AU22_out_bg.nii.gz
# => Saved to labels_output/360_F_AU22_out_c1.nii.gz
# => Saved to labels_output/360_F_AU22_out_c2.nii.gz
# => Saved to labels_output/360_F_AU22_out_c3.nii.gz
# => Saved to labels_output/360_F_AU22_out.nii.gz
# => Saved to labels_output/368_M_AM17_out_bg.nii.gz
# => Saved to labels_output/368_M_AM17_out_c1.nii.gz
# => Saved to labels_output/368_M_AM17_out_c2.nii.gz
# => Saved to labels_output/368_M_AM17_out_c3.nii.gz
# => Saved to labels_output/368_M_AM17_out.nii.gz
# => Saved to labels_output/370_F_AT20_out_bg.nii.gz
# => Saved to labels_output/370_F_AT20_out_c1.nii.gz
# => Saved to labels_output/370_F_AT20_out_c2.nii.gz
# => Saved to labels_output/370_F_AT20_out_c3.nii.gz
# => Saved to labels_output/370_F_AT20_out.nii.gz
# => Saved to labels_output/371_F_AU23_out_bg.nii.gz
# => Saved to labels_output/371_F_AU23_out_c1.nii.gz
# => Saved to labels_output/371_F_AU23_out_c2.nii.gz
# => Saved to labels_output/371_F_AU23_out_c3.nii.gz
# => Saved to labels_output/371_F_AU23_out.nii.gz
# => Saved to labels_output/373_F_AS14_out_bg.nii.gz
# => Saved to labels_output/373_F_AS14_out_c1.nii.gz
# => Saved to labels_output/373_F_AS14_out_c2.nii.gz
# => Saved to labels_output/373_F_AS14_out_c3.nii.gz
# => Saved to labels_output/373_F_AS14_out.nii.gz
# => Saved to labels_output/378_M_AH5_out_bg.nii.gz
# => Saved to labels_output/378_M_AH5_out_c1.nii.gz
# => Saved to labels_output/378_M_AH5_out_c2.nii.gz
# => Saved to labels_output/378_M_AH5_out_c3.nii.gz
# => Saved to labels_output/378_M_AH5_out.nii.gz
# => Saved to labels_output/379_M_AG2_out_bg.nii.gz
# => Saved to labels_output/379_M_AG2_out_c1.nii.gz
# => Saved to labels_output/379_M_AG2_out_c2.nii.gz
# => Saved to labels_output/379_M_AG2_out_c3.nii.gz
# => Saved to labels_output/379_M_AG2_out.nii.gz
# => Saved to labels_output/380_F_AU24_out_bg.nii.gz
# => Saved to labels_output/380_F_AU24_out_c1.nii.gz
# => Saved to labels_output/380_F_AU24_out_c2.nii.gz
# => Saved to labels_output/380_F_AU24_out_c3.nii.gz
# => Saved to labels_output/380_F_AU24_out.nii.gz
# => Saved to labels_output/387_M_AG3_out_bg.nii.gz
# => Saved to labels_output/387_M_AG3_out_c1.nii.gz
# => Saved to labels_output/387_M_AG3_out_c2.nii.gz
# => Saved to labels_output/387_M_AG3_out_c3.nii.gz
# => Saved to labels_output/387_M_AG3_out.nii.gz
# => Saved to labels_output/392_F_AU25_out_bg.nii.gz
# => Saved to labels_output/392_F_AU25_out_c1.nii.gz
# => Saved to labels_output/392_F_AU25_out_c2.nii.gz
# => Saved to labels_output/392_F_AU25_out_c3.nii.gz
# => Saved to labels_output/392_F_AU25_out.nii.gz
# => Saved to labels_output/400_M_AX6_out_bg.nii.gz
# => Saved to labels_output/400_M_AX6_out_c1.nii.gz
# => Saved to labels_output/400_M_AX6_out_c2.nii.gz
# => Saved to labels_output/400_M_AX6_out_c3.nii.gz
# => Saved to labels_output/400_M_AX6_out.nii.gz
# => Saved to labels_output/402_F_BI16_out_bg.nii.gz
# => Saved to labels_output/402_F_BI16_out_c1.nii.gz
# => Saved to labels_output/402_F_BI16_out_c2.nii.gz
# => Saved to labels_output/402_F_BI16_out_c3.nii.gz
# => Saved to labels_output/402_F_BI16_out.nii.gz
# => Saved to labels_output/403_F_BJ21_out_bg.nii.gz
# => Saved to labels_output/403_F_BJ21_out_c1.nii.gz
# => Saved to labels_output/403_F_BJ21_out_c2.nii.gz
# => Saved to labels_output/403_F_BJ21_out_c3.nii.gz
# => Saved to labels_output/403_F_BJ21_out.nii.gz
# => Saved to labels_output/405_F_BH11_out_bg.nii.gz
# => Saved to labels_output/405_F_BH11_out_c1.nii.gz
# => Saved to labels_output/405_F_BH11_out_c2.nii.gz
# => Saved to labels_output/405_F_BH11_out_c3.nii.gz
# => Saved to labels_output/405_F_BH11_out.nii.gz
# => Saved to labels_output/407_M_AV2_out_bg.nii.gz
# => Saved to labels_output/407_M_AV2_out_c1.nii.gz
# => Saved to labels_output/407_M_AV2_out_c2.nii.gz
# => Saved to labels_output/407_M_AV2_out_c3.nii.gz
# => Saved to labels_output/407_M_AV2_out.nii.gz
# => Saved to labels_output/409_M_AZ12_out_bg.nii.gz
# => Saved to labels_output/409_M_AZ12_out_c1.nii.gz
# => Saved to labels_output/409_M_AZ12_out_c2.nii.gz
# => Saved to labels_output/409_M_AZ12_out_c3.nii.gz
# => Saved to labels_output/409_M_AZ12_out.nii.gz
# => Saved to labels_output/410_M_AX7_out_bg.nii.gz
# => Saved to labels_output/410_M_AX7_out_c1.nii.gz
# => Saved to labels_output/410_M_AX7_out_c2.nii.gz
# => Saved to labels_output/410_M_AX7_out_c3.nii.gz
# => Saved to labels_output/410_M_AX7_out.nii.gz
# => Saved to labels_output/412_F_BI17_out_bg.nii.gz
# => Saved to labels_output/412_F_BI17_out_c1.nii.gz
# => Saved to labels_output/412_F_BI17_out_c2.nii.gz
# => Saved to labels_output/412_F_BI17_out_c3.nii.gz
# => Saved to labels_output/412_F_BI17_out.nii.gz
# => Saved to labels_output/413_F_BJ22_out_bg.nii.gz
# => Saved to labels_output/413_F_BJ22_out_c1.nii.gz
# => Saved to labels_output/413_F_BJ22_out_c2.nii.gz
# => Saved to labels_output/413_F_BJ22_out_c3.nii.gz
# => Saved to labels_output/413_F_BJ22_out.nii.gz
# => Saved to labels_output/416_F_BH12_out_bg.nii.gz
# => Saved to labels_output/416_F_BH12_out_c1.nii.gz
# => Saved to labels_output/416_F_BH12_out_c2.nii.gz
# => Saved to labels_output/416_F_BH12_out_c3.nii.gz
# => Saved to labels_output/416_F_BH12_out.nii.gz
# => Saved to labels_output/418_M_AW4_out_bg.nii.gz
# => Saved to labels_output/418_M_AW4_out_c1.nii.gz
# => Saved to labels_output/418_M_AW4_out_c2.nii.gz
# => Saved to labels_output/418_M_AW4_out_c3.nii.gz
# => Saved to labels_output/418_M_AW4_out.nii.gz
# => Saved to labels_output/419_M_AZ12_out_bg.nii.gz
# => Saved to labels_output/419_M_AZ12_out_c1.nii.gz
# => Saved to labels_output/419_M_AZ12_out_c2.nii.gz
# => Saved to labels_output/419_M_AZ12_out_c3.nii.gz
# => Saved to labels_output/419_M_AZ12_out.nii.gz
# => Saved to labels_output/420_M_AX8_out_bg.nii.gz
# => Saved to labels_output/420_M_AX8_out_c1.nii.gz
# => Saved to labels_output/420_M_AX8_out_c2.nii.gz
# => Saved to labels_output/420_M_AX8_out_c3.nii.gz
# => Saved to labels_output/420_M_AX8_out.nii.gz
# => Saved to labels_output/421_F_BI18_out_bg.nii.gz
# => Saved to labels_output/421_F_BI18_out_c1.nii.gz
# => Saved to labels_output/421_F_BI18_out_c2.nii.gz
# => Saved to labels_output/421_F_BI18_out_c3.nii.gz
# => Saved to labels_output/421_F_BI18_out.nii.gz
# => Saved to labels_output/424_F_BF1_out_bg.nii.gz
# => Saved to labels_output/424_F_BF1_out_c1.nii.gz
# => Saved to labels_output/424_F_BF1_out_c2.nii.gz
# => Saved to labels_output/424_F_BF1_out_c3.nii.gz
# => Saved to labels_output/424_F_BF1_out.nii.gz
# => Saved to labels_output/425_M_AV3_out_bg.nii.gz
# => Saved to labels_output/425_M_AV3_out_c1.nii.gz
# => Saved to labels_output/425_M_AV3_out_c2.nii.gz
# => Saved to labels_output/425_M_AV3_out_c3.nii.gz
# => Saved to labels_output/425_M_AV3_out.nii.gz
# => Saved to labels_output/426_M_BA13_out_bg.nii.gz
# => Saved to labels_output/426_M_BA13_out_c1.nii.gz
# => Saved to labels_output/426_M_BA13_out_c2.nii.gz
# => Saved to labels_output/426_M_BA13_out_c3.nii.gz
# => Saved to labels_output/426_M_BA13_out.nii.gz
# => Saved to labels_output/429_M_BB16_out_bg.nii.gz
# => Saved to labels_output/429_M_BB16_out_c1.nii.gz
# => Saved to labels_output/429_M_BB16_out_c2.nii.gz
# => Saved to labels_output/429_M_BB16_out_c3.nii.gz
# => Saved to labels_output/429_M_BB16_out.nii.gz
# => Saved to labels_output/430_F_BI19_out_bg.nii.gz
# => Saved to labels_output/430_F_BI19_out_c1.nii.gz
# => Saved to labels_output/430_F_BI19_out_c2.nii.gz
# => Saved to labels_output/430_F_BI19_out_c3.nii.gz
# => Saved to labels_output/430_F_BI19_out.nii.gz
# => Saved to labels_output/433_F_BF2_out_bg.nii.gz
# => Saved to labels_output/433_F_BF2_out_c1.nii.gz
# => Saved to labels_output/433_F_BF2_out_c2.nii.gz
# => Saved to labels_output/433_F_BF2_out_c3.nii.gz
# => Saved to labels_output/433_F_BF2_out.nii.gz
# => Saved to labels_output/435_M_BD21_out_bg.nii.gz
# => Saved to labels_output/435_M_BD21_out_c1.nii.gz
# => Saved to labels_output/435_M_BD21_out_c2.nii.gz
# => Saved to labels_output/435_M_BD21_out_c3.nii.gz
# => Saved to labels_output/435_M_BD21_out.nii.gz
# => Saved to labels_output/436_M_BA14_out_bg.nii.gz
# => Saved to labels_output/436_M_BA14_out_c1.nii.gz
# => Saved to labels_output/436_M_BA14_out_c2.nii.gz
# => Saved to labels_output/436_M_BA14_out_c3.nii.gz
# => Saved to labels_output/436_M_BA14_out.nii.gz
# => Saved to labels_output/438_M_BC19_out_bg.nii.gz
# => Saved to labels_output/438_M_BC19_out_c1.nii.gz
# => Saved to labels_output/438_M_BC19_out_c2.nii.gz
# => Saved to labels_output/438_M_BC19_out_c3.nii.gz
# => Saved to labels_output/438_M_BC19_out.nii.gz
# => Saved to labels_output/442_F_BI20_out_bg.nii.gz
# => Saved to labels_output/442_F_BI20_out_c1.nii.gz
# => Saved to labels_output/442_F_BI20_out_c2.nii.gz
# => Saved to labels_output/442_F_BI20_out_c3.nii.gz
# => Saved to labels_output/442_F_BI20_out.nii.gz
# => Saved to labels_output/443_F_BG6_out_bg.nii.gz
# => Saved to labels_output/443_F_BG6_out_c1.nii.gz
# => Saved to labels_output/443_F_BG6_out_c2.nii.gz
# => Saved to labels_output/443_F_BG6_out_c3.nii.gz
# => Saved to labels_output/443_F_BG6_out.nii.gz
# => Saved to labels_output/445_M_BD22_out_bg.nii.gz
# => Saved to labels_output/445_M_BD22_out_c1.nii.gz
# => Saved to labels_output/445_M_BD22_out_c2.nii.gz
# => Saved to labels_output/445_M_BD22_out_c3.nii.gz
# => Saved to labels_output/445_M_BD22_out.nii.gz
# => Saved to labels_output/446_M_BA15_out_bg.nii.gz
# => Saved to labels_output/446_M_BA15_out_c1.nii.gz
# => Saved to labels_output/446_M_BA15_out_c2.nii.gz
# => Saved to labels_output/446_M_BA15_out_c3.nii.gz
# => Saved to labels_output/446_M_BA15_out.nii.gz
# => Saved to labels_output/452_F_BG7_out_bg.nii.gz
# => Saved to labels_output/452_F_BG7_out_c1.nii.gz
# => Saved to labels_output/452_F_BG7_out_c2.nii.gz
# => Saved to labels_output/452_F_BG7_out_c3.nii.gz
# => Saved to labels_output/452_F_BG7_out.nii.gz
# => Saved to labels_output/456_F_BF3_out_bg.nii.gz
# => Saved to labels_output/456_F_BF3_out_c1.nii.gz
# => Saved to labels_output/456_F_BF3_out_c2.nii.gz
# => Saved to labels_output/456_F_BF3_out_c3.nii.gz
# => Saved to labels_output/456_F_BF3_out.nii.gz
# => Saved to labels_output/458_M_BE24_out_bg.nii.gz
# => Saved to labels_output/458_M_BE24_out_c1.nii.gz
# => Saved to labels_output/458_M_BE24_out_c2.nii.gz
# => Saved to labels_output/458_M_BE24_out_c3.nii.gz
# => Saved to labels_output/458_M_BE24_out.nii.gz
# => Saved to labels_output/461_M_BB18_out_bg.nii.gz
# => Saved to labels_output/461_M_BB18_out_c1.nii.gz
# => Saved to labels_output/461_M_BB18_out_c2.nii.gz
# => Saved to labels_output/461_M_BB18_out_c3.nii.gz
# => Saved to labels_output/461_M_BB18_out.nii.gz
# => Saved to labels_output/463_f_BG8_out_bg.nii.gz
# => Saved to labels_output/463_f_BG8_out_c1.nii.gz
# => Saved to labels_output/463_f_BG8_out_c2.nii.gz
# => Saved to labels_output/463_f_BG8_out_c3.nii.gz
# => Saved to labels_output/463_f_BG8_out.nii.gz
# => Saved to labels_output/466_F_BH16_out_bg.nii.gz
# => Saved to labels_output/466_F_BH16_out_c1.nii.gz
# => Saved to labels_output/466_F_BH16_out_c2.nii.gz
# => Saved to labels_output/466_F_BH16_out_c3.nii.gz
# => Saved to labels_output/466_F_BH16_out.nii.gz
# => Saved to labels_output/468_M_BE25_out_bg.nii.gz
# => Saved to labels_output/468_M_BE25_out_c1.nii.gz
# => Saved to labels_output/468_M_BE25_out_c2.nii.gz
# => Saved to labels_output/468_M_BE25_out_c3.nii.gz
# => Saved to labels_output/468_M_BE25_out.nii.gz
# => Saved to labels_output/470_F_BG9_out_bg.nii.gz
# => Saved to labels_output/470_F_BG9_out_c1.nii.gz
# => Saved to labels_output/470_F_BG9_out_c2.nii.gz
# => Saved to labels_output/470_F_BG9_out_c3.nii.gz
# => Saved to labels_output/470_F_BG9_out.nii.gz
# => Saved to labels_output/473_M_BD23_out_bg.nii.gz
# => Saved to labels_output/473_M_BD23_out_c1.nii.gz
# => Saved to labels_output/473_M_BD23_out_c2.nii.gz
# => Saved to labels_output/473_M_BD23_out_c3.nii.gz
# => Saved to labels_output/473_M_BD23_out.nii.gz
# => Saved to labels_output/478_F_BG10_out_bg.nii.gz
# => Saved to labels_output/478_F_BG10_out_c1.nii.gz
# => Saved to labels_output/478_F_BG10_out_c2.nii.gz
# => Saved to labels_output/478_F_BG10_out_c3.nii.gz
# => Saved to labels_output/478_F_BG10_out.nii.gz
# => Saved to labels_output/479_F_BJ23_out_bg.nii.gz
# => Saved to labels_output/479_F_BJ23_out_c1.nii.gz
# => Saved to labels_output/479_F_BJ23_out_c2.nii.gz
# => Saved to labels_output/479_F_BJ23_out_c3.nii.gz
# => Saved to labels_output/479_F_BJ23_out.nii.gz
# => Saved to labels_output/483_M_AY9_out_bg.nii.gz
# => Saved to labels_output/483_M_AY9_out_c1.nii.gz
# => Saved to labels_output/483_M_AY9_out_c2.nii.gz
# => Saved to labels_output/483_M_AY9_out_c3.nii.gz
# => Saved to labels_output/483_M_AY9_out.nii.gz
# => Saved to labels_output/485_F_BJ24_out_bg.nii.gz
# => Saved to labels_output/485_F_BJ24_out_c1.nii.gz
# => Saved to labels_output/485_F_BJ24_out_c2.nii.gz
# => Saved to labels_output/485_F_BJ24_out_c3.nii.gz
# => Saved to labels_output/485_F_BJ24_out.nii.gz
# => Saved to labels_output/488_F_BF4_out_bg.nii.gz
# => Saved to labels_output/488_F_BF4_out_c1.nii.gz
# => Saved to labels_output/488_F_BF4_out_c2.nii.gz
# => Saved to labels_output/488_F_BF4_out_c3.nii.gz
# => Saved to labels_output/488_F_BF4_out.nii.gz
# => Saved to labels_output/489_F_BH14_out_bg.nii.gz
# => Saved to labels_output/489_F_BH14_out_c1.nii.gz
# => Saved to labels_output/489_F_BH14_out_c2.nii.gz
# => Saved to labels_output/489_F_BH14_out_c3.nii.gz
# => Saved to labels_output/489_F_BH14_out.nii.gz
# => Saved to labels_output/494_M_AY10_out_bg.nii.gz
# => Saved to labels_output/494_M_AY10_out_c1.nii.gz
# => Saved to labels_output/494_M_AY10_out_c2.nii.gz
# => Saved to labels_output/494_M_AY10_out_c3.nii.gz
# => Saved to labels_output/494_M_AY10_out.nii.gz
# => Saved to labels_output/496_M_BC20_out_bg.nii.gz
# => Saved to labels_output/496_M_BC20_out_c1.nii.gz
# => Saved to labels_output/496_M_BC20_out_c2.nii.gz
# => Saved to labels_output/496_M_BC20_out_c3.nii.gz
# => Saved to labels_output/496_M_BC20_out.nii.gz
# => Saved to labels_output/498_F_BJ25_out_bg.nii.gz
# => Saved to labels_output/498_F_BJ25_out_c1.nii.gz
# => Saved to labels_output/498_F_BJ25_out_c2.nii.gz
# => Saved to labels_output/498_F_BJ25_out_c3.nii.gz
# => Saved to labels_output/498_F_BJ25_out.nii.gz
# => Saved to labels_output/501_F_BF5_out_bg.nii.gz
# => Saved to labels_output/501_F_BF5_out_c1.nii.gz
# => Saved to labels_output/501_F_BF5_out_c2.nii.gz
# => Saved to labels_output/501_F_BF5_out_c3.nii.gz
# => Saved to labels_output/501_F_BF5_out.nii.gz
# => Saved to labels_output/505_M_BK1_out_bg.nii.gz
# => Saved to labels_output/505_M_BK1_out_c1.nii.gz
# => Saved to labels_output/505_M_BK1_out_c2.nii.gz
# => Saved to labels_output/505_M_BK1_out_c3.nii.gz
# => Saved to labels_output/505_M_BK1_out.nii.gz
# => Saved to labels_output/507_M_BQ16_out_bg.nii.gz
# => Saved to labels_output/507_M_BQ16_out_c1.nii.gz
# => Saved to labels_output/507_M_BQ16_out_c2.nii.gz
# => Saved to labels_output/507_M_BQ16_out_c3.nii.gz
# => Saved to labels_output/507_M_BQ16_out.nii.gz
# => Saved to labels_output/508_M_BS21_out_bg.nii.gz
# => Saved to labels_output/508_M_BS21_out_c1.nii.gz
# => Saved to labels_output/508_M_BS21_out_c2.nii.gz
# => Saved to labels_output/508_M_BS21_out_c3.nii.gz
# => Saved to labels_output/508_M_BS21_out.nii.gz
# => Saved to labels_output/511_F_BU1_out_bg.nii.gz
# => Saved to labels_output/511_F_BU1_out_c1.nii.gz
# => Saved to labels_output/511_F_BU1_out_c2.nii.gz
# => Saved to labels_output/511_F_BU1_out_c3.nii.gz
# => Saved to labels_output/511_F_BU1_out.nii.gz
# => Saved to labels_output/513_M_BK2_out_bg.nii.gz
# => Saved to labels_output/513_M_BK2_out_c1.nii.gz
# => Saved to labels_output/513_M_BK2_out_c2.nii.gz
# => Saved to labels_output/513_M_BK2_out_c3.nii.gz
# => Saved to labels_output/513_M_BK2_out.nii.gz
# => Saved to labels_output/514_F_BW11_out_bg.nii.gz
# => Saved to labels_output/514_F_BW11_out_c1.nii.gz
# => Saved to labels_output/514_F_BW11_out_c2.nii.gz
# => Saved to labels_output/514_F_BW11_out_c3.nii.gz
# => Saved to labels_output/514_F_BW11_out.nii.gz
# => Saved to labels_output/516_M_BS22_out_bg.nii.gz
# => Saved to labels_output/516_M_BS22_out_c1.nii.gz
# => Saved to labels_output/516_M_BS22_out_c2.nii.gz
# => Saved to labels_output/516_M_BS22_out_c3.nii.gz
# => Saved to labels_output/516_M_BS22_out.nii.gz
# => Saved to labels_output/518_F_BU2_out_bg.nii.gz
# => Saved to labels_output/518_F_BU2_out_c1.nii.gz
# => Saved to labels_output/518_F_BU2_out_c2.nii.gz
# => Saved to labels_output/518_F_BU2_out_c3.nii.gz
# => Saved to labels_output/518_F_BU2_out.nii.gz
# => Saved to labels_output/521_M_BK3_out_bg.nii.gz
# => Saved to labels_output/521_M_BK3_out_c1.nii.gz
# => Saved to labels_output/521_M_BK3_out_c2.nii.gz
# => Saved to labels_output/521_M_BK3_out_c3.nii.gz
# => Saved to labels_output/521_M_BK3_out.nii.gz
# => Saved to labels_output/523_M_BO11_out_bg.nii.gz
# => Saved to labels_output/523_M_BO11_out_c1.nii.gz
# => Saved to labels_output/523_M_BO11_out_c2.nii.gz
# => Saved to labels_output/523_M_BO11_out_c3.nii.gz
# => Saved to labels_output/523_M_BO11_out.nii.gz
# => Saved to labels_output/525_F_BX16_out_bg.nii.gz
# => Saved to labels_output/525_F_BX16_out_c1.nii.gz
# => Saved to labels_output/525_F_BX16_out_c2.nii.gz
# => Saved to labels_output/525_F_BX16_out_c3.nii.gz
# => Saved to labels_output/525_F_BX16_out.nii.gz
# => Saved to labels_output/528_F_BW12_out_bg.nii.gz
# => Saved to labels_output/528_F_BW12_out_c1.nii.gz
# => Saved to labels_output/528_F_BW12_out_c2.nii.gz
# => Saved to labels_output/528_F_BW12_out_c3.nii.gz
# => Saved to labels_output/528_F_BW12_out.nii.gz
# ...
# => Saved to labels_output/564_M_BR19_out_c1.nii.gz
# => Saved to labels_output/564_M_BR19_out_c2.nii.gz
# => Saved to labels_output/564_M_BR19_out_c3.nii.gz
# => Saved to labels_output/564_M_BR19_out.nii.gz
# => Saved to labels_output/566_M_BT24_out_bg.nii.gz
# => Saved to labels_output/566_M_BT24_out_c1.nii.gz
# => Saved to labels_output/566_M_BT24_out_c2.nii.gz
# => Saved to labels_output/566_M_BT24_out_c3.nii.gz
# => Saved to labels_output/566_M_BT24_out.nii.gz
# => Saved to labels_output/567_F_BV9_out_bg.nii.gz
# => Saved to labels_output/567_F_BV9_out_c1.nii.gz
# => Saved to labels_output/567_F_BV9_out_c2.nii.gz
# => Saved to labels_output/567_F_BV9_out_c3.nii.gz
# => Saved to labels_output/567_F_BV9_out.nii.gz
# => Saved to labels_output/568_F_BX19_out_bg.nii.gz
# => Saved to labels_output/568_F_BX19_out_c1.nii.gz
# => Saved to labels_output/568_F_BX19_out_c2.nii.gz
# => Saved to labels_output/568_F_BX19_out_c3.nii.gz
# => Saved to labels_output/568_F_BX19_out.nii.gz
# => Saved to labels_output/575_M_BR20_out_bg.nii.gz
# => Saved to labels_output/575_M_BR20_out_c1.nii.gz
# => Saved to labels_output/575_M_BR20_out_c2.nii.gz
# => Saved to labels_output/575_M_BR20_out_c3.nii.gz
# => Saved to labels_output/575_M_BR20_out.nii.gz
# => Saved to labels_output/577_M_BT25_out_bg.nii.gz
# => Saved to labels_output/577_M_BT25_out_c1.nii.gz
# => Saved to labels_output/577_M_BT25_out_c2.nii.gz
# => Saved to labels_output/577_M_BT25_out_c3.nii.gz
# => Saved to labels_output/577_M_BT25_out.nii.gz
# => Saved to labels_output/578_F_BV10_out_bg.nii.gz
# => Saved to labels_output/578_F_BV10_out_c1.nii.gz
# => Saved to labels_output/578_F_BV10_out_c2.nii.gz
# => Saved to labels_output/578_F_BV10_out_c3.nii.gz
# => Saved to labels_output/578_F_BV10_out.nii.gz
# => Saved to labels_output/579_F_BX20_out_bg.nii.gz
# => Saved to labels_output/579_F_BX20_out_c1.nii.gz
# => Saved to labels_output/579_F_BX20_out_c2.nii.gz
# => Saved to labels_output/579_F_BX20_out_c3.nii.gz
# => Saved to labels_output/579_F_BX20_out.nii.gz
# => Saved to labels_output/582_M_BM6_out_bg.nii.gz
# => Saved to labels_output/582_M_BM6_out_c1.nii.gz
# => Saved to labels_output/582_M_BM6_out_c2.nii.gz
# => Saved to labels_output/582_M_BM6_out_c3.nii.gz
# => Saved to labels_output/582_M_BM6_out.nii.gz
# => Saved to labels_output/583_M_BN9_out_bg.nii.gz
# => Saved to labels_output/583_M_BN9_out_c1.nii.gz
# => Saved to labels_output/583_M_BN9_out_c2.nii.gz
# => Saved to labels_output/583_M_BN9_out_c3.nii.gz
# => Saved to labels_output/583_M_BN9_out.nii.gz
# => Saved to labels_output/584_M_BN10_out_bg.nii.gz
# => Saved to labels_output/584_M_BN10_out_c1.nii.gz
# => Saved to labels_output/584_M_BN10_out_c2.nii.gz
# => Saved to labels_output/584_M_BN10_out_c3.nii.gz
# => Saved to labels_output/584_M_BN10_out.nii.gz
# => Saved to labels_output/587_F_BY21_out_bg.nii.gz
# => Saved to labels_output/587_F_BY21_out_c1.nii.gz
# => Saved to labels_output/587_F_BY21_out_c2.nii.gz
# => Saved to labels_output/587_F_BY21_out_c3.nii.gz
# => Saved to labels_output/587_F_BY21_out.nii.gz
# => Saved to labels_output/588_F_BY22_out_bg.nii.gz
# => Saved to labels_output/588_F_BY22_out_c1.nii.gz
# => Saved to labels_output/588_F_BY22_out_c2.nii.gz
# => Saved to labels_output/588_F_BY22_out_c3.nii.gz
# => Saved to labels_output/588_F_BY22_out.nii.gz
# => Saved to labels_output/589_F_BY23_out_bg.nii.gz
# => Saved to labels_output/589_F_BY23_out_c1.nii.gz
# => Saved to labels_output/589_F_BY23_out_c2.nii.gz
# => Saved to labels_output/589_F_BY23_out_c3.nii.gz
# => Saved to labels_output/589_F_BY23_out.nii.gz
# => Saved to labels_output/590_F_BY24_out_bg.nii.gz
# => Saved to labels_output/590_F_BY24_out_c1.nii.gz
# => Saved to labels_output/590_F_BY24_out_c2.nii.gz
# => Saved to labels_output/590_F_BY24_out_c3.nii.gz
# => Saved to labels_output/590_F_BY24_out.nii.gz
# => Saved to labels_output/591_M_BM7_out_bg.nii.gz
# => Saved to labels_output/591_M_BM7_out_c1.nii.gz
# => Saved to labels_output/591_M_BM7_out_c2.nii.gz
# => Saved to labels_output/591_M_BM7_out_c3.nii.gz
# => Saved to labels_output/591_M_BM7_out.nii.gz
# => Saved to labels_output/592_M_BM8_out_bg.nii.gz
# => Saved to labels_output/592_M_BM8_out_c1.nii.gz
# => Saved to labels_output/592_M_BM8_out_c2.nii.gz
# => Saved to labels_output/592_M_BM8_out_c3.nii.gz
# => Saved to labels_output/592_M_BM8_out.nii.gz
# => Saved to labels_output/593_F_BY25_out_bg.nii.gz
# => Saved to labels_output/593_F_BY25_out_c1.nii.gz
# => Saved to labels_output/593_F_BY25_out_c2.nii.gz
# => Saved to labels_output/593_F_BY25_out_c3.nii.gz
# => Saved to labels_output/593_F_BY25_out.nii.gz
# => Saved to labels_output/594_M_CB6_out_bg.nii.gz
# => Saved to labels_output/594_M_CB6_out_c1.nii.gz
# => Saved to labels_output/594_M_CB6_out_c2.nii.gz
# => Saved to labels_output/594_M_CB6_out_c3.nii.gz
# => Saved to labels_output/594_M_CB6_out.nii.gz
# => Saved to labels_output/595_M_CF16_out_bg.nii.gz
# => Saved to labels_output/595_M_CF16_out_c1.nii.gz
# => Saved to labels_output/595_M_CF16_out_c2.nii.gz
# => Saved to labels_output/595_M_CF16_out_c3.nii.gz
# => Saved to labels_output/595_M_CF16_out.nii.gz
# => Saved to labels_output/597_F_CK11_out_bg.nii.gz
# => Saved to labels_output/597_F_CK11_out_c1.nii.gz
# => Saved to labels_output/597_F_CK11_out_c2.nii.gz
# => Saved to labels_output/597_F_CK11_out_c3.nii.gz
# => Saved to labels_output/597_F_CK11_out.nii.gz
# => Saved to labels_output/600_F_CM6_out_bg.nii.gz
# => Saved to labels_output/600_F_CM6_out_c1.nii.gz
# => Saved to labels_output/600_F_CM6_out_c2.nii.gz
# => Saved to labels_output/600_F_CM6_out_c3.nii.gz
# => Saved to labels_output/600_F_CM6_out.nii.gz
# => Saved to labels_output/602_M_CB7_out_bg.nii.gz
# => Saved to labels_output/602_M_CB7_out_c1.nii.gz
# => Saved to labels_output/602_M_CB7_out_c2.nii.gz
# => Saved to labels_output/602_M_CB7_out_c3.nii.gz
# => Saved to labels_output/602_M_CB7_out.nii.gz
# => Saved to labels_output/603_M_CF17_out_bg.nii.gz
# => Saved to labels_output/603_M_CF17_out_c1.nii.gz
# => Saved to labels_output/603_M_CF17_out_c2.nii.gz
# => Saved to labels_output/603_M_CF17_out_c3.nii.gz
# => Saved to labels_output/603_M_CF17_out.nii.gz
# => Saved to labels_output/607_F_CK12_out_bg.nii.gz
# => Saved to labels_output/607_F_CK12_out_c1.nii.gz
# => Saved to labels_output/607_F_CK12_out_c2.nii.gz
# => Saved to labels_output/607_F_CK12_out_c3.nii.gz
# => Saved to labels_output/607_F_CK12_out.nii.gz
# => Saved to labels_output/608_F_CL16_out_bg.nii.gz
# => Saved to labels_output/608_F_CL16_out_c1.nii.gz
# => Saved to labels_output/608_F_CL16_out_c2.nii.gz
# => Saved to labels_output/608_F_CL16_out_c3.nii.gz
# => Saved to labels_output/608_F_CL16_out.nii.gz
# => Saved to labels_output/610_F_CN21_out_bg.nii.gz
# => Saved to labels_output/610_F_CN21_out_c1.nii.gz
# => Saved to labels_output/610_F_CN21_out_c2.nii.gz
# => Saved to labels_output/610_F_CN21_out_c3.nii.gz
# => Saved to labels_output/610_F_CN21_out.nii.gz
# => Saved to labels_output/612_M_CH21_out_bg.nii.gz
# => Saved to labels_output/612_M_CH21_out_c1.nii.gz
# => Saved to labels_output/612_M_CH21_out_c2.nii.gz
# => Saved to labels_output/612_M_CH21_out_c3.nii.gz
# => Saved to labels_output/612_M_CH21_out.nii.gz
# => Saved to labels_output/618_F_CL17_out_bg.nii.gz
# => Saved to labels_output/618_F_CL17_out_c1.nii.gz
# => Saved to labels_output/618_F_CL17_out_c2.nii.gz
# => Saved to labels_output/618_F_CL17_out_c3.nii.gz
# => Saved to labels_output/618_F_CL17_out.nii.gz
# => Saved to labels_output/619_F_CN22_out_bg.nii.gz
# => Saved to labels_output/619_F_CN22_out_c1.nii.gz
# => Saved to labels_output/619_F_CN22_out_c2.nii.gz
# => Saved to labels_output/619_F_CN22_out_c3.nii.gz
# => Saved to labels_output/619_F_CN22_out.nii.gz
# => Saved to labels_output/620_F_CM7_out_bg.nii.gz
# => Saved to labels_output/620_F_CM7_out_c1.nii.gz
# => Saved to labels_output/620_F_CM7_out_c2.nii.gz
# => Saved to labels_output/620_F_CM7_out_c3.nii.gz
# => Saved to labels_output/620_F_CM7_out.nii.gz
# => Saved to labels_output/623_M_CC9_out_bg.nii.gz
# => Saved to labels_output/623_M_CC9_out_c1.nii.gz
# => Saved to labels_output/623_M_CC9_out_c2.nii.gz
# => Saved to labels_output/623_M_CC9_out_c3.nii.gz
# => Saved to labels_output/623_M_CC9_out.nii.gz
# => Saved to labels_output/625_M_CH22_out_bg.nii.gz
# => Saved to labels_output/625_M_CH22_out_c1.nii.gz
# => Saved to labels_output/625_M_CH22_out_c2.nii.gz
# => Saved to labels_output/625_M_CH22_out_c3.nii.gz
# => Saved to labels_output/625_M_CH22_out.nii.gz
# => Saved to labels_output/629_F_CL18_out_bg.nii.gz
# => Saved to labels_output/629_F_CL18_out_c1.nii.gz
# => Saved to labels_output/629_F_CL18_out_c2.nii.gz
# => Saved to labels_output/629_F_CL18_out_c3.nii.gz
# => Saved to labels_output/629_F_CL18_out.nii.gz
# => Saved to labels_output/631_M_CD12_out_bg.nii.gz
# => Saved to labels_output/631_M_CD12_out_c1.nii.gz
# => Saved to labels_output/631_M_CD12_out_c2.nii.gz
# => Saved to labels_output/631_M_CD12_out_c3.nii.gz
# => Saved to labels_output/631_M_CD12_out.nii.gz
# => Saved to labels_output/634_F_CL19_out_bg.nii.gz
# => Saved to labels_output/634_F_CL19_out_c1.nii.gz
# => Saved to labels_output/634_F_CL19_out_c2.nii.gz
# => Saved to labels_output/634_F_CL19_out_c3.nii.gz
# => Saved to labels_output/634_F_CL19_out.nii.gz
# => Saved to labels_output/636_F_CN23_out_bg.nii.gz
# => Saved to labels_output/636_F_CN23_out_c1.nii.gz
# => Saved to labels_output/636_F_CN23_out_c2.nii.gz
# => Saved to labels_output/636_F_CN23_out_c3.nii.gz
# => Saved to labels_output/636_F_CN23_out.nii.gz
# => Saved to labels_output/638_F_CM8_out_bg.nii.gz
# => Saved to labels_output/638_F_CM8_out_c1.nii.gz
# => Saved to labels_output/638_F_CM8_out_c2.nii.gz
# => Saved to labels_output/638_F_CM8_out_c3.nii.gz
# => Saved to labels_output/638_F_CM8_out.nii.gz
# => Saved to labels_output/642_M_CC9_out_bg.nii.gz
# => Saved to labels_output/642_M_CC9_out_c1.nii.gz
# => Saved to labels_output/642_M_CC9_out_c2.nii.gz
# => Saved to labels_output/642_M_CC9_out_c3.nii.gz
# => Saved to labels_output/642_M_CC9_out.nii.gz
# => Saved to labels_output/643_M_CD13_out_bg.nii.gz
# => Saved to labels_output/643_M_CD13_out_c1.nii.gz
# => Saved to labels_output/643_M_CD13_out_c2.nii.gz
# => Saved to labels_output/643_M_CD13_out_c3.nii.gz
# => Saved to labels_output/643_M_CD13_out.nii.gz
# => Saved to labels_output/644_M_CH23_out_bg.nii.gz
# => Saved to labels_output/644_M_CH23_out_c1.nii.gz
# => Saved to labels_output/644_M_CH23_out_c2.nii.gz
# => Saved to labels_output/644_M_CH23_out_c3.nii.gz
# => Saved to labels_output/644_M_CH23_out.nii.gz
# => Saved to labels_output/647_F_CL20_out_bg.nii.gz
# => Saved to labels_output/647_F_CL20_out_c1.nii.gz
# => Saved to labels_output/647_F_CL20_out_c2.nii.gz
# => Saved to labels_output/647_F_CL20_out_c3.nii.gz
# => Saved to labels_output/647_F_CL20_out.nii.gz
# => Saved to labels_output/649_F_CN24_out_bg.nii.gz
# => Saved to labels_output/649_F_CN24_out_c1.nii.gz
# => Saved to labels_output/649_F_CN24_out_c2.nii.gz
# => Saved to labels_output/649_F_CN24_out_c3.nii.gz
# => Saved to labels_output/649_F_CN24_out.nii.gz
# => Saved to labels_output/652_M_CG18_out_bg.nii.gz
# => Saved to labels_output/652_M_CG18_out_c1.nii.gz
# => Saved to labels_output/652_M_CG18_out_c2.nii.gz
# => Saved to labels_output/652_M_CG18_out_c3.nii.gz
# => Saved to labels_output/652_M_CG18_out.nii.gz
# => Saved to labels_output/657_F_CK13_out_bg.nii.gz
# => Saved to labels_output/657_F_CK13_out_c1.nii.gz
# => Saved to labels_output/657_F_CK13_out_c2.nii.gz
# => Saved to labels_output/657_F_CK13_out_c3.nii.gz
# => Saved to labels_output/657_F_CK13_out.nii.gz
# => Saved to labels_output/658_M_CG19_out_bg.nii.gz
# => Saved to labels_output/658_M_CG19_out_c1.nii.gz
# => Saved to labels_output/658_M_CG19_out_c2.nii.gz
# => Saved to labels_output/658_M_CG19_out_c3.nii.gz
# => Saved to labels_output/658_M_CG19_out.nii.gz
# => Saved to labels_output/660_F_CK14_out_bg.nii.gz
# => Saved to labels_output/660_F_CK14_out_c1.nii.gz
# => Saved to labels_output/660_F_CK14_out_c2.nii.gz
# => Saved to labels_output/660_F_CK14_out_c3.nii.gz
# => Saved to labels_output/660_F_CK14_out.nii.gz
# => Saved to labels_output/661_F_CN25_out_bg.nii.gz
# => Saved to labels_output/661_F_CN25_out_c1.nii.gz
# => Saved to labels_output/661_F_CN25_out_c2.nii.gz
# => Saved to labels_output/661_F_CN25_out_c3.nii.gz
# => Saved to labels_output/661_F_CN25_out.nii.gz
# => Saved to labels_output/663_F_CM9_out_bg.nii.gz
# => Saved to labels_output/663_F_CM9_out_c1.nii.gz
# => Saved to labels_output/663_F_CM9_out_c2.nii.gz
# => Saved to labels_output/663_F_CM9_out_c3.nii.gz
# => Saved to labels_output/663_F_CM9_out.nii.gz
# => Saved to labels_output/668_M_CE15_out_bg.nii.gz
# => Saved to labels_output/668_M_CE15_out_c1.nii.gz
# => Saved to labels_output/668_M_CE15_out_c2.nii.gz
# => Saved to labels_output/668_M_CE15_out_c3.nii.gz
# => Saved to labels_output/668_M_CE15_out.nii.gz
# => Saved to labels_output/669_M_CG20_out_bg.nii.gz
# => Saved to labels_output/669_M_CG20_out_c1.nii.gz
# => Saved to labels_output/669_M_CG20_out_c2.nii.gz
# => Saved to labels_output/669_M_CG20_out_c3.nii.gz
# => Saved to labels_output/669_M_CG20_out.nii.gz
# => Saved to labels_output/670_M_CI25_out_bg.nii.gz
# => Saved to labels_output/670_M_CI25_out_c1.nii.gz
# => Saved to labels_output/670_M_CI25_out_c2.nii.gz
# => Saved to labels_output/670_M_CI25_out_c3.nii.gz
# => Saved to labels_output/670_M_CI25_out.nii.gz
# => Saved to labels_output/673_F_CK15_out_bg.nii.gz
# => Saved to labels_output/673_F_CK15_out_c1.nii.gz
# => Saved to labels_output/673_F_CK15_out_c2.nii.gz
# => Saved to labels_output/673_F_CK15_out_c3.nii.gz
# => Saved to labels_output/673_F_CK15_out.nii.gz
# => Saved to labels_output/675_F_CM10_out_bg.nii.gz
# => Saved to labels_output/675_F_CM10_out_c1.nii.gz
# => Saved to labels_output/675_F_CM10_out_c2.nii.gz
# => Saved to labels_output/675_F_CM10_out_c3.nii.gz
# => Saved to labels_output/675_F_CM10_out.nii.gz
# => Saved to labels_output/678_M_BZ1_out_bg.nii.gz
# => Saved to labels_output/678_M_BZ1_out_c1.nii.gz
# => Saved to labels_output/678_M_BZ1_out_c2.nii.gz
# => Saved to labels_output/678_M_BZ1_out_c3.nii.gz
# => Saved to labels_output/678_M_BZ1_out.nii.gz
# => Saved to labels_output/679_M_BZ2_out_bg.nii.gz
# => Saved to labels_output/679_M_BZ2_out_c1.nii.gz
# => Saved to labels_output/679_M_BZ2_out_c2.nii.gz
# => Saved to labels_output/679_M_BZ2_out_c3.nii.gz
# => Saved to labels_output/679_M_BZ2_out.nii.gz
# => Saved to labels_output/685_F_CJ1_out_bg.nii.gz
# => Saved to labels_output/685_F_CJ1_out_c1.nii.gz
# => Saved to labels_output/685_F_CJ1_out_c2.nii.gz
# => Saved to labels_output/685_F_CJ1_out_c3.nii.gz
# => Saved to labels_output/685_F_CJ1_out.nii.gz
# => Saved to labels_output/686_F_CJ2_out_bg.nii.gz
# => Saved to labels_output/686_F_CJ2_out_c1.nii.gz
# => Saved to labels_output/686_F_CJ2_out_c2.nii.gz
# => Saved to labels_output/686_F_CJ2_out_c3.nii.gz
# => Saved to labels_output/686_F_CJ2_out.nii.gz
# => Saved to labels_output/687_F_CJ3_out_bg.nii.gz
# => Saved to labels_output/687_F_CJ3_out_c1.nii.gz
# => Saved to labels_output/687_F_CJ3_out_c2.nii.gz
# => Saved to labels_output/687_F_CJ3_out_c3.nii.gz
# => Saved to labels_output/687_F_CJ3_out.nii.gz
# => Saved to labels_output/689_M_BZ3_out_bg.nii.gz
# => Saved to labels_output/689_M_BZ3_out_c1.nii.gz
# => Saved to labels_output/689_M_BZ3_out_c2.nii.gz
# => Saved to labels_output/689_M_BZ3_out_c3.nii.gz
# => Saved to labels_output/689_M_BZ3_out.nii.gz
# => Saved to labels_output/690_M_CA4_out_bg.nii.gz
# => Saved to labels_output/690_M_CA4_out_c1.nii.gz
# => Saved to labels_output/690_M_CA4_out_c2.nii.gz
# => Saved to labels_output/690_M_CA4_out_c3.nii.gz
# => Saved to labels_output/690_M_CA4_out.nii.gz
# => Saved to labels_output/691_M_CA5_out_bg.nii.gz
# => Saved to labels_output/691_M_CA5_out_c1.nii.gz
# => Saved to labels_output/691_M_CA5_out_c2.nii.gz
# => Saved to labels_output/691_M_CA5_out_c3.nii.gz
# => Saved to labels_output/691_M_CA5_out.nii.gz
# => Saved to labels_output/697_F_CJ4_out_bg.nii.gz
# => Saved to labels_output/697_F_CJ4_out_c1.nii.gz
# => Saved to labels_output/697_F_CJ4_out_c2.nii.gz
# => Saved to labels_output/697_F_CJ4_out_c3.nii.gz
# => Saved to labels_output/697_F_CJ4_out.nii.gz
# => Saved to labels_output/698_F_CJ5_out_bg.nii.gz
# => Saved to labels_output/698_F_CJ5_out_c1.nii.gz
# => Saved to labels_output/698_F_CJ5_out_c2.nii.gz
# => Saved to labels_output/698_F_CJ5_out_c3.nii.gz
# => Saved to labels_output/698_F_CJ5_out.nii.gz
