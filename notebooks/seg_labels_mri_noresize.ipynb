# %%
import argparse
import logging
import sys

import monai
import torch
from torch.utils.tensorboard import SummaryWriter
from monai.utils import set_determinism
import numpy as np
from glob import glob
import os
import nibabel as nib

from monai.transforms.transform import Transform
from monai.transforms import Activations, EnsureType, Compose, MaskIntensity, AddChannel, ToTensor, MaskIntensity
from transforms import CropMRId, BinaryMask, GetLargestComponent, GetLabelsAsOneHotd, Shaped, InverseOneHot
from torch import nn
from transforms_dict import getSegmentationEvalTransformsForMRI, getSegmentationPostProcessingForLabelOutput, getSegmentationPostProcessingForAllLabelsOutput
from transforms_dict import getSegmentationInverseTransformForLabels, getSegmentationPostProcessingForLabel

from seg_data import getDataset
from seg_model import getUNetForSegmentation
from utils import compute_mean_dice, getReducePlateauScheduler, getAdamOptimizer, loadExistingModel
from utils import print_model_output, check_model_name, getDevice


from monai.inferers import sliding_window_inference
from monai.data import decollate_batch

# %%
#Parameters
N4 = False
resample = False
save_tmp = False
get_largest_component = False

# %%
#Modelname and device

def getUNETRForSegmentation():
    device = getDevice()
    model = monai.networks.nets.UNETR(
        in_channels=1,
        out_channels=4,
        img_size=(96, 96, 96),
        feature_size=16,
        hidden_size=768,
        mlp_dim=3072,
        num_heads=12,
        pos_embed="perceptron",
        norm_name="instance",
        res_block=True,
        dropout_rate=0.0,
    ).to(device)
    return model

model = getUNETRForSegmentation()
modelname = "labels/seg_labels_unetr_noresize.pth"

#model = getUNetForSegmentation()
#modelname = "labels/seg_labels_2.pth"

modelname = check_model_name(modelname)
set_determinism(seed=0)
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
device = getDevice()

# %%
#postprocessing
device = getDevice()
outputs_processing = getSegmentationPostProcessingForLabelOutput(axis=1)
all_outputs_processing = getSegmentationPostProcessingForAllLabelsOutput(axis=1)
labels_processing = getSegmentationPostProcessingForLabel(axis=1)
test_proba = Compose([
    EnsureType(),
    Activations(other=nn.Softmax(dim=1)),
    EnsureType(data_type="tensor", device=device)
])

#activations
softmax = Activations(other=nn.Softmax(dim=1))

# %%
#Model
loadExistingModel(model, None, ft=modelname)
model.eval()

mris = sorted(glob(os.path.join("dataset", "Painfact-Segmentation", 'MRI', "*.nii.gz")))
masks = sorted(glob(os.path.join("dataset", "Painfact-Segmentation", 'Label', "*.nii.gz")))
for i, mri in enumerate(mris):
    mriname = mri
    outname = "labels_output_new_xd/" + mriname.split('/')[-1].split('.')[0]
    
    mask_bg = AddChannel()(ToTensor()(nib.load(masks[i]).get_fdata()))
    #maskint = MaskIntensity(mask_bg)

    mri_preprocessing = getSegmentationEvalTransformsForMRI(N4=N4, outname=outname, save=save_tmp, no_resize=True)
    

    with torch.no_grad():
        inputs = mri_preprocessing(mriname).to(device)
        print(inputs.shape)
        outputs = sliding_window_inference(inputs, (96, 96, 96), 1, model).cpu()
        print(outputs.shape)
        
        preds = outputs_processing(outputs)
        #preds = maskint(preds)
        all_preds = all_outputs_processing(outputs)
        #all_preds = maskint(all_preds)
        probs = test_proba(outputs)
        
        suffix = ["bg", "c1", "c2", "c3"]
        for i in range(len(suffix)):
            transform = getSegmentationInverseTransformForLabels(mriname, out_name=outname, suffix=suffix[i], save=True, no_resize=True)
            transform(preds[0, i, :, :, :])        
        #for i in range(len(suffix)):
        #    transform = getSegmentationInverseTransformForLabels(mriname, out_name=outname, suffix=suffix[i]+'_prob', save=True)
        #    transform(probs[0, i, :, :, :])
        transform = getSegmentationInverseTransformForLabels(mriname, out_name=outname, suffix=None, save=True, no_resize=True)
        transform(all_preds[0,:,:,:])
# Out:
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/000_M_I23_out_bg.nii.gz
# => Saved to labels_output_new_xd/000_M_I23_out_c1.nii.gz
# => Saved to labels_output_new_xd/000_M_I23_out_c2.nii.gz
# => Saved to labels_output_new_xd/000_M_I23_out_c3.nii.gz
# => Saved to labels_output_new_xd/000_M_I23_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/101_M_A1_out_bg.nii.gz
# => Saved to labels_output_new_xd/101_M_A1_out_c1.nii.gz
# => Saved to labels_output_new_xd/101_M_A1_out_c2.nii.gz
# => Saved to labels_output_new_xd/101_M_A1_out_c3.nii.gz
# => Saved to labels_output_new_xd/101_M_A1_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/102_M_A2_out_bg.nii.gz
# => Saved to labels_output_new_xd/102_M_A2_out_c1.nii.gz
# => Saved to labels_output_new_xd/102_M_A2_out_c2.nii.gz
# => Saved to labels_output_new_xd/102_M_A2_out_c3.nii.gz
# => Saved to labels_output_new_xd/102_M_A2_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/103_M_I21_out_bg.nii.gz
# => Saved to labels_output_new_xd/103_M_I21_out_c1.nii.gz
# => Saved to labels_output_new_xd/103_M_I21_out_c2.nii.gz
# => Saved to labels_output_new_xd/103_M_I21_out_c3.nii.gz
# => Saved to labels_output_new_xd/103_M_I21_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/109_F_K2_out_bg.nii.gz
# => Saved to labels_output_new_xd/109_F_K2_out_c1.nii.gz
# => Saved to labels_output_new_xd/109_F_K2_out_c2.nii.gz
# => Saved to labels_output_new_xd/109_F_K2_out_c3.nii.gz
# => Saved to labels_output_new_xd/109_F_K2_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/110_F_K1_out_bg.nii.gz
# => Saved to labels_output_new_xd/110_F_K1_out_c1.nii.gz
# => Saved to labels_output_new_xd/110_F_K1_out_c2.nii.gz
# => Saved to labels_output_new_xd/110_F_K1_out_c3.nii.gz
# => Saved to labels_output_new_xd/110_F_K1_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/113_M_A3_out_bg.nii.gz
# => Saved to labels_output_new_xd/113_M_A3_out_c1.nii.gz
# => Saved to labels_output_new_xd/113_M_A3_out_c2.nii.gz
# => Saved to labels_output_new_xd/113_M_A3_out_c3.nii.gz
# => Saved to labels_output_new_xd/113_M_A3_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/114_M_A4_out_bg.nii.gz
# => Saved to labels_output_new_xd/114_M_A4_out_c1.nii.gz
# => Saved to labels_output_new_xd/114_M_A4_out_c2.nii.gz
# => Saved to labels_output_new_xd/114_M_A4_out_c3.nii.gz
# => Saved to labels_output_new_xd/114_M_A4_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/115_M_E13_out_bg.nii.gz
# => Saved to labels_output_new_xd/115_M_E13_out_c1.nii.gz
# => Saved to labels_output_new_xd/115_M_E13_out_c2.nii.gz
# => Saved to labels_output_new_xd/115_M_E13_out_c3.nii.gz
# => Saved to labels_output_new_xd/115_M_E13_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/116_F_K3_out_bg.nii.gz
# => Saved to labels_output_new_xd/116_F_K3_out_c1.nii.gz
# => Saved to labels_output_new_xd/116_F_K3_out_c2.nii.gz
# => Saved to labels_output_new_xd/116_F_K3_out_c3.nii.gz
# => Saved to labels_output_new_xd/116_F_K3_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/117_F_K4_out_bg.nii.gz
# => Saved to labels_output_new_xd/117_F_K4_out_c1.nii.gz
# => Saved to labels_output_new_xd/117_F_K4_out_c2.nii.gz
# => Saved to labels_output_new_xd/117_F_K4_out_c3.nii.gz
# => Saved to labels_output_new_xd/117_F_K4_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/120_M_B5_out_bg.nii.gz
# => Saved to labels_output_new_xd/120_M_B5_out_c1.nii.gz
# => Saved to labels_output_new_xd/120_M_B5_out_c2.nii.gz
# => Saved to labels_output_new_xd/120_M_B5_out_c3.nii.gz
# => Saved to labels_output_new_xd/120_M_B5_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/123_F_K5_out_bg.nii.gz
# => Saved to labels_output_new_xd/123_F_K5_out_c1.nii.gz
# => Saved to labels_output_new_xd/123_F_K5_out_c2.nii.gz
# => Saved to labels_output_new_xd/123_F_K5_out_c3.nii.gz
# => Saved to labels_output_new_xd/123_F_K5_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/124_F_L6_out_bg.nii.gz
# => Saved to labels_output_new_xd/124_F_L6_out_c1.nii.gz
# => Saved to labels_output_new_xd/124_F_L6_out_c2.nii.gz
# => Saved to labels_output_new_xd/124_F_L6_out_c3.nii.gz
# => Saved to labels_output_new_xd/124_F_L6_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/130_M_C8_out_bg.nii.gz
# => Saved to labels_output_new_xd/130_M_C8_out_c1.nii.gz
# => Saved to labels_output_new_xd/130_M_C8_out_c2.nii.gz
# => Saved to labels_output_new_xd/130_M_C8_out_c3.nii.gz
# => Saved to labels_output_new_xd/130_M_C8_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/131_M_D9_out_bg.nii.gz
# => Saved to labels_output_new_xd/131_M_D9_out_c1.nii.gz
# => Saved to labels_output_new_xd/131_M_D9_out_c2.nii.gz
# => Saved to labels_output_new_xd/131_M_D9_out_c3.nii.gz
# => Saved to labels_output_new_xd/131_M_D9_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/132_M_I22_out_bg.nii.gz
# => Saved to labels_output_new_xd/132_M_I22_out_c1.nii.gz
# => Saved to labels_output_new_xd/132_M_I22_out_c2.nii.gz
# => Saved to labels_output_new_xd/132_M_I22_out_c3.nii.gz
# => Saved to labels_output_new_xd/132_M_I22_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/135_F_L10_out_bg.nii.gz
# => Saved to labels_output_new_xd/135_F_L10_out_c1.nii.gz
# => Saved to labels_output_new_xd/135_F_L10_out_c2.nii.gz
# => Saved to labels_output_new_xd/135_F_L10_out_c3.nii.gz
# => Saved to labels_output_new_xd/135_F_L10_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/136_F_L8_out_bg.nii.gz
# => Saved to labels_output_new_xd/136_F_L8_out_c1.nii.gz
# => Saved to labels_output_new_xd/136_F_L8_out_c2.nii.gz
# => Saved to labels_output_new_xd/136_F_L8_out_c3.nii.gz
# => Saved to labels_output_new_xd/136_F_L8_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/141_M_D10_out_bg.nii.gz
# => Saved to labels_output_new_xd/141_M_D10_out_c1.nii.gz
# => Saved to labels_output_new_xd/141_M_D10_out_c2.nii.gz
# => Saved to labels_output_new_xd/141_M_D10_out_c3.nii.gz
# => Saved to labels_output_new_xd/141_M_D10_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/142_M_C7_out_bg.nii.gz
# => Saved to labels_output_new_xd/142_M_C7_out_c1.nii.gz
# => Saved to labels_output_new_xd/142_M_C7_out_c2.nii.gz
# => Saved to labels_output_new_xd/142_M_C7_out_c3.nii.gz
# => Saved to labels_output_new_xd/142_M_C7_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/145_F_L7_out_bg.nii.gz
# => Saved to labels_output_new_xd/145_F_L7_out_c1.nii.gz
# => Saved to labels_output_new_xd/145_F_L7_out_c2.nii.gz
# => Saved to labels_output_new_xd/145_F_L7_out_c3.nii.gz
# => Saved to labels_output_new_xd/145_F_L7_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/146_F_L9_out_bg.nii.gz
# => Saved to labels_output_new_xd/146_F_L9_out_c1.nii.gz
# => Saved to labels_output_new_xd/146_F_L9_out_c2.nii.gz
# => Saved to labels_output_new_xd/146_F_L9_out_c3.nii.gz
# => Saved to labels_output_new_xd/146_F_L9_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/150_M_F15_out_bg.nii.gz
# => Saved to labels_output_new_xd/150_M_F15_out_c1.nii.gz
# => Saved to labels_output_new_xd/150_M_F15_out_c2.nii.gz
# => Saved to labels_output_new_xd/150_M_F15_out_c3.nii.gz
# => Saved to labels_output_new_xd/150_M_F15_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/151_F_M11_out_bg.nii.gz
# => Saved to labels_output_new_xd/151_F_M11_out_c1.nii.gz
# => Saved to labels_output_new_xd/151_F_M11_out_c2.nii.gz
# => Saved to labels_output_new_xd/151_F_M11_out_c3.nii.gz
# => Saved to labels_output_new_xd/151_F_M11_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/152_F_M15_out_bg.nii.gz
# => Saved to labels_output_new_xd/152_F_M15_out_c1.nii.gz
# => Saved to labels_output_new_xd/152_F_M15_out_c2.nii.gz
# => Saved to labels_output_new_xd/152_F_M15_out_c3.nii.gz
# => Saved to labels_output_new_xd/152_F_M15_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/159_M_G17_out_bg.nii.gz
# => Saved to labels_output_new_xd/159_M_G17_out_c1.nii.gz
# => Saved to labels_output_new_xd/159_M_G17_out_c2.nii.gz
# => Saved to labels_output_new_xd/159_M_G17_out_c3.nii.gz
# => Saved to labels_output_new_xd/159_M_G17_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/160_F_M13_out_bg.nii.gz
# => Saved to labels_output_new_xd/160_F_M13_out_c1.nii.gz
# => Saved to labels_output_new_xd/160_F_M13_out_c2.nii.gz
# => Saved to labels_output_new_xd/160_F_M13_out_c3.nii.gz
# => Saved to labels_output_new_xd/160_F_M13_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/161_F_M12_out_bg.nii.gz
# => Saved to labels_output_new_xd/161_F_M12_out_c1.nii.gz
# => Saved to labels_output_new_xd/161_F_M12_out_c2.nii.gz
# => Saved to labels_output_new_xd/161_F_M12_out_c3.nii.gz
# => Saved to labels_output_new_xd/161_F_M12_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/162_M_G19_out_bg.nii.gz
# => Saved to labels_output_new_xd/162_M_G19_out_c1.nii.gz
# => Saved to labels_output_new_xd/162_M_G19_out_c2.nii.gz
# => Saved to labels_output_new_xd/162_M_G19_out_c3.nii.gz
# => Saved to labels_output_new_xd/162_M_G19_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/163_M_G18_out_bg.nii.gz
# => Saved to labels_output_new_xd/163_M_G18_out_c1.nii.gz
# => Saved to labels_output_new_xd/163_M_G18_out_c2.nii.gz
# => Saved to labels_output_new_xd/163_M_G18_out_c3.nii.gz
# => Saved to labels_output_new_xd/163_M_G18_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/164_M_J24_out_bg.nii.gz
# => Saved to labels_output_new_xd/164_M_J24_out_c1.nii.gz
# => Saved to labels_output_new_xd/164_M_J24_out_c2.nii.gz
# => Saved to labels_output_new_xd/164_M_J24_out_c3.nii.gz
# => Saved to labels_output_new_xd/164_M_J24_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/170_F_N20_out_bg.nii.gz
# => Saved to labels_output_new_xd/170_F_N20_out_c1.nii.gz
# => Saved to labels_output_new_xd/170_F_N20_out_c2.nii.gz
# => Saved to labels_output_new_xd/170_F_N20_out_c3.nii.gz
# => Saved to labels_output_new_xd/170_F_N20_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/177_F_N19_out_bg.nii.gz
# => Saved to labels_output_new_xd/177_F_N19_out_c1.nii.gz
# => Saved to labels_output_new_xd/177_F_N19_out_c2.nii.gz
# => Saved to labels_output_new_xd/177_F_N19_out_c3.nii.gz
# => Saved to labels_output_new_xd/177_F_N19_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/178_F_N17_out_bg.nii.gz
# => Saved to labels_output_new_xd/178_F_N17_out_c1.nii.gz
# => Saved to labels_output_new_xd/178_F_N17_out_c2.nii.gz
# => Saved to labels_output_new_xd/178_F_N17_out_c3.nii.gz
# => Saved to labels_output_new_xd/178_F_N17_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/185_F_N18_out_bg.nii.gz
# => Saved to labels_output_new_xd/185_F_N18_out_c1.nii.gz
# => Saved to labels_output_new_xd/185_F_N18_out_c2.nii.gz
# => Saved to labels_output_new_xd/185_F_N18_out_c3.nii.gz
# => Saved to labels_output_new_xd/185_F_N18_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/186_F_N16_out_bg.nii.gz
# => Saved to labels_output_new_xd/186_F_N16_out_c1.nii.gz
# => Saved to labels_output_new_xd/186_F_N16_out_c2.nii.gz
# => Saved to labels_output_new_xd/186_F_N16_out_c3.nii.gz
# => Saved to labels_output_new_xd/186_F_N16_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/187_M_H20_out_bg.nii.gz
# => Saved to labels_output_new_xd/187_M_H20_out_c1.nii.gz
# => Saved to labels_output_new_xd/187_M_H20_out_c2.nii.gz
# => Saved to labels_output_new_xd/187_M_H20_out_c3.nii.gz
# => Saved to labels_output_new_xd/187_M_H20_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/189_M_J25_out_bg.nii.gz
# => Saved to labels_output_new_xd/189_M_J25_out_c1.nii.gz
# => Saved to labels_output_new_xd/189_M_J25_out_c2.nii.gz
# => Saved to labels_output_new_xd/189_M_J25_out_c3.nii.gz
# => Saved to labels_output_new_xd/189_M_J25_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/195_F_O21_out_bg.nii.gz
# => Saved to labels_output_new_xd/195_F_O21_out_c1.nii.gz
# => Saved to labels_output_new_xd/195_F_O21_out_c2.nii.gz
# => Saved to labels_output_new_xd/195_F_O21_out_c3.nii.gz
# => Saved to labels_output_new_xd/195_F_O21_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/196_F_O22_out_bg.nii.gz
# => Saved to labels_output_new_xd/196_F_O22_out_c1.nii.gz
# => Saved to labels_output_new_xd/196_F_O22_out_c2.nii.gz
# => Saved to labels_output_new_xd/196_F_O22_out_c3.nii.gz
# => Saved to labels_output_new_xd/196_F_O22_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/197_M_E11_out_bg.nii.gz
# => Saved to labels_output_new_xd/197_M_E11_out_c1.nii.gz
# => Saved to labels_output_new_xd/197_M_E11_out_c2.nii.gz
# => Saved to labels_output_new_xd/197_M_E11_out_c3.nii.gz
# => Saved to labels_output_new_xd/197_M_E11_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/198_M_E14_out_bg.nii.gz
# => Saved to labels_output_new_xd/198_M_E14_out_c1.nii.gz
# => Saved to labels_output_new_xd/198_M_E14_out_c2.nii.gz
# => Saved to labels_output_new_xd/198_M_E14_out_c3.nii.gz
# => Saved to labels_output_new_xd/198_M_E14_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/199_M_E12_out_bg.nii.gz
# => Saved to labels_output_new_xd/199_M_E12_out_c1.nii.gz
# => Saved to labels_output_new_xd/199_M_E12_out_c2.nii.gz
# => Saved to labels_output_new_xd/199_M_E12_out_c3.nii.gz
# => Saved to labels_output_new_xd/199_M_E12_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/201_F_O25_out_bg.nii.gz
# => Saved to labels_output_new_xd/201_F_O25_out_c1.nii.gz
# => Saved to labels_output_new_xd/201_F_O25_out_c2.nii.gz
# => Saved to labels_output_new_xd/201_F_O25_out_c3.nii.gz
# => Saved to labels_output_new_xd/201_F_O25_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/202_F_O23_out_bg.nii.gz
# => Saved to labels_output_new_xd/202_F_O23_out_c1.nii.gz
# => Saved to labels_output_new_xd/202_F_O23_out_c2.nii.gz
# => Saved to labels_output_new_xd/202_F_O23_out_c3.nii.gz
# => Saved to labels_output_new_xd/202_F_O23_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/203_F_O24_out_bg.nii.gz
# => Saved to labels_output_new_xd/203_F_O24_out_c1.nii.gz
# => Saved to labels_output_new_xd/203_F_O24_out_c2.nii.gz
# => Saved to labels_output_new_xd/203_F_O24_out_c3.nii.gz
# => Saved to labels_output_new_xd/203_F_O24_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/207_M_P1_out_bg.nii.gz
# => Saved to labels_output_new_xd/207_M_P1_out_c1.nii.gz
# => Saved to labels_output_new_xd/207_M_P1_out_c2.nii.gz
# => Saved to labels_output_new_xd/207_M_P1_out_c3.nii.gz
# => Saved to labels_output_new_xd/207_M_P1_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/208_M_Q4_out_bg.nii.gz
# => Saved to labels_output_new_xd/208_M_Q4_out_c1.nii.gz
# => Saved to labels_output_new_xd/208_M_Q4_out_c2.nii.gz
# => Saved to labels_output_new_xd/208_M_Q4_out_c3.nii.gz
# => Saved to labels_output_new_xd/208_M_Q4_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/209_M_P2_out_bg.nii.gz
# => Saved to labels_output_new_xd/209_M_P2_out_c1.nii.gz
# => Saved to labels_output_new_xd/209_M_P2_out_c2.nii.gz
# => Saved to labels_output_new_xd/209_M_P2_out_c3.nii.gz
# => Saved to labels_output_new_xd/209_M_P2_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/213_F_AE16_out_bg.nii.gz
# => Saved to labels_output_new_xd/213_F_AE16_out_c1.nii.gz
# => Saved to labels_output_new_xd/213_F_AE16_out_c2.nii.gz
# => Saved to labels_output_new_xd/213_F_AE16_out_c3.nii.gz
# => Saved to labels_output_new_xd/213_F_AE16_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/214_F_AE17_out_bg.nii.gz
# => Saved to labels_output_new_xd/214_F_AE17_out_c1.nii.gz
# => Saved to labels_output_new_xd/214_F_AE17_out_c2.nii.gz
# => Saved to labels_output_new_xd/214_F_AE17_out_c3.nii.gz
# => Saved to labels_output_new_xd/214_F_AE17_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/215_F_AE18_out_bg.nii.gz
# => Saved to labels_output_new_xd/215_F_AE18_out_c1.nii.gz
# => Saved to labels_output_new_xd/215_F_AE18_out_c2.nii.gz
# => Saved to labels_output_new_xd/215_F_AE18_out_c3.nii.gz
# => Saved to labels_output_new_xd/215_F_AE18_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/216_F_AE19_out_bg.nii.gz
# => Saved to labels_output_new_xd/216_F_AE19_out_c1.nii.gz
# => Saved to labels_output_new_xd/216_F_AE19_out_c2.nii.gz
# => Saved to labels_output_new_xd/216_F_AE19_out_c3.nii.gz
# => Saved to labels_output_new_xd/216_F_AE19_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/220_M_P3_out_bg.nii.gz
# => Saved to labels_output_new_xd/220_M_P3_out_c1.nii.gz
# => Saved to labels_output_new_xd/220_M_P3_out_c2.nii.gz
# => Saved to labels_output_new_xd/220_M_P3_out_c3.nii.gz
# => Saved to labels_output_new_xd/220_M_P3_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/221_M_Q5_out_bg.nii.gz
# => Saved to labels_output_new_xd/221_M_Q5_out_c1.nii.gz
# => Saved to labels_output_new_xd/221_M_Q5_out_c2.nii.gz
# => Saved to labels_output_new_xd/221_M_Q5_out_c3.nii.gz
# => Saved to labels_output_new_xd/221_M_Q5_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/223_M_AA23_out_bg.nii.gz
# => Saved to labels_output_new_xd/223_M_AA23_out_c1.nii.gz
# => Saved to labels_output_new_xd/223_M_AA23_out_c2.nii.gz
# => Saved to labels_output_new_xd/223_M_AA23_out_c3.nii.gz
# => Saved to labels_output_new_xd/223_M_AA23_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/226_F_AE20_out_bg.nii.gz
# => Saved to labels_output_new_xd/226_F_AE20_out_c1.nii.gz
# => Saved to labels_output_new_xd/226_F_AE20_out_c2.nii.gz
# => Saved to labels_output_new_xd/226_F_AE20_out_c3.nii.gz
# => Saved to labels_output_new_xd/226_F_AE20_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/227_F_AB1_out_bg.nii.gz
# => Saved to labels_output_new_xd/227_F_AB1_out_c1.nii.gz
# => Saved to labels_output_new_xd/227_F_AB1_out_c2.nii.gz
# => Saved to labels_output_new_xd/227_F_AB1_out_c3.nii.gz
# => Saved to labels_output_new_xd/227_F_AB1_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/231_M_AA24_out_bg.nii.gz
# => Saved to labels_output_new_xd/231_M_AA24_out_c1.nii.gz
# => Saved to labels_output_new_xd/231_M_AA24_out_c2.nii.gz
# => Saved to labels_output_new_xd/231_M_AA24_out_c3.nii.gz
# => Saved to labels_output_new_xd/231_M_AA24_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/234_F_AB2_out_bg.nii.gz
# => Saved to labels_output_new_xd/234_F_AB2_out_c1.nii.gz
# => Saved to labels_output_new_xd/234_F_AB2_out_c2.nii.gz
# => Saved to labels_output_new_xd/234_F_AB2_out_c3.nii.gz
# => Saved to labels_output_new_xd/234_F_AB2_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/235_F_AB3_out_bg.nii.gz
# => Saved to labels_output_new_xd/235_F_AB3_out_c1.nii.gz
# => Saved to labels_output_new_xd/235_F_AB3_out_c2.nii.gz
# => Saved to labels_output_new_xd/235_F_AB3_out_c3.nii.gz
# => Saved to labels_output_new_xd/235_F_AB3_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/236_F_AB4_out_bg.nii.gz
# => Saved to labels_output_new_xd/236_F_AB4_out_c1.nii.gz
# => Saved to labels_output_new_xd/236_F_AB4_out_c2.nii.gz
# => Saved to labels_output_new_xd/236_F_AB4_out_c3.nii.gz
# => Saved to labels_output_new_xd/236_F_AB4_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/237_F_AB5_out_bg.nii.gz
# => Saved to labels_output_new_xd/237_F_AB5_out_c1.nii.gz
# => Saved to labels_output_new_xd/237_F_AB5_out_c2.nii.gz
# => Saved to labels_output_new_xd/237_F_AB5_out_c3.nii.gz
# => Saved to labels_output_new_xd/237_F_AB5_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/239_M_R6_out_bg.nii.gz
# => Saved to labels_output_new_xd/239_M_R6_out_c1.nii.gz
# => Saved to labels_output_new_xd/239_M_R6_out_c2.nii.gz
# => Saved to labels_output_new_xd/239_M_R6_out_c3.nii.gz
# => Saved to labels_output_new_xd/239_M_R6_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/240_M_R7_out_bg.nii.gz
# => Saved to labels_output_new_xd/240_M_R7_out_c1.nii.gz
# => Saved to labels_output_new_xd/240_M_R7_out_c2.nii.gz
# => Saved to labels_output_new_xd/240_M_R7_out_c3.nii.gz
# => Saved to labels_output_new_xd/240_M_R7_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/241_F_AC6_out_bg.nii.gz
# => Saved to labels_output_new_xd/241_F_AC6_out_c1.nii.gz
# => Saved to labels_output_new_xd/241_F_AC6_out_c2.nii.gz
# => Saved to labels_output_new_xd/241_F_AC6_out_c3.nii.gz
# => Saved to labels_output_new_xd/241_F_AC6_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/242_F_AC7_out_bg.nii.gz
# => Saved to labels_output_new_xd/242_F_AC7_out_c1.nii.gz
# => Saved to labels_output_new_xd/242_F_AC7_out_c2.nii.gz
# => Saved to labels_output_new_xd/242_F_AC7_out_c3.nii.gz
# => Saved to labels_output_new_xd/242_F_AC7_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/243_F_AC8_out_bg.nii.gz
# => Saved to labels_output_new_xd/243_F_AC8_out_c1.nii.gz
# => Saved to labels_output_new_xd/243_F_AC8_out_c2.nii.gz
# => Saved to labels_output_new_xd/243_F_AC8_out_c3.nii.gz
# => Saved to labels_output_new_xd/243_F_AC8_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/244_M_R8_out_bg.nii.gz
# => Saved to labels_output_new_xd/244_M_R8_out_c1.nii.gz
# => Saved to labels_output_new_xd/244_M_R8_out_c2.nii.gz
# => Saved to labels_output_new_xd/244_M_R8_out_c3.nii.gz
# => Saved to labels_output_new_xd/244_M_R8_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/246_M_S10_out_bg.nii.gz
# => Saved to labels_output_new_xd/246_M_S10_out_c1.nii.gz
# => Saved to labels_output_new_xd/246_M_S10_out_c2.nii.gz
# => Saved to labels_output_new_xd/246_M_S10_out_c3.nii.gz
# => Saved to labels_output_new_xd/246_M_S10_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/247_M_Z22_out_bg.nii.gz
# => Saved to labels_output_new_xd/247_M_Z22_out_c1.nii.gz
# => Saved to labels_output_new_xd/247_M_Z22_out_c2.nii.gz
# => Saved to labels_output_new_xd/247_M_Z22_out_c3.nii.gz
# => Saved to labels_output_new_xd/247_M_Z22_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/250_F_AC9_out_bg.nii.gz
# => Saved to labels_output_new_xd/250_F_AC9_out_c1.nii.gz
# => Saved to labels_output_new_xd/250_F_AC9_out_c2.nii.gz
# => Saved to labels_output_new_xd/250_F_AC9_out_c3.nii.gz
# => Saved to labels_output_new_xd/250_F_AC9_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/251_F_AC10_out_bg.nii.gz
# => Saved to labels_output_new_xd/251_F_AC10_out_c1.nii.gz
# => Saved to labels_output_new_xd/251_F_AC10_out_c2.nii.gz
# => Saved to labels_output_new_xd/251_F_AC10_out_c3.nii.gz
# => Saved to labels_output_new_xd/251_F_AC10_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/252_M_T11_out_bg.nii.gz
# => Saved to labels_output_new_xd/252_M_T11_out_c1.nii.gz
# => Saved to labels_output_new_xd/252_M_T11_out_c2.nii.gz
# => Saved to labels_output_new_xd/252_M_T11_out_c3.nii.gz
# => Saved to labels_output_new_xd/252_M_T11_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/253_M_T12_out_bg.nii.gz
# => Saved to labels_output_new_xd/253_M_T12_out_c1.nii.gz
# => Saved to labels_output_new_xd/253_M_T12_out_c2.nii.gz
# => Saved to labels_output_new_xd/253_M_T12_out_c3.nii.gz
# => Saved to labels_output_new_xd/253_M_T12_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/254_M_U13_out_bg.nii.gz
# => Saved to labels_output_new_xd/254_M_U13_out_c1.nii.gz
# => Saved to labels_output_new_xd/254_M_U13_out_c2.nii.gz
# => Saved to labels_output_new_xd/254_M_U13_out_c3.nii.gz
# => Saved to labels_output_new_xd/254_M_U13_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/257_F_AD11_out_bg.nii.gz
# => Saved to labels_output_new_xd/257_F_AD11_out_c1.nii.gz
# => Saved to labels_output_new_xd/257_F_AD11_out_c2.nii.gz
# => Saved to labels_output_new_xd/257_F_AD11_out_c3.nii.gz
# => Saved to labels_output_new_xd/257_F_AD11_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/258_F_AD12_out_bg.nii.gz
# => Saved to labels_output_new_xd/258_F_AD12_out_c1.nii.gz
# => Saved to labels_output_new_xd/258_F_AD12_out_c2.nii.gz
# => Saved to labels_output_new_xd/258_F_AD12_out_c3.nii.gz
# => Saved to labels_output_new_xd/258_F_AD12_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/259_F_AD1_out_bg.nii.gz
# => Saved to labels_output_new_xd/259_F_AD1_out_c1.nii.gz
# => Saved to labels_output_new_xd/259_F_AD1_out_c2.nii.gz
# => Saved to labels_output_new_xd/259_F_AD1_out_c3.nii.gz
# => Saved to labels_output_new_xd/259_F_AD1_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/263_F_AD14_out_bg.nii.gz
# => Saved to labels_output_new_xd/263_F_AD14_out_c1.nii.gz
# => Saved to labels_output_new_xd/263_F_AD14_out_c2.nii.gz
# => Saved to labels_output_new_xd/263_F_AD14_out_c3.nii.gz
# => Saved to labels_output_new_xd/263_F_AD14_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/265_M_U15_out_bg.nii.gz
# => Saved to labels_output_new_xd/265_M_U15_out_c1.nii.gz
# => Saved to labels_output_new_xd/265_M_U15_out_c2.nii.gz
# => Saved to labels_output_new_xd/265_M_U15_out_c3.nii.gz
# => Saved to labels_output_new_xd/265_M_U15_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/266_M_W16_out_bg.nii.gz
# => Saved to labels_output_new_xd/266_M_W16_out_c1.nii.gz
# => Saved to labels_output_new_xd/266_M_W16_out_c2.nii.gz
# => Saved to labels_output_new_xd/266_M_W16_out_c3.nii.gz
# => Saved to labels_output_new_xd/266_M_W16_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/269_F_AD15_out_bg.nii.gz
# => Saved to labels_output_new_xd/269_F_AD15_out_c1.nii.gz
# => Saved to labels_output_new_xd/269_F_AD15_out_c2.nii.gz
# => Saved to labels_output_new_xd/269_F_AD15_out_c3.nii.gz
# => Saved to labels_output_new_xd/269_F_AD15_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/270_F_AF21_out_bg.nii.gz
# => Saved to labels_output_new_xd/270_F_AF21_out_c1.nii.gz
# => Saved to labels_output_new_xd/270_F_AF21_out_c2.nii.gz
# => Saved to labels_output_new_xd/270_F_AF21_out_c3.nii.gz
# => Saved to labels_output_new_xd/270_F_AF21_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/271_F_AF22_out_bg.nii.gz
# => Saved to labels_output_new_xd/271_F_AF22_out_c1.nii.gz
# => Saved to labels_output_new_xd/271_F_AF22_out_c2.nii.gz
# => Saved to labels_output_new_xd/271_F_AF22_out_c3.nii.gz
# => Saved to labels_output_new_xd/271_F_AF22_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/274_M_X17_out_bg.nii.gz
# => Saved to labels_output_new_xd/274_M_X17_out_c1.nii.gz
# => Saved to labels_output_new_xd/274_M_X17_out_c2.nii.gz
# => Saved to labels_output_new_xd/274_M_X17_out_c3.nii.gz
# => Saved to labels_output_new_xd/274_M_X17_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/275_M_Y20_out_bg.nii.gz
# => Saved to labels_output_new_xd/275_M_Y20_out_c1.nii.gz
# => Saved to labels_output_new_xd/275_M_Y20_out_c2.nii.gz
# => Saved to labels_output_new_xd/275_M_Y20_out_c3.nii.gz
# => Saved to labels_output_new_xd/275_M_Y20_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/276_M_Y19_out_bg.nii.gz
# => Saved to labels_output_new_xd/276_M_Y19_out_c1.nii.gz
# => Saved to labels_output_new_xd/276_M_Y19_out_c2.nii.gz
# => Saved to labels_output_new_xd/276_M_Y19_out_c3.nii.gz
# => Saved to labels_output_new_xd/276_M_Y19_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/277_M_X18_out_bg.nii.gz
# => Saved to labels_output_new_xd/277_M_X18_out_c1.nii.gz
# => Saved to labels_output_new_xd/277_M_X18_out_c2.nii.gz
# => Saved to labels_output_new_xd/277_M_X18_out_c3.nii.gz
# => Saved to labels_output_new_xd/277_M_X18_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/280_F_AF23_out_bg.nii.gz
# => Saved to labels_output_new_xd/280_F_AF23_out_c1.nii.gz
# => Saved to labels_output_new_xd/280_F_AF23_out_c2.nii.gz
# => Saved to labels_output_new_xd/280_F_AF23_out_c3.nii.gz
# => Saved to labels_output_new_xd/280_F_AF23_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/281_F_AF24_out_bg.nii.gz
# => Saved to labels_output_new_xd/281_F_AF24_out_c1.nii.gz
# => Saved to labels_output_new_xd/281_F_AF24_out_c2.nii.gz
# => Saved to labels_output_new_xd/281_F_AF24_out_c3.nii.gz
# => Saved to labels_output_new_xd/281_F_AF24_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/282_F_AF25_out_bg.nii.gz
# => Saved to labels_output_new_xd/282_F_AF25_out_c1.nii.gz
# => Saved to labels_output_new_xd/282_F_AF25_out_c2.nii.gz
# => Saved to labels_output_new_xd/282_F_AF25_out_c3.nii.gz
# => Saved to labels_output_new_xd/282_F_AF25_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/284_M_AK11_out_bg.nii.gz
# => Saved to labels_output_new_xd/284_M_AK11_out_c1.nii.gz
# => Saved to labels_output_new_xd/284_M_AK11_out_c2.nii.gz
# => Saved to labels_output_new_xd/284_M_AK11_out_c3.nii.gz
# => Saved to labels_output_new_xd/284_M_AK11_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/285_M_AK12_out_bg.nii.gz
# => Saved to labels_output_new_xd/285_M_AK12_out_c1.nii.gz
# => Saved to labels_output_new_xd/285_M_AK12_out_c2.nii.gz
# => Saved to labels_output_new_xd/285_M_AK12_out_c3.nii.gz
# => Saved to labels_output_new_xd/285_M_AK12_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/287_F_AR6_out_bg.nii.gz
# => Saved to labels_output_new_xd/287_F_AR6_out_c1.nii.gz
# => Saved to labels_output_new_xd/287_F_AR6_out_c2.nii.gz
# => Saved to labels_output_new_xd/287_F_AR6_out_c3.nii.gz
# => Saved to labels_output_new_xd/287_F_AR6_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/289_F_AQ_out_bg.nii.gz
# => Saved to labels_output_new_xd/289_F_AQ_out_c1.nii.gz
# => Saved to labels_output_new_xd/289_F_AQ_out_c2.nii.gz
# => Saved to labels_output_new_xd/289_F_AQ_out_c3.nii.gz
# => Saved to labels_output_new_xd/289_F_AQ_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/295_M_AI17_out_bg.nii.gz
# => Saved to labels_output_new_xd/295_M_AI17_out_c1.nii.gz
# => Saved to labels_output_new_xd/295_M_AI17_out_c2.nii.gz
# => Saved to labels_output_new_xd/295_M_AI17_out_c3.nii.gz
# => Saved to labels_output_new_xd/295_M_AI17_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/296_M_AI18_out_bg.nii.gz
# => Saved to labels_output_new_xd/296_M_AI18_out_c1.nii.gz
# => Saved to labels_output_new_xd/296_M_AI18_out_c2.nii.gz
# => Saved to labels_output_new_xd/296_M_AI18_out_c3.nii.gz
# => Saved to labels_output_new_xd/296_M_AI18_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/297_M_AK13_out_bg.nii.gz
# => Saved to labels_output_new_xd/297_M_AK13_out_c1.nii.gz
# => Saved to labels_output_new_xd/297_M_AK13_out_c2.nii.gz
# => Saved to labels_output_new_xd/297_M_AK13_out_c3.nii.gz
# => Saved to labels_output_new_xd/297_M_AK13_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/301_F_AR7_out_bg.nii.gz
# => Saved to labels_output_new_xd/301_F_AR7_out_c1.nii.gz
# => Saved to labels_output_new_xd/301_F_AR7_out_c2.nii.gz
# => Saved to labels_output_new_xd/301_F_AR7_out_c3.nii.gz
# => Saved to labels_output_new_xd/301_F_AR7_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/304_F_AQ2_out_bg.nii.gz
# => Saved to labels_output_new_xd/304_F_AQ2_out_c1.nii.gz
# => Saved to labels_output_new_xd/304_F_AQ2_out_c2.nii.gz
# => Saved to labels_output_new_xd/304_F_AQ2_out_c3.nii.gz
# => Saved to labels_output_new_xd/304_F_AQ2_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/306_M_AJ9_out_bg.nii.gz
# => Saved to labels_output_new_xd/306_M_AJ9_out_c1.nii.gz
# => Saved to labels_output_new_xd/306_M_AJ9_out_c2.nii.gz
# => Saved to labels_output_new_xd/306_M_AJ9_out_c3.nii.gz
# => Saved to labels_output_new_xd/306_M_AJ9_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/307_M_AL14_out_bg.nii.gz
# => Saved to labels_output_new_xd/307_M_AL14_out_c1.nii.gz
# => Saved to labels_output_new_xd/307_M_AL14_out_c2.nii.gz
# => Saved to labels_output_new_xd/307_M_AL14_out_c3.nii.gz
# => Saved to labels_output_new_xd/307_M_AL14_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/310_F_AR8_out_bg.nii.gz
# => Saved to labels_output_new_xd/310_F_AR8_out_c1.nii.gz
# => Saved to labels_output_new_xd/310_F_AR8_out_c2.nii.gz
# => Saved to labels_output_new_xd/310_F_AR8_out_c3.nii.gz
# => Saved to labels_output_new_xd/310_F_AR8_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/312_F_AQ3_out_bg.nii.gz
# => Saved to labels_output_new_xd/312_F_AQ3_out_c1.nii.gz
# => Saved to labels_output_new_xd/312_F_AQ3_out_c2.nii.gz
# => Saved to labels_output_new_xd/312_F_AQ3_out_c3.nii.gz
# => Saved to labels_output_new_xd/312_F_AQ3_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/316_M_AJ9_out_bg.nii.gz
# => Saved to labels_output_new_xd/316_M_AJ9_out_c1.nii.gz
# => Saved to labels_output_new_xd/316_M_AJ9_out_c2.nii.gz
# => Saved to labels_output_new_xd/316_M_AJ9_out_c3.nii.gz
# => Saved to labels_output_new_xd/316_M_AJ9_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/317_M_AL15_out_bg.nii.gz
# => Saved to labels_output_new_xd/317_M_AL15_out_c1.nii.gz
# => Saved to labels_output_new_xd/317_M_AL15_out_c2.nii.gz
# => Saved to labels_output_new_xd/317_M_AL15_out_c3.nii.gz
# => Saved to labels_output_new_xd/317_M_AL15_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/318_F_AR9_out_bg.nii.gz
# => Saved to labels_output_new_xd/318_F_AR9_out_c1.nii.gz
# => Saved to labels_output_new_xd/318_F_AR9_out_c2.nii.gz
# => Saved to labels_output_new_xd/318_F_AR9_out_c3.nii.gz
# => Saved to labels_output_new_xd/318_F_AR9_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/322_F_AQ5_out_bg.nii.gz
# => Saved to labels_output_new_xd/322_F_AQ5_out_c1.nii.gz
# => Saved to labels_output_new_xd/322_F_AQ5_out_c2.nii.gz
# => Saved to labels_output_new_xd/322_F_AQ5_out_c3.nii.gz
# => Saved to labels_output_new_xd/322_F_AQ5_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/324_M_AM16_out_bg.nii.gz
# => Saved to labels_output_new_xd/324_M_AM16_out_c1.nii.gz
# => Saved to labels_output_new_xd/324_M_AM16_out_c2.nii.gz
# => Saved to labels_output_new_xd/324_M_AM16_out_c3.nii.gz
# => Saved to labels_output_new_xd/324_M_AM16_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/326_M_AO21_out_bg.nii.gz
# => Saved to labels_output_new_xd/326_M_AO21_out_c1.nii.gz
# => Saved to labels_output_new_xd/326_M_AO21_out_c2.nii.gz
# => Saved to labels_output_new_xd/326_M_AO21_out_c3.nii.gz
# => Saved to labels_output_new_xd/326_M_AO21_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/328_F_AT16_out_bg.nii.gz
# => Saved to labels_output_new_xd/328_F_AT16_out_c1.nii.gz
# => Saved to labels_output_new_xd/328_F_AT16_out_c2.nii.gz
# => Saved to labels_output_new_xd/328_F_AT16_out_c3.nii.gz
# => Saved to labels_output_new_xd/328_F_AT16_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/329_F_AS11_out_bg.nii.gz
# => Saved to labels_output_new_xd/329_F_AS11_out_c1.nii.gz
# => Saved to labels_output_new_xd/329_F_AS11_out_c2.nii.gz
# => Saved to labels_output_new_xd/329_F_AS11_out_c3.nii.gz
# => Saved to labels_output_new_xd/329_F_AS11_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/333_M_AN18_out_bg.nii.gz
# => Saved to labels_output_new_xd/333_M_AN18_out_c1.nii.gz
# => Saved to labels_output_new_xd/333_M_AN18_out_c2.nii.gz
# => Saved to labels_output_new_xd/333_M_AN18_out_c3.nii.gz
# => Saved to labels_output_new_xd/333_M_AN18_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/335_F_AT17_out_bg.nii.gz
# => Saved to labels_output_new_xd/335_F_AT17_out_c1.nii.gz
# => Saved to labels_output_new_xd/335_F_AT17_out_c2.nii.gz
# => Saved to labels_output_new_xd/335_F_AT17_out_c3.nii.gz
# => Saved to labels_output_new_xd/335_F_AT17_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/336_F_AS12_out_bg.nii.gz
# => Saved to labels_output_new_xd/336_F_AS12_out_c1.nii.gz
# => Saved to labels_output_new_xd/336_F_AS12_out_c2.nii.gz
# => Saved to labels_output_new_xd/336_F_AS12_out_c3.nii.gz
# => Saved to labels_output_new_xd/336_F_AS12_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/340_M_AN19_out_bg.nii.gz
# => Saved to labels_output_new_xd/340_M_AN19_out_c1.nii.gz
# => Saved to labels_output_new_xd/340_M_AN19_out_c2.nii.gz
# => Saved to labels_output_new_xd/340_M_AN19_out_c3.nii.gz
# => Saved to labels_output_new_xd/340_M_AN19_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/342_M_AO22_out_bg.nii.gz
# => Saved to labels_output_new_xd/342_M_AO22_out_c1.nii.gz
# => Saved to labels_output_new_xd/342_M_AO22_out_c2.nii.gz
# => Saved to labels_output_new_xd/342_M_AO22_out_c3.nii.gz
# => Saved to labels_output_new_xd/342_M_AO22_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/344_M_AG2_out_bg.nii.gz
# => Saved to labels_output_new_xd/344_M_AG2_out_c1.nii.gz
# => Saved to labels_output_new_xd/344_M_AG2_out_c2.nii.gz
# => Saved to labels_output_new_xd/344_M_AG2_out_c3.nii.gz
# => Saved to labels_output_new_xd/344_M_AG2_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/350_F_AT18_out_bg.nii.gz
# => Saved to labels_output_new_xd/350_F_AT18_out_c1.nii.gz
# => Saved to labels_output_new_xd/350_F_AT18_out_c2.nii.gz
# => Saved to labels_output_new_xd/350_F_AT18_out_c3.nii.gz
# => Saved to labels_output_new_xd/350_F_AT18_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/351_F_AU21_out_bg.nii.gz
# => Saved to labels_output_new_xd/351_F_AU21_out_c1.nii.gz
# => Saved to labels_output_new_xd/351_F_AU21_out_c2.nii.gz
# => Saved to labels_output_new_xd/351_F_AU21_out_c3.nii.gz
# => Saved to labels_output_new_xd/351_F_AU21_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/353_M_AN20_out_bg.nii.gz
# => Saved to labels_output_new_xd/353_M_AN20_out_c1.nii.gz
# => Saved to labels_output_new_xd/353_M_AN20_out_c2.nii.gz
# => Saved to labels_output_new_xd/353_M_AN20_out_c3.nii.gz
# => Saved to labels_output_new_xd/353_M_AN20_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/355_M_AP24_out_bg.nii.gz
# => Saved to labels_output_new_xd/355_M_AP24_out_c1.nii.gz
# => Saved to labels_output_new_xd/355_M_AP24_out_c2.nii.gz
# => Saved to labels_output_new_xd/355_M_AP24_out_c3.nii.gz
# => Saved to labels_output_new_xd/355_M_AP24_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/359_F_AT19_out_bg.nii.gz
# => Saved to labels_output_new_xd/359_F_AT19_out_c1.nii.gz
# => Saved to labels_output_new_xd/359_F_AT19_out_c2.nii.gz
# => Saved to labels_output_new_xd/359_F_AT19_out_c3.nii.gz
# => Saved to labels_output_new_xd/359_F_AT19_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/360_F_AU22_out_bg.nii.gz
# => Saved to labels_output_new_xd/360_F_AU22_out_c1.nii.gz
# => Saved to labels_output_new_xd/360_F_AU22_out_c2.nii.gz
# => Saved to labels_output_new_xd/360_F_AU22_out_c3.nii.gz
# => Saved to labels_output_new_xd/360_F_AU22_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/368_M_AM17_out_bg.nii.gz
# => Saved to labels_output_new_xd/368_M_AM17_out_c1.nii.gz
# => Saved to labels_output_new_xd/368_M_AM17_out_c2.nii.gz
# => Saved to labels_output_new_xd/368_M_AM17_out_c3.nii.gz
# => Saved to labels_output_new_xd/368_M_AM17_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/370_F_AT20_out_bg.nii.gz
# => Saved to labels_output_new_xd/370_F_AT20_out_c1.nii.gz
# => Saved to labels_output_new_xd/370_F_AT20_out_c2.nii.gz
# => Saved to labels_output_new_xd/370_F_AT20_out_c3.nii.gz
# => Saved to labels_output_new_xd/370_F_AT20_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/371_F_AU23_out_bg.nii.gz
# => Saved to labels_output_new_xd/371_F_AU23_out_c1.nii.gz
# => Saved to labels_output_new_xd/371_F_AU23_out_c2.nii.gz
# => Saved to labels_output_new_xd/371_F_AU23_out_c3.nii.gz
# => Saved to labels_output_new_xd/371_F_AU23_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/373_F_AS14_out_bg.nii.gz
# => Saved to labels_output_new_xd/373_F_AS14_out_c1.nii.gz
# => Saved to labels_output_new_xd/373_F_AS14_out_c2.nii.gz
# => Saved to labels_output_new_xd/373_F_AS14_out_c3.nii.gz
# => Saved to labels_output_new_xd/373_F_AS14_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/378_M_AH5_out_bg.nii.gz
# => Saved to labels_output_new_xd/378_M_AH5_out_c1.nii.gz
# => Saved to labels_output_new_xd/378_M_AH5_out_c2.nii.gz
# => Saved to labels_output_new_xd/378_M_AH5_out_c3.nii.gz
# => Saved to labels_output_new_xd/378_M_AH5_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/379_M_AG2_out_bg.nii.gz
# => Saved to labels_output_new_xd/379_M_AG2_out_c1.nii.gz
# => Saved to labels_output_new_xd/379_M_AG2_out_c2.nii.gz
# => Saved to labels_output_new_xd/379_M_AG2_out_c3.nii.gz
# => Saved to labels_output_new_xd/379_M_AG2_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/380_F_AU24_out_bg.nii.gz
# => Saved to labels_output_new_xd/380_F_AU24_out_c1.nii.gz
# => Saved to labels_output_new_xd/380_F_AU24_out_c2.nii.gz
# => Saved to labels_output_new_xd/380_F_AU24_out_c3.nii.gz
# => Saved to labels_output_new_xd/380_F_AU24_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/387_M_AG3_out_bg.nii.gz
# => Saved to labels_output_new_xd/387_M_AG3_out_c1.nii.gz
# => Saved to labels_output_new_xd/387_M_AG3_out_c2.nii.gz
# => Saved to labels_output_new_xd/387_M_AG3_out_c3.nii.gz
# => Saved to labels_output_new_xd/387_M_AG3_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/392_F_AU25_out_bg.nii.gz
# => Saved to labels_output_new_xd/392_F_AU25_out_c1.nii.gz
# => Saved to labels_output_new_xd/392_F_AU25_out_c2.nii.gz
# => Saved to labels_output_new_xd/392_F_AU25_out_c3.nii.gz
# => Saved to labels_output_new_xd/392_F_AU25_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/400_M_AX6_out_bg.nii.gz
# => Saved to labels_output_new_xd/400_M_AX6_out_c1.nii.gz
# => Saved to labels_output_new_xd/400_M_AX6_out_c2.nii.gz
# => Saved to labels_output_new_xd/400_M_AX6_out_c3.nii.gz
# => Saved to labels_output_new_xd/400_M_AX6_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/402_F_BI16_out_bg.nii.gz
# => Saved to labels_output_new_xd/402_F_BI16_out_c1.nii.gz
# => Saved to labels_output_new_xd/402_F_BI16_out_c2.nii.gz
# => Saved to labels_output_new_xd/402_F_BI16_out_c3.nii.gz
# ...
# => Saved to labels_output_new_xd/485_F_BJ24_out_bg.nii.gz
# => Saved to labels_output_new_xd/485_F_BJ24_out_c1.nii.gz
# => Saved to labels_output_new_xd/485_F_BJ24_out_c2.nii.gz
# => Saved to labels_output_new_xd/485_F_BJ24_out_c3.nii.gz
# => Saved to labels_output_new_xd/485_F_BJ24_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/488_F_BF4_out_bg.nii.gz
# => Saved to labels_output_new_xd/488_F_BF4_out_c1.nii.gz
# => Saved to labels_output_new_xd/488_F_BF4_out_c2.nii.gz
# => Saved to labels_output_new_xd/488_F_BF4_out_c3.nii.gz
# => Saved to labels_output_new_xd/488_F_BF4_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/489_F_BH14_out_bg.nii.gz
# => Saved to labels_output_new_xd/489_F_BH14_out_c1.nii.gz
# => Saved to labels_output_new_xd/489_F_BH14_out_c2.nii.gz
# => Saved to labels_output_new_xd/489_F_BH14_out_c3.nii.gz
# => Saved to labels_output_new_xd/489_F_BH14_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/494_M_AY10_out_bg.nii.gz
# => Saved to labels_output_new_xd/494_M_AY10_out_c1.nii.gz
# => Saved to labels_output_new_xd/494_M_AY10_out_c2.nii.gz
# => Saved to labels_output_new_xd/494_M_AY10_out_c3.nii.gz
# => Saved to labels_output_new_xd/494_M_AY10_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/496_M_BC20_out_bg.nii.gz
# => Saved to labels_output_new_xd/496_M_BC20_out_c1.nii.gz
# => Saved to labels_output_new_xd/496_M_BC20_out_c2.nii.gz
# => Saved to labels_output_new_xd/496_M_BC20_out_c3.nii.gz
# => Saved to labels_output_new_xd/496_M_BC20_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/498_F_BJ25_out_bg.nii.gz
# => Saved to labels_output_new_xd/498_F_BJ25_out_c1.nii.gz
# => Saved to labels_output_new_xd/498_F_BJ25_out_c2.nii.gz
# => Saved to labels_output_new_xd/498_F_BJ25_out_c3.nii.gz
# => Saved to labels_output_new_xd/498_F_BJ25_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/501_F_BF5_out_bg.nii.gz
# => Saved to labels_output_new_xd/501_F_BF5_out_c1.nii.gz
# => Saved to labels_output_new_xd/501_F_BF5_out_c2.nii.gz
# => Saved to labels_output_new_xd/501_F_BF5_out_c3.nii.gz
# => Saved to labels_output_new_xd/501_F_BF5_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/505_M_BK1_out_bg.nii.gz
# => Saved to labels_output_new_xd/505_M_BK1_out_c1.nii.gz
# => Saved to labels_output_new_xd/505_M_BK1_out_c2.nii.gz
# => Saved to labels_output_new_xd/505_M_BK1_out_c3.nii.gz
# => Saved to labels_output_new_xd/505_M_BK1_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/507_M_BQ16_out_bg.nii.gz
# => Saved to labels_output_new_xd/507_M_BQ16_out_c1.nii.gz
# => Saved to labels_output_new_xd/507_M_BQ16_out_c2.nii.gz
# => Saved to labels_output_new_xd/507_M_BQ16_out_c3.nii.gz
# => Saved to labels_output_new_xd/507_M_BQ16_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/508_M_BS21_out_bg.nii.gz
# => Saved to labels_output_new_xd/508_M_BS21_out_c1.nii.gz
# => Saved to labels_output_new_xd/508_M_BS21_out_c2.nii.gz
# => Saved to labels_output_new_xd/508_M_BS21_out_c3.nii.gz
# => Saved to labels_output_new_xd/508_M_BS21_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/511_F_BU1_out_bg.nii.gz
# => Saved to labels_output_new_xd/511_F_BU1_out_c1.nii.gz
# => Saved to labels_output_new_xd/511_F_BU1_out_c2.nii.gz
# => Saved to labels_output_new_xd/511_F_BU1_out_c3.nii.gz
# => Saved to labels_output_new_xd/511_F_BU1_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/513_M_BK2_out_bg.nii.gz
# => Saved to labels_output_new_xd/513_M_BK2_out_c1.nii.gz
# => Saved to labels_output_new_xd/513_M_BK2_out_c2.nii.gz
# => Saved to labels_output_new_xd/513_M_BK2_out_c3.nii.gz
# => Saved to labels_output_new_xd/513_M_BK2_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/514_F_BW11_out_bg.nii.gz
# => Saved to labels_output_new_xd/514_F_BW11_out_c1.nii.gz
# => Saved to labels_output_new_xd/514_F_BW11_out_c2.nii.gz
# => Saved to labels_output_new_xd/514_F_BW11_out_c3.nii.gz
# => Saved to labels_output_new_xd/514_F_BW11_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/516_M_BS22_out_bg.nii.gz
# => Saved to labels_output_new_xd/516_M_BS22_out_c1.nii.gz
# => Saved to labels_output_new_xd/516_M_BS22_out_c2.nii.gz
# => Saved to labels_output_new_xd/516_M_BS22_out_c3.nii.gz
# => Saved to labels_output_new_xd/516_M_BS22_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/518_F_BU2_out_bg.nii.gz
# => Saved to labels_output_new_xd/518_F_BU2_out_c1.nii.gz
# => Saved to labels_output_new_xd/518_F_BU2_out_c2.nii.gz
# => Saved to labels_output_new_xd/518_F_BU2_out_c3.nii.gz
# => Saved to labels_output_new_xd/518_F_BU2_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/521_M_BK3_out_bg.nii.gz
# => Saved to labels_output_new_xd/521_M_BK3_out_c1.nii.gz
# => Saved to labels_output_new_xd/521_M_BK3_out_c2.nii.gz
# => Saved to labels_output_new_xd/521_M_BK3_out_c3.nii.gz
# => Saved to labels_output_new_xd/521_M_BK3_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/523_M_BO11_out_bg.nii.gz
# => Saved to labels_output_new_xd/523_M_BO11_out_c1.nii.gz
# => Saved to labels_output_new_xd/523_M_BO11_out_c2.nii.gz
# => Saved to labels_output_new_xd/523_M_BO11_out_c3.nii.gz
# => Saved to labels_output_new_xd/523_M_BO11_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/525_F_BX16_out_bg.nii.gz
# => Saved to labels_output_new_xd/525_F_BX16_out_c1.nii.gz
# => Saved to labels_output_new_xd/525_F_BX16_out_c2.nii.gz
# => Saved to labels_output_new_xd/525_F_BX16_out_c3.nii.gz
# => Saved to labels_output_new_xd/525_F_BX16_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/528_F_BW12_out_bg.nii.gz
# => Saved to labels_output_new_xd/528_F_BW12_out_c1.nii.gz
# => Saved to labels_output_new_xd/528_F_BW12_out_c2.nii.gz
# => Saved to labels_output_new_xd/528_F_BW12_out_c3.nii.gz
# => Saved to labels_output_new_xd/528_F_BW12_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/529_F_BW13_out_bg.nii.gz
# => Saved to labels_output_new_xd/529_F_BW13_out_c1.nii.gz
# => Saved to labels_output_new_xd/529_F_BW13_out_c2.nii.gz
# => Saved to labels_output_new_xd/529_F_BW13_out_c3.nii.gz
# => Saved to labels_output_new_xd/529_F_BW13_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/534_M_BO12_out_bg.nii.gz
# => Saved to labels_output_new_xd/534_M_BO12_out_c1.nii.gz
# => Saved to labels_output_new_xd/534_M_BO12_out_c2.nii.gz
# => Saved to labels_output_new_xd/534_M_BO12_out_c3.nii.gz
# => Saved to labels_output_new_xd/534_M_BO12_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/535_M_BR18_out_bg.nii.gz
# => Saved to labels_output_new_xd/535_M_BR18_out_c1.nii.gz
# => Saved to labels_output_new_xd/535_M_BR18_out_c2.nii.gz
# => Saved to labels_output_new_xd/535_M_BR18_out_c3.nii.gz
# => Saved to labels_output_new_xd/535_M_BR18_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/537_F_BV6_out_bg.nii.gz
# => Saved to labels_output_new_xd/537_F_BV6_out_c1.nii.gz
# => Saved to labels_output_new_xd/537_F_BV6_out_c2.nii.gz
# => Saved to labels_output_new_xd/537_F_BV6_out_c3.nii.gz
# => Saved to labels_output_new_xd/537_F_BV6_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/538_F_BU3_out_bg.nii.gz
# => Saved to labels_output_new_xd/538_F_BU3_out_c1.nii.gz
# => Saved to labels_output_new_xd/538_F_BU3_out_c2.nii.gz
# => Saved to labels_output_new_xd/538_F_BU3_out_c3.nii.gz
# => Saved to labels_output_new_xd/538_F_BU3_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/539_F_BX17_out_bg.nii.gz
# => Saved to labels_output_new_xd/539_F_BX17_out_c1.nii.gz
# => Saved to labels_output_new_xd/539_F_BX17_out_c2.nii.gz
# => Saved to labels_output_new_xd/539_F_BX17_out_c3.nii.gz
# => Saved to labels_output_new_xd/539_F_BX17_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/540_M_BL5_out_bg.nii.gz
# => Saved to labels_output_new_xd/540_M_BL5_out_c1.nii.gz
# => Saved to labels_output_new_xd/540_M_BL5_out_c2.nii.gz
# => Saved to labels_output_new_xd/540_M_BL5_out_c3.nii.gz
# => Saved to labels_output_new_xd/540_M_BL5_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/542_M_BO13_out_bg.nii.gz
# => Saved to labels_output_new_xd/542_M_BO13_out_c1.nii.gz
# => Saved to labels_output_new_xd/542_M_BO13_out_c2.nii.gz
# => Saved to labels_output_new_xd/542_M_BO13_out_c3.nii.gz
# => Saved to labels_output_new_xd/542_M_BO13_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/548_F_BW14_out_bg.nii.gz
# => Saved to labels_output_new_xd/548_F_BW14_out_c1.nii.gz
# => Saved to labels_output_new_xd/548_F_BW14_out_c2.nii.gz
# => Saved to labels_output_new_xd/548_F_BW14_out_c3.nii.gz
# => Saved to labels_output_new_xd/548_F_BW14_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/549_F_BV7_out_bg.nii.gz
# => Saved to labels_output_new_xd/549_F_BV7_out_c1.nii.gz
# => Saved to labels_output_new_xd/549_F_BV7_out_c2.nii.gz
# => Saved to labels_output_new_xd/549_F_BV7_out_c3.nii.gz
# => Saved to labels_output_new_xd/549_F_BV7_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/550_F_BU4_out_bg.nii.gz
# => Saved to labels_output_new_xd/550_F_BU4_out_c1.nii.gz
# => Saved to labels_output_new_xd/550_F_BU4_out_c2.nii.gz
# => Saved to labels_output_new_xd/550_F_BU4_out_c3.nii.gz
# => Saved to labels_output_new_xd/550_F_BU4_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/552_F_BW15_out_bg.nii.gz
# => Saved to labels_output_new_xd/552_F_BW15_out_c1.nii.gz
# => Saved to labels_output_new_xd/552_F_BW15_out_c2.nii.gz
# => Saved to labels_output_new_xd/552_F_BW15_out_c3.nii.gz
# => Saved to labels_output_new_xd/552_F_BW15_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/553_M_BQ17_out_bg.nii.gz
# => Saved to labels_output_new_xd/553_M_BQ17_out_c1.nii.gz
# => Saved to labels_output_new_xd/553_M_BQ17_out_c2.nii.gz
# => Saved to labels_output_new_xd/553_M_BQ17_out_c3.nii.gz
# => Saved to labels_output_new_xd/553_M_BQ17_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/555_F_BP0_out_bg.nii.gz
# => Saved to labels_output_new_xd/555_F_BP0_out_c1.nii.gz
# => Saved to labels_output_new_xd/555_F_BP0_out_c2.nii.gz
# => Saved to labels_output_new_xd/555_F_BP0_out_c3.nii.gz
# => Saved to labels_output_new_xd/555_F_BP0_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/556_M_BT23_out_bg.nii.gz
# => Saved to labels_output_new_xd/556_M_BT23_out_c1.nii.gz
# => Saved to labels_output_new_xd/556_M_BT23_out_c2.nii.gz
# => Saved to labels_output_new_xd/556_M_BT23_out_c3.nii.gz
# => Saved to labels_output_new_xd/556_M_BT23_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/557_F_BV8_out_bg.nii.gz
# => Saved to labels_output_new_xd/557_F_BV8_out_c1.nii.gz
# => Saved to labels_output_new_xd/557_F_BV8_out_c2.nii.gz
# => Saved to labels_output_new_xd/557_F_BV8_out_c3.nii.gz
# => Saved to labels_output_new_xd/557_F_BV8_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/558_F_BU5_out_bg.nii.gz
# => Saved to labels_output_new_xd/558_F_BU5_out_c1.nii.gz
# => Saved to labels_output_new_xd/558_F_BU5_out_c2.nii.gz
# => Saved to labels_output_new_xd/558_F_BU5_out_c3.nii.gz
# => Saved to labels_output_new_xd/558_F_BU5_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/559_F_BX18_out_bg.nii.gz
# => Saved to labels_output_new_xd/559_F_BX18_out_c1.nii.gz
# => Saved to labels_output_new_xd/559_F_BX18_out_c2.nii.gz
# => Saved to labels_output_new_xd/559_F_BX18_out_c3.nii.gz
# => Saved to labels_output_new_xd/559_F_BX18_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/563_M_BP15_out_bg.nii.gz
# => Saved to labels_output_new_xd/563_M_BP15_out_c1.nii.gz
# => Saved to labels_output_new_xd/563_M_BP15_out_c2.nii.gz
# => Saved to labels_output_new_xd/563_M_BP15_out_c3.nii.gz
# => Saved to labels_output_new_xd/563_M_BP15_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/564_M_BR19_out_bg.nii.gz
# => Saved to labels_output_new_xd/564_M_BR19_out_c1.nii.gz
# => Saved to labels_output_new_xd/564_M_BR19_out_c2.nii.gz
# => Saved to labels_output_new_xd/564_M_BR19_out_c3.nii.gz
# => Saved to labels_output_new_xd/564_M_BR19_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/566_M_BT24_out_bg.nii.gz
# => Saved to labels_output_new_xd/566_M_BT24_out_c1.nii.gz
# => Saved to labels_output_new_xd/566_M_BT24_out_c2.nii.gz
# => Saved to labels_output_new_xd/566_M_BT24_out_c3.nii.gz
# => Saved to labels_output_new_xd/566_M_BT24_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/567_F_BV9_out_bg.nii.gz
# => Saved to labels_output_new_xd/567_F_BV9_out_c1.nii.gz
# => Saved to labels_output_new_xd/567_F_BV9_out_c2.nii.gz
# => Saved to labels_output_new_xd/567_F_BV9_out_c3.nii.gz
# => Saved to labels_output_new_xd/567_F_BV9_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/568_F_BX19_out_bg.nii.gz
# => Saved to labels_output_new_xd/568_F_BX19_out_c1.nii.gz
# => Saved to labels_output_new_xd/568_F_BX19_out_c2.nii.gz
# => Saved to labels_output_new_xd/568_F_BX19_out_c3.nii.gz
# => Saved to labels_output_new_xd/568_F_BX19_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/575_M_BR20_out_bg.nii.gz
# => Saved to labels_output_new_xd/575_M_BR20_out_c1.nii.gz
# => Saved to labels_output_new_xd/575_M_BR20_out_c2.nii.gz
# => Saved to labels_output_new_xd/575_M_BR20_out_c3.nii.gz
# => Saved to labels_output_new_xd/575_M_BR20_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/577_M_BT25_out_bg.nii.gz
# => Saved to labels_output_new_xd/577_M_BT25_out_c1.nii.gz
# => Saved to labels_output_new_xd/577_M_BT25_out_c2.nii.gz
# => Saved to labels_output_new_xd/577_M_BT25_out_c3.nii.gz
# => Saved to labels_output_new_xd/577_M_BT25_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/578_F_BV10_out_bg.nii.gz
# => Saved to labels_output_new_xd/578_F_BV10_out_c1.nii.gz
# => Saved to labels_output_new_xd/578_F_BV10_out_c2.nii.gz
# => Saved to labels_output_new_xd/578_F_BV10_out_c3.nii.gz
# => Saved to labels_output_new_xd/578_F_BV10_out.nii.gz
# torch.Size([1, 1, 305, 216, 227])
# torch.Size([1, 4, 305, 216, 227])
# => Saved to labels_output_new_xd/579_F_BX20_out_bg.nii.gz
# KeyboardInterrupt
